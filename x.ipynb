# %% [raw]
# i want to create an array in which i store the symbols "Nifty 50", "Niftybees" then using yahoofinance i want to fetch the daily closing prices of both.

# %%
# Installing Packages
# !pip install yfinance datetime numpy pandas scikit-learn pyotp asyncio aiohttp
# Out:
# Requirement already satisfied: yfinance in ./lib/python3.13/site-packages (0.2.55)
# Requirement already satisfied: datetime in ./lib/python3.13/site-packages (5.5)
# Requirement already satisfied: numpy in ./lib/python3.13/site-packages (2.2.4)
# Requirement already satisfied: pandas in ./lib/python3.13/site-packages (2.2.3)
# Requirement already satisfied: scikit-learn in ./lib/python3.13/site-packages (1.6.1)
# Requirement already satisfied: pyotp in ./lib/python3.13/site-packages (2.9.0)
# Requirement already satisfied: asyncio in ./lib/python3.13/site-packages (3.4.3)
# Requirement already satisfied: aiohttp in ./lib/python3.13/site-packages (3.11.14)
# Requirement already satisfied: requests>=2.31 in ./lib/python3.13/site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in ./lib/python3.13/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in ./lib/python3.13/site-packages (from yfinance) (4.3.7)
# Requirement already satisfied: pytz>=2022.5 in ./lib/python3.13/site-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in ./lib/python3.13/site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in ./lib/python3.13/site-packages (from yfinance) (3.17.9)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in ./lib/python3.13/site-packages (from yfinance) (4.13.3)
# Requirement already satisfied: zope.interface in ./lib/python3.13/site-packages (from datetime) (7.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in ./lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.6.0 in ./lib/python3.13/site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in ./lib/python3.13/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./lib/python3.13/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in ./lib/python3.13/site-packages (from aiohttp) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in ./lib/python3.13/site-packages (from aiohttp) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in ./lib/python3.13/site-packages (from aiohttp) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./lib/python3.13/site-packages (from aiohttp) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./lib/python3.13/site-packages (from aiohttp) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in ./lib/python3.13/site-packages (from aiohttp) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./lib/python3.13/site-packages (from aiohttp) (1.18.3)
# Requirement already satisfied: soupsieve>1.2 in ./lib/python3.13/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in ./lib/python3.13/site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.13.0)
# Requirement already satisfied: six>=1.5 in ./lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./lib/python3.13/site-packages (from requests>=2.31->yfinance) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in ./lib/python3.13/site-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./lib/python3.13/site-packages (from requests>=2.31->yfinance) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./lib/python3.13/site-packages (from requests>=2.31->yfinance) (2025.1.31)
# Requirement already satisfied: setuptools in ./lib/python3.13/site-packages (from zope.interface->datetime) (78.1.0)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import yfinance as yf

# Step 1: Define the symbols
symbols = ["^NSEI", "NIFTYBEES.NS"]

# Step 2: Fetch daily closing prices
data = yf.download(symbols, start="2024-01-01", end="2024-03-26")["Close"]

# Step 3: Display the closing prices
print(data.tail())  # Show the last few rows
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  2 of 2 completed
# Ticker      NIFTYBEES.NS         ^NSEI
# Date
# 2024-03-18    243.979996  22055.699219
# 2024-03-19    241.600006  21817.449219
# 2024-03-20    241.580002  21839.099609
# 2024-03-21    243.990005  22011.949219
# 2024-03-22    244.740005  22096.750000

# %% [raw]
# start date is 01/01/2025 and end date is today. today is dynamic going to change everyday. so make appropriate changes.

# %%
import yfinance as yf
from datetime import datetime

# Step 1: Define the symbols
symbols = ["^NSEI", "NIFTYBEES.NS"]

# Step 2: Define the date range
start_date = "2025-01-01"
end_date = datetime.today().strftime("%Y-%m-%d")  # Dynamically fetch today's date

# Step 3: Fetch daily closing prices
data = yf.download(symbols, start=start_date, end=end_date)["Close"]

# Step 4: Display the closing prices
print(data.tail())  # Show the last few rows
# Out:
# [*********************100%***********************]  2 of 2 completed
# Ticker      NIFTYBEES.NS         ^NSEI
# Date
# 2025-03-25    264.730011  23668.650391
# 2025-03-26    262.899994  23486.849609
# 2025-03-27    263.730011  23591.949219
# 2025-03-28    263.209991  23519.349609
# 2025-04-01    259.600006  23165.699219

# %% [raw]
# i want to fetch o h l c of both for today.

# %%
import yfinance as yf

# Step 1: Define the symbols
symbols = ["^NSEI", "NIFTYBEES.NS"]

# Step 2: Fetch today's OHLC data
ohlc_data = {symbol: yf.Ticker(symbol).history(period="1d")[["Open", "High", "Low", "Close"]] for symbol in symbols}

# Step 3: Display OHLC data
for symbol, data in ohlc_data.items():
    print(f"\nOHLC for {symbol} (Today):\n", data)
# Out:
# OHLC for ^NSEI (Today):
#                                     Open     High           Low         Close
# Date
# 2025-04-02 00:00:00+05:30  23192.599609  23350.0  23158.449219  23332.349609
#
# OHLC for NIFTYBEES.NS (Today):
#                                   Open        High         Low       Close
# Date
# 2025-04-02 00:00:00+05:30  260.700012  261.850006  259.109985  261.640015

# %% [raw]
# fetch the daily closing prices of Nifty 50 and Niftybees. start date is 01/01/2025 and end date is today. today is dynamic going to change everyday. also fetch and print the todays opening price of Nifty 50.

# %%
import yfinance as yf
from datetime import datetime

# Step 1: Define the symbols
symbols = ["^NSEI", "NIFTYBEES.NS"]

# Step 2: Define the date range
start_date = "2025-01-01"
end_date = datetime.today().strftime("%Y-%m-%d")  # Dynamically fetch today's date

# Step 3: Fetch daily closing prices
closing_prices = yf.download(symbols, start=start_date, end=end_date)["Close"]
print("\nDaily Closing Prices:\n", closing_prices.tail())  # Print last few rows

# Step 4: Fetch today's opening price of Nifty 50
nifty_today = yf.Ticker("^NSEI").history(period="1d")
nifty_opening_price = nifty_today["Open"].iloc[0] if not nifty_today.empty else "Market Closed"

print(f"\nToday's Opening Price of Nifty 50: {nifty_opening_price}")
# Out:
# [*********************100%***********************]  2 of 2 completed
# Daily Closing Prices:
#  Ticker      NIFTYBEES.NS         ^NSEI
# Date
# 2025-03-25    264.730011  23668.650391
# 2025-03-26    262.899994  23486.849609
# 2025-03-27    263.730011  23591.949219
# 2025-03-28    263.209991  23519.349609
# 2025-04-01    259.600006  23165.699219
#
# Today's Opening Price of Nifty 50: 23192.599609375

# %% [raw]
# now, use the simple linear regression for nifty 50 and niftybees closing prices and use the nifty 50 opening price to predict the opening price of niftybees.

# %%
import yfinance as yf
from datetime import datetime
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

# Step 1: Define symbols
symbols = ["^NSEI", "NIFTYBEES.NS"]

# Step 2: Define the date range
start_date = "2025-01-01"
end_date = datetime.today().strftime("%Y-%m-%d")

# Step 3: Fetch historical closing prices
closing_prices = yf.download(symbols, start=start_date, end=end_date)["Close"]

# Step 4: Prepare data for regression
X = closing_prices["^NSEI"].values.reshape(-1, 1)  # Nifty 50 closing prices (independent variable)
y = closing_prices["NIFTYBEES.NS"].values.reshape(-1, 1)  # Niftybees closing prices (dependent variable)

# Step 5: Train the Linear Regression model
model = LinearRegression()
model.fit(X, y)

# Step 6: Fetch today's opening price of Nifty 50
nifty_today = yf.Ticker("^NSEI").history(period="1d")
nifty_opening_price = nifty_today["Open"].iloc[0] if not nifty_today.empty else None

# Step 7: Predict Niftybees opening price
if nifty_opening_price is not None:
    niftybees_predicted_opening = model.predict(np.array([[nifty_opening_price]]))[0][0]
    print(f"\nToday's Opening Price of Nifty 50: {nifty_opening_price}")
    print(f"Predicted Opening Price of Niftybees: {niftybees_predicted_opening:.2f}")
else:
    print("Market is closed or Nifty 50 opening price is unavailable.")
# Out:
# [*********************100%***********************]  2 of 2 completed
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 23
#      21 # Step 5: Train the Linear Regression model
#      22 model = LinearRegression()
# ---> 23 model.fit(X, y)
#      25 # Step 6: Fetch today's opening price of Nifty 50
#      26 nifty_today = yf.Ticker("^NSEI").history(period="1d")
#
# File ~/Documents/algo-trading/venv/lib/python3.13/site-packages/sklearn/base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File ~/Documents/algo-trading/venv/lib/python3.13/site-packages/sklearn/linear_model/_base.py:601, in LinearRegression.fit(self, X, y, sample_weight)
#     597 n_jobs_ = self.n_jobs
#     599 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 601 X, y = validate_data(
#     602     self,
#     603     X,
#     604     y,
#     605     accept_sparse=accept_sparse,
#     606     y_numeric=True,
#     607     multi_output=True,
#     608     force_writeable=True,
#     609 )
#     611 has_sw = sample_weight is not None
#     612 if has_sw:
#
# File ~/Documents/algo-trading/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2961, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2959         y = check_array(y, input_name="y", **check_y_params)
#    2960     else:
# -> 2961         X, y = check_X_y(X, y, **check_params)
#    2962     out = X, y
#    2964 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~/Documents/algo-trading/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:1370, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1364     raise ValueError(
#    1365         f"{estimator_name} requires y to be passed, but the target y is None"
#    1366     )
#    1368 ensure_all_finite = _deprecate_force_all_finite(force_all_finite, ensure_all_finite)
# -> 1370 X = check_array(
#    1371     X,
#    1372     accept_sparse=accept_sparse,
#    1373     accept_large_sparse=accept_large_sparse,
#    1374     dtype=dtype,
#    1375     order=order,
#    1376     copy=copy,
#    1377     force_writeable=force_writeable,
#    1378     ensure_all_finite=ensure_all_finite,
#    1379     ensure_2d=ensure_2d,
#    1380     allow_nd=allow_nd,
#    1381     ensure_min_samples=ensure_min_samples,
#    1382     ensure_min_features=ensure_min_features,
#    1383     estimator=estimator,
#    1384     input_name="X",
#    1385 )
#    1387 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1389 check_consistent_length(X, y)
#
# File ~/Documents/algo-trading/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:1107, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1101     raise ValueError(
#    1102         "Found array with dim %d. %s expected <= 2."
#    1103         % (array.ndim, estimator_name)
#    1104     )
#    1106 if ensure_all_finite:
# -> 1107     _assert_all_finite(
#    1108         array,
#    1109         input_name=input_name,
#    1110         estimator_name=estimator_name,
#    1111         allow_nan=ensure_all_finite == "allow-nan",
#    1112     )
#    1114 if copy:
#    1115     if _is_numpy_namespace(xp):
#    1116         # only make a copy if `array` and `array_orig` may share memory`
#
# File ~/Documents/algo-trading/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:120, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     117 if first_pass_isfinite:
#     118     return
# --> 120 _assert_all_finite_element_wise(
#     121     X,
#     122     xp=xp,
#     123     allow_nan=allow_nan,
#     124     msg_dtype=msg_dtype,
#     125     estimator_name=estimator_name,
#     126     input_name=input_name,
#     127 )
#
# File ~/Documents/algo-trading/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:169, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     152 if estimator_name and input_name == "X" and has_nan_error:
#     153     # Improve the error message on how to handle missing values in
#     154     # scikit-learn.
#     155     msg_err += (
#     156         f"\n{estimator_name} does not accept missing values"
#     157         " encoded as NaN natively. For supervised learning, you might want"
#    (...)    167         "#estimators-that-handle-nan-values"
#     168     )
# --> 169 raise ValueError(msg_err)
#
# ValueError: Input X contains NaN.
# LinearRegression does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values

# %% [raw]
# above error

# %%
import yfinance as yf
from datetime import datetime
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

# Step 1: Define symbols
symbols = ["^NSEI", "NIFTYBEES.NS"]

# Step 2: Define the date range
start_date = "2025-01-01"
end_date = datetime.today().strftime("%Y-%m-%d")

# Step 3: Fetch historical closing prices
closing_prices = yf.download(symbols, start=start_date, end=end_date)["Close"]

# Step 4: Drop NaN values
closing_prices.dropna(inplace=True)  # Remove rows with missing values

# Step 5: Prepare data for regression
X = closing_prices["^NSEI"].values.reshape(-1, 1)  # Nifty 50 closing prices
y = closing_prices["NIFTYBEES.NS"].values.reshape(-1, 1)  # Niftybees closing prices

# Step 6: Train the Linear Regression model
model = LinearRegression()
model.fit(X, y)

# Step 7: Fetch today's opening price of Nifty 50
nifty_today = yf.Ticker("^NSEI").history(period="1d")
nifty_opening_price = nifty_today["Open"].iloc[0] if not nifty_today.empty else None

# Step 8: Predict Niftybees opening price
if nifty_opening_price is not None:
    niftybees_predicted_opening = model.predict(np.array([[nifty_opening_price]]))[0][0]
    print(f"\nToday's Opening Price of Nifty 50: {nifty_opening_price}")
    print(f"Predicted Opening Price of Niftybees: {niftybees_predicted_opening:.2f}")
else:
    print("Market is closed or Nifty 50 opening price is unavailable.")

# %%
import yfinance as yf
from datetime import datetime
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

# Step 1: Define symbols (Underlying Index → ETF)
assets = {
    "^NSEI": "NIFTYBEES.NS",      # Nifty 50 → Niftybees
    "^NSMIDCP50": "JUNIORBEES.NS", # Nifty Next 50 → Junior Bees
    "^NSEBANK": "BANKBEES.NS"      # Nifty Bank → Bank Bees
}

# Step 2: Define the date range
start_date = "2025-01-01"
end_date = datetime.today().strftime("%Y-%m-%d")

# Step 3: Fetch daily closing prices
symbols = list(assets.keys()) + list(assets.values())  # All underlying + ETFs
closing_prices = yf.download(symbols, start=start_date, end=end_date)["Close"]

# Step 4: Drop NaN values to ensure matching dates
closing_prices.dropna(inplace=True)

# Step 5: Fetch today's opening prices for underlying indices
opening_prices = {}
for index in assets.keys():
    data = yf.Ticker(index).history(period="1d")
    opening_prices[index] = data["Open"].iloc[0] if not data.empty else None

# Step 6: Train Linear Regression models & Predict ETF Opening Prices
predicted_openings = {}

for index, etf in assets.items():
    # Prepare data for regression (X: Index Closing, y: ETF Closing)
    X = closing_prices[index].values.reshape(-1, 1)
    y = closing_prices[etf].values.reshape(-1, 1)

    # Train Linear Regression Model
    model = LinearRegression()
    model.fit(X, y)

    # Predict ETF opening price if underlying opening price is available
    if opening_prices[index] is not None:
        predicted_openings[etf] = model.predict(np.array([[opening_prices[index]]]))[0][0]
    else:
        predicted_openings[etf] = "Market Closed"

# Step 7: Print results
print("\nToday's Opening Prices:")
for index, price in opening_prices.items():
    print(f"{index}: {price}")

print("\nPredicted ETF Opening Prices:")
for etf, predicted in predicted_openings.items():
    print(f"{etf}: {predicted:.2f}" if isinstance(predicted, float) else f"{etf}: {predicted}")

# %% [raw]
# NSEMDCP50

# %%
import yfinance as yf
from datetime import datetime
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

# Step 1: Define symbols (Underlying Index → ETF)
assets = {
    "^NSEI": "NIFTYBEES.NS",      # Nifty 50 → Niftybees
    "^NSEMDCP50": "JUNIORBEES.NS", # Nifty Next 50 → Junior Bees
    "^NSEBANK": "BANKBEES.NS"      # Nifty Bank → Bank Bees
}

# Step 2: Define the date range
start_date = "2025-01-01"
end_date = datetime.today().strftime("%Y-%m-%d")

# Step 3: Fetch daily closing prices
symbols = list(assets.keys()) + list(assets.values())  # All underlying + ETFs
closing_prices = yf.download(symbols, start=start_date, end=end_date)["Close"]

# Step 4: Drop NaN values to ensure matching dates
closing_prices.dropna(inplace=True)

# Step 5: Fetch today's opening prices for underlying indices
opening_prices = {}
for index in assets.keys():
    data = yf.Ticker(index).history(period="1d")
    opening_prices[index] = data["Open"].iloc[0] if not data.empty else None

# Step 6: Train Linear Regression models & Predict ETF Opening Prices
predicted_openings = {}

for index, etf in assets.items():
    # Prepare data for regression (X: Index Closing, y: ETF Closing)
    X = closing_prices[index].values.reshape(-1, 1)
    y = closing_prices[etf].values.reshape(-1, 1)

    # Train Linear Regression Model
    model = LinearRegression()
    model.fit(X, y)

    # Predict ETF opening price if underlying opening price is available
    if opening_prices[index] is not None:
        predicted_openings[etf] = model.predict(np.array([[opening_prices[index]]]))[0][0]
    else:
        predicted_openings[etf] = "Market Closed"

# Step 7: Print results
print("\nToday's Opening Prices:")
for index, price in opening_prices.items():
    print(f"{index}: {price}")

print("\nPredicted ETF Opening Prices:")
for etf, predicted in predicted_openings.items():
    print(f"{etf}: {predicted:.2f}" if isinstance(predicted, float) else f"{etf}: {predicted}")

# %%
NSMIDCP

# %%
import yfinance as yf
from datetime import datetime
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

# Step 1: Define symbols (Underlying Index → ETF)
assets = {
    "^NSEI": "NIFTYBEES.NS",      # Nifty 50 → Niftybees
    "^NSMIDCP": "JUNIORBEES.NS",   # Nifty Next 50 → Junior Bees
    "^NSEBANK": "BANKBEES.NS"      # Nifty Bank → Bank Bees
}

# Step 2: Define the date range
start_date = "2025-01-01"
end_date = datetime.today().strftime("%Y-%m-%d")

# Step 3: Fetch daily closing prices
symbols = list(assets.keys()) + list(assets.values())  # All underlying + ETFs
closing_prices = yf.download(symbols, start=start_date, end=end_date)["Close"]

# Step 4: Drop NaN values to ensure matching dates
closing_prices.dropna(inplace=True)

# Step 5: Fetch today's opening prices for underlying indices
opening_prices = {}
for index in assets.keys():
    data = yf.Ticker(index).history(period="1d")
    opening_prices[index] = data["Open"].iloc[0] if not data.empty else None

# Step 6: Train Linear Regression models & Predict ETF Opening Prices
predicted_openings = {}

for index, etf in assets.items():
    # Prepare data for regression (X: Index Closing, y: ETF Closing)
    X = closing_prices[index].values.reshape(-1, 1)
    y = closing_prices[etf].values.reshape(-1, 1)

    # Train Linear Regression Model
    model = LinearRegression()
    model.fit(X, y)

    # Predict ETF opening price if underlying opening price is available
    if opening_prices[index] is not None:
        predicted_openings[etf] = model.predict(np.array([[opening_prices[index]]]))[0][0]
    else:
        predicted_openings[etf] = "Market Closed"

# Step 7: Print results
print("\nToday's Opening Prices:")
for index, price in opening_prices.items():
    print(f"{index}: {price}")

print("\nPredicted ETF Opening Prices:")
for etf, predicted in predicted_openings.items():
    print(f"{etf}: {predicted:.2f}" if isinstance(predicted, float) else f"{etf}: {predicted}")

# %% [raw]
# improve the code in structure, efficiency, readability & maintainability, error handling. also you can use classes and functions whenever necessary. add small meaningful comments.

# %%
import yfinance as yf
from datetime import datetime
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

class ETFPricePredictor:
    """Predicts ETF opening prices using linear regression based on underlying index data."""

    def __init__(self, assets, start_date="2025-01-01"):
        """
        Initializes the ETFPricePredictor.

        :param assets: Dictionary mapping underlying indices to their respective ETFs.
        :param start_date: The start date for fetching historical data.
        """
        self.assets = assets
        self.start_date = start_date
        self.end_date = datetime.today().strftime("%Y-%m-%d")
        self.closing_prices = None
        self.opening_prices = {}
        self.models = {}

    def fetch_closing_prices(self):
        """Fetches daily closing prices for underlying indices and ETFs."""
        symbols = list(self.assets.keys()) + list(self.assets.values())  # Get all required symbols
        try:
            data = yf.download(symbols, start=self.start_date, end=self.end_date)["Close"]
            data.dropna(inplace=True)  # Remove missing values to align data
            self.closing_prices = data
        except Exception as e:
            print(f"Error fetching closing prices: {e}")

    def fetch_opening_prices(self):
        """Fetches today's opening prices for the underlying indices."""
        for index in self.assets.keys():
            try:
                data = yf.Ticker(index).history(period="1d")
                self.opening_prices[index] = data["Open"].iloc[0] if not data.empty else None
            except Exception as e:
                print(f"Error fetching opening price for {index}: {e}")
                self.opening_prices[index] = None  # Handle missing data safely

    def train_models(self):
        """Trains a Linear Regression model for each ETF based on its underlying index."""
        if self.closing_prices is None:
            print("Error: Closing prices not available. Fetch data first.")
            return
        
        for index, etf in self.assets.items():
            try:
                X = self.closing_prices[index].values.reshape(-1, 1)  # Independent variable (Index closing)
                y = self.closing_prices[etf].values.reshape(-1, 1)  # Dependent variable (ETF closing)
                
                model = LinearRegression()
                model.fit(X, y)  # Train the model
                self.models[etf] = model
            except Exception as e:
                print(f"Error training model for {etf}: {e}")

    def predict_opening_prices(self):
        """Predicts today's opening price for ETFs using the trained regression models."""
        predicted_openings = {}
        for index, etf in self.assets.items():
            if self.opening_prices.get(index) is not None and etf in self.models:
                try:
                    predicted_openings[etf] = self.models[etf].predict(np.array([[self.opening_prices[index]]]))[0][0]
                except Exception as e:
                    print(f"Error predicting opening price for {etf}: {e}")
                    predicted_openings[etf] = None
            else:
                predicted_openings[etf] = "Market Closed or Model Not Available"
        return predicted_openings

    def run(self):
        """Executes the complete process: fetch data, train models, and predict prices."""
        print("Fetching historical closing prices...")
        self.fetch_closing_prices()

        print("Fetching today's opening prices...")
        self.fetch_opening_prices()

        print("Training regression models...")
        self.train_models()

        print("\nToday's Opening Prices:")
        for index, price in self.opening_prices.items():
            print(f"{index}: {price}")

        print("\nPredicted ETF Opening Prices:")
        predicted_prices = self.predict_opening_prices()
        for etf, price in predicted_prices.items():
            print(f"{etf}: {price:.2f}" if isinstance(price, float) else f"{etf}: {price}")

if __name__ == "__main__":
    assets = {
        "^NSEI": "NIFTYBEES.NS",      # Nifty 50 → Niftybees
        "^NSMIDCP": "JUNIORBEES.NS",   # Nifty Next 50 → Junior Bees
        "^NSEBANK": "BANKBEES.NS"      # Nifty Bank → Bank Bees
    }

    predictor = ETFPricePredictor(assets)
    predictor.run()

# %% [raw]
# add assets = {...} into the class and run functions in main.

# %%
import yfinance as yf
from datetime import datetime
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

class ETFPricePredictor:
    """Predicts ETF opening prices using linear regression based on underlying index data."""

    def __init__(self, start_date="2025-01-01"):
        """
        Initializes the ETFPricePredictor.

        :param start_date: The start date for fetching historical data.
        """
        self.assets = {
            "^NSEI": "NIFTYBEES.NS",      # Nifty 50 → Niftybees
            "^NSMIDCP": "JUNIORBEES.NS",   # Nifty Next 50 → Junior Bees
            "^NSEBANK": "BANKBEES.NS"      # Nifty Bank → Bank Bees
        }
        self.start_date = start_date
        self.end_date = datetime.today().strftime("%Y-%m-%d")
        self.closing_prices = None
        self.opening_prices = {}
        self.models = {}

    def fetch_closing_prices(self):
        """Fetches daily closing prices for underlying indices and ETFs."""
        symbols = list(self.assets.keys()) + list(self.assets.values())  # Get all required symbols
        try:
            data = yf.download(symbols, start=self.start_date, end=self.end_date)["Close"]
            data.dropna(inplace=True)  # Remove missing values to align data
            self.closing_prices = data
        except Exception as e:
            print(f"Error fetching closing prices: {e}")

    def fetch_opening_prices(self):
        """Fetches today's opening prices for the underlying indices."""
        for index in self.assets.keys():
            try:
                data = yf.Ticker(index).history(period="1d")
                self.opening_prices[index] = data["Open"].iloc[0] if not data.empty else None
            except Exception as e:
                print(f"Error fetching opening price for {index}: {e}")
                self.opening_prices[index] = None  # Handle missing data safely

    def train_models(self):
        """Trains a Linear Regression model for each ETF based on its underlying index."""
        if self.closing_prices is None:
            print("Error: Closing prices not available. Fetch data first.")
            return
        
        for index, etf in self.assets.items():
            try:
                X = self.closing_prices[index].values.reshape(-1, 1)  # Independent variable (Index closing)
                y = self.closing_prices[etf].values.reshape(-1, 1)  # Dependent variable (ETF closing)
                
                model = LinearRegression()
                model.fit(X, y)  # Train the model
                self.models[etf] = model
            except Exception as e:
                print(f"Error training model for {etf}: {e}")

    def predict_opening_prices(self):
        """Predicts today's opening price for ETFs using the trained regression models."""
        predicted_openings = {}
        for index, etf in self.assets.items():
            if self.opening_prices.get(index) is not None and etf in self.models:
                try:
                    predicted_openings[etf] = self.models[etf].predict(np.array([[self.opening_prices[index]]]))[0][0]
                except Exception as e:
                    print(f"Error predicting opening price for {etf}: {e}")
                    predicted_openings[etf] = None
            else:
                predicted_openings[etf] = "Market Closed or Model Not Available"
        return predicted_openings

def main():
    """Main execution function"""
    predictor = ETFPricePredictor()

    print("Fetching historical closing prices...")
    predictor.fetch_closing_prices()

    print("Fetching today's opening prices...")
    predictor.fetch_opening_prices()

    print("Training regression models...")
    predictor.train_models()

    print("\nToday's Opening Prices:")
    for index, price in predictor.opening_prices.items():
        print(f"{index}: {price}")

    print("\nPredicted ETF Opening Prices:")
    predicted_prices = predictor.predict_opening_prices()
    for etf, price in predicted_prices.items():
        print(f"{etf}: {price:.2f}" if isinstance(price, float) else f"{etf}: {price}")

if __name__ == "__main__":
    main()

# %% [raw]
# manual update

# %%
import yfinance as yf
from datetime import datetime
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

class ETFPricePredictor:
    """Predicts ETF opening prices using linear regression based on underlying index data."""

    def __init__(self, start_date="2025-01-01"):
        """
        Initializes the ETFPricePredictor.

        :param start_date: The start date for fetching historical data.
        """
        self.assets = {
            "^NSEI": "NIFTYBEES.NS",       # Nifty 50 → Niftybees
            "^NSMIDCP": "JUNIORBEES.NS",   # Nifty Next 50 → Juniorbees
            "^NSEBANK": "BANKBEES.NS"      # Nifty Bank → Bankbees
        }
        self.start_date = start_date
        self.end_date = datetime.today().strftime("%Y-%m-%d")
        self.closing_prices = None
        self.opening_prices = {}
        self.models = {}

    def fetch_closing_prices(self):
        """Fetches daily closing prices for underlying indices and ETFs."""
        symbols = list(self.assets.keys()) + list(self.assets.values())  # Get all required symbols
        try:
            data = yf.download(symbols, start=self.start_date, end=self.end_date)["Close"]
            data.dropna(inplace=True)  # Remove missing values to align data
            self.closing_prices = data
        except Exception as e:
            print(f"Error fetching closing prices: {e}")

    def fetch_opening_prices(self):
        """Fetches today's opening prices for the underlying indices."""
        for index in self.assets.keys():
            try:
                data = yf.Ticker(index).history(period="1d")
                self.opening_prices[index] = data["Open"].iloc[0] if not data.empty else None
            except Exception as e:
                print(f"Error fetching opening price for {index}: {e}")
                self.opening_prices[index] = None  # Handle missing data safely

    def train_models(self):
        """Trains a Linear Regression model for each ETF based on its underlying index."""
        if self.closing_prices is None:
            print("Error: Closing prices not available. Fetch data first.")
            return
        
        for index, etf in self.assets.items():
            try:
                x = self.closing_prices[index].values.reshape(-1, 1)  # Independent variable (Index closing)
                y = self.closing_prices[etf].values.reshape(-1, 1)  # Dependent variable (ETF closing)
                
                model = LinearRegression()
                model.fit(x, y)  # Train the model
                self.models[etf] = model
            except Exception as e:
                print(f"Error training model for {etf}: {e}")

    def predict_opening_prices(self):
        """Predicts today's opening price for ETFs using the trained regression models."""
        predicted_openings = {}
        for index, etf in self.assets.items():
            if self.opening_prices.get(index) is not None and etf in self.models:
                try:
                    predicted_openings[etf] = self.models[etf].predict(np.array([[self.opening_prices[index]]]))[0][0]
                except Exception as e:
                    print(f"Error predicting opening price for {etf}: {e}")
                    predicted_openings[etf] = None
            else:
                predicted_openings[etf] = "Market Closed or Model Not Available"
        return predicted_openings

def main():
    """Main execution function"""
    predictor = ETFPricePredictor()

    print("Fetching historical closing prices...")
    predictor.fetch_closing_prices()

    print("Fetching today's opening prices...")
    predictor.fetch_opening_prices()

    print("Training regression models...")
    predictor.train_models()

    print("\nToday's Opening Prices:")
    for index, price in predictor.opening_prices.items():
        print(f"{index}: {price}")

    print("\nPredicted ETF Opening Prices:")
    predicted_prices = predictor.predict_opening_prices()
    for etf, price in predicted_prices.items():
        print(f"{etf}: {price:.2f}" if isinstance(price, float) else f"{etf}: {price}")

if __name__ == "__main__":
    main()

# %% [raw]
# dont make any changes in ETFPricePredictor class except adding asset = {..} into main because it is used both the class ETFPricePredictor and new class. create a new class to fetch average volume and calculate safe volume by using formula average volume / 4500 and i want it as an integer. also add comment after formula "6.25 hours = 22,500 seconds | 22500/5 = 4500"

# %%
import yfinance as yf
from datetime import datetime
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

class ETFPricePredictor:
    """Predicts ETF opening prices using linear regression based on underlying index data."""

    def __init__(self, assets, start_date="2025-01-01"):
        """
        Initializes the ETFPricePredictor.

        :param assets: Dictionary mapping underlying indices to their respective ETFs.
        :param start_date: The start date for fetching historical data.
        """
        self.assets = assets
        self.start_date = start_date
        self.end_date = datetime.today().strftime("%Y-%m-%d")
        self.closing_prices = None
        self.opening_prices = {}
        self.models = {}

    def fetch_closing_prices(self):
        """Fetches daily closing prices for underlying indices and ETFs."""
        symbols = list(self.assets.keys()) + list(self.assets.values())  # Get all required symbols
        try:
            data = yf.download(symbols, start=self.start_date, end=self.end_date)["Close"]
            data.dropna(inplace=True)  # Remove missing values to align data
            self.closing_prices = data
        except Exception as e:
            print(f"Error fetching closing prices: {e}")

    def fetch_opening_prices(self):
        """Fetches today's opening prices for the underlying indices."""
        for index in self.assets.keys():
            try:
                data = yf.Ticker(index).history(period="1d")
                self.opening_prices[index] = data["Open"].iloc[0] if not data.empty else None
            except Exception as e:
                print(f"Error fetching opening price for {index}: {e}")
                self.opening_prices[index] = None  # Handle missing data safely

    def train_models(self):
        """Trains a Linear Regression model for each ETF based on its underlying index."""
        if self.closing_prices is None:
            print("Error: Closing prices not available. Fetch data first.")
            return
        
        for index, etf in self.assets.items():
            try:
                X = self.closing_prices[index].values.reshape(-1, 1)  # Independent variable (Index closing)
                y = self.closing_prices[etf].values.reshape(-1, 1)  # Dependent variable (ETF closing)
                
                model = LinearRegression()
                model.fit(X, y)  # Train the model
                self.models[etf] = model
            except Exception as e:
                print(f"Error training model for {etf}: {e}")

    def predict_opening_prices(self):
        """Predicts today's opening price for ETFs using the trained regression models."""
        predicted_openings = {}
        for index, etf in self.assets.items():
            if self.opening_prices.get(index) is not None and etf in self.models:
                try:
                    predicted_openings[etf] = self.models[etf].predict(np.array([[self.opening_prices[index]]]))[0][0]
                except Exception as e:
                    print(f"Error predicting opening price for {etf}: {e}")
                    predicted_openings[etf] = None
            else:
                predicted_openings[etf] = "Market Closed or Model Not Available"
        return predicted_openings

class ETFVolumeAnalyzer:
    """Analyzes ETF trading volume and calculates safe volume."""

    def __init__(self, assets, start_date="2025-01-01"):
        """
        Initializes the ETFVolumeAnalyzer.

        :param assets: Dictionary mapping underlying indices to their respective ETFs.
        :param start_date: The start date for fetching historical volume data.
        """
        self.etf_symbols = list(assets.values())  # ETFs only (excluding indices)
        self.start_date = start_date
        self.end_date = datetime.today().strftime("%Y-%m-%d")
        self.average_volumes = {}
        self.safe_volumes = {}

    def fetch_average_volumes(self):
        """Fetches daily ETF trading volumes and calculates the average volume for each ETF."""
        try:
            volume_data = yf.download(self.etf_symbols, start=self.start_date, end=self.end_date)["Volume"]
            self.average_volumes = volume_data.mean().to_dict()  # Calculate average volume
        except Exception as e:
            print(f"Error fetching ETF volumes: {e}")

    def calculate_safe_volumes(self):
        """Calculates safe volume using the formula: Average Volume / 4500."""
        for etf, avg_volume in self.average_volumes.items():
            self.safe_volumes[etf] = int(avg_volume / 4500)  # Ensure integer output
            # 6.25 hours = 22,500 seconds | 22500/5 = 4500

    def get_safe_volumes(self):
        """Returns the calculated safe volumes."""
        return self.safe_volumes

def main():
    """Main execution function"""
    assets = {
        "^NSEI": "NIFTYBEES.NS",      # Nifty 50 → Niftybees
        "^NSMIDCP": "JUNIORBEES.NS",   # Nifty Next 50 → Junior Bees
        "^NSEBANK": "BANKBEES.NS"      # Nifty Bank → Bank Bees
    }

    # Predict ETF opening prices
    predictor = ETFPricePredictor(assets)
    
    print("Fetching historical closing prices...")
    predictor.fetch_closing_prices()

    print("Fetching today's opening prices...")
    predictor.fetch_opening_prices()

    print("Training regression models...")
    predictor.train_models()

    print("\nToday's Opening Prices:")
    for index, price in predictor.opening_prices.items():
        print(f"{index}: {price}")

    print("\nPredicted ETF Opening Prices:")
    predicted_prices = predictor.predict_opening_prices()
    for etf, price in predicted_prices.items():
        print(f"{etf}: {price:.2f}" if isinstance(price, float) else f"{etf}: {price}")

    # Analyze ETF trading volumes
    volume_analyzer = ETFVolumeAnalyzer(assets)
    
    print("\nFetching ETF volume data...")
    volume_analyzer.fetch_average_volumes()

    print("Calculating safe volumes...")
    volume_analyzer.calculate_safe_volumes()

    print("\nAverage ETF Trading Volumes:")
    for etf, avg_volume in volume_analyzer.average_volumes.items():
        print(f"{etf}: {avg_volume:,.0f}")

    print("\nSafe Trading Volumes:")
    safe_volumes = volume_analyzer.get_safe_volumes()
    for etf, safe_vol in safe_volumes.items():
        print(f"{etf}: {safe_vol}")

if __name__ == "__main__":
    main()

# %% [raw]
# import requests
# import pyotp
#
# # Zerodha credentials
# KITE_USERNAME = 'DXU151'
# KITE_PASSWORD = 'Pratibha'
# KITE_TOTP_KEY = 'FLJBDJNEBOIMZZZPE25YYYR72Y2B2IAP'
#
# class ZerodhaLogin:
#     """Handles Zerodha Kite login and maintains a session for order placement."""
#
#     LOGIN_URL = "https://kite.zerodha.com/api/login"
#     TOTP_URL = "https://kite.zerodha.com/api/twofa"
#
#     def __init__(self):
#         self.session = requests.Session()
#         self.enctoken = None  # Will store the authentication token after login
#         self.headers = None  # Store headers after login
#
#     def login(self):
#         """Performs login using Zerodha credentials and TOTP authentication."""
#         try:
#             # Step 1: Submit username & password
#             res1 = self.session.post(self.LOGIN_URL, data={
#                 "user_id": KITE_USERNAME,
#                 "password": KITE_PASSWORD,
#                 "type": "user_id"
#             })
#             res1.raise_for_status()  # Raise error for HTTP failures
#             loginRes = res1.json()
#
#             if "data" not in loginRes or "request_id" not in loginRes["data"]:
#                 raise ValueError("Login failed: Invalid response from server")
#
#             # Step 2: Submit TOTP for 2FA authentication
#             totp_value = pyotp.TOTP(KITE_TOTP_KEY).now()
#             finalRes = self.session.post(self.TOTP_URL, data={
#                 "request_id": loginRes["data"]["request_id"],
#                 "twofa_value": totp_value,
#                 "user_id": loginRes["data"]["user_id"],
#                 "twofa_type": "totp"
#             })
#             finalRes.raise_for_status()
#             authRes = finalRes.json()
#
#             if "status" not in authRes or authRes["status"] != "success":
#                 raise ValueError("TOTP Authentication failed")
#
#             # Step 3: Extract encrypted token from cookies
#             self.enctoken = self.session.cookies.get_dict().get("enctoken", None)
#             if not self.enctoken:
#                 raise ValueError("Failed to retrieve enctoken")
#
#             # Step 4: Store headers after login
#             self.headers = {
#                 "Authorization": f"enctoken {self.enctoken}",
#                 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36",
#                 "Referer": "https://kite.zerodha.com/dashboard",
#                 "Accept-Language": "en-US,en;q=0.6",
#                 "Content-type": "application/x-www-form-urlencoded",
#                 "Accept": "application/json, text/plain, */*",
#             }
#
#             print("Login successful!")
#             return self.session, self.enctoken, self.headers
#
#         except requests.exceptions.RequestException as e:
#             print(f"HTTP Request Failed: {e}")
#         except ValueError as ve:
#             print(f"Error: {ve}")
#
# above is the code of login at zerodha i dont want any changes in ETFPricePredictor, ETFVolumeAnalyzer and ZerodhaLogin classes. i want to add ZerodhaLogin class to the selected code. make appropriate modification and changes.

# %%
import yfinance as yf
from datetime import datetime
import numpy as np
import pandas as pd
import requests
import pyotp
from sklearn.linear_model import LinearRegression

class ETFPricePredictor:
    """Predicts ETF opening prices using linear regression based on underlying index data."""

    def __init__(self, assets, start_date="2025-01-01"):
        self.assets = assets
        self.start_date = start_date
        self.end_date = datetime.today().strftime("%Y-%m-%d")
        self.closing_prices = None
        self.opening_prices = {}
        self.models = {}

    def fetch_closing_prices(self):
        """Fetches daily closing prices for underlying indices and ETFs."""
        symbols = list(self.assets.keys()) + list(self.assets.values())  # Get all required symbols
        try:
            data = yf.download(symbols, start=self.start_date, end=self.end_date)["Close"]
            data.dropna(inplace=True)  # Remove missing values to align data
            self.closing_prices = data
        except Exception as e:
            print(f"Error fetching closing prices: {e}")

    def fetch_opening_prices(self):
        """Fetches today's opening prices for the underlying indices."""
        for index in self.assets.keys():
            try:
                data = yf.Ticker(index).history(period="1d")
                self.opening_prices[index] = data["Open"].iloc[0] if not data.empty else None
            except Exception as e:
                print(f"Error fetching opening price for {index}: {e}")
                self.opening_prices[index] = None  # Handle missing data safely

    def train_models(self):
        """Trains a Linear Regression model for each ETF based on its underlying index."""
        if self.closing_prices is None:
            print("Error: Closing prices not available. Fetch data first.")
            return
        
        for index, etf in self.assets.items():
            try:
                X = self.closing_prices[index].values.reshape(-1, 1)  # Independent variable (Index closing)
                y = self.closing_prices[etf].values.reshape(-1, 1)  # Dependent variable (ETF closing)
                
                model = LinearRegression()
                model.fit(X, y)  # Train the model
                self.models[etf] = model
            except Exception as e:
                print(f"Error training model for {etf}: {e}")

    def predict_opening_prices(self):
        """Predicts today's opening price for ETFs using the trained regression models."""
        predicted_openings = {}
        for index, etf in self.assets.items():
            if self.opening_prices.get(index) is not None and etf in self.models:
                try:
                    predicted_openings[etf] = self.models[etf].predict(np.array([[self.opening_prices[index]]]))[0][0]
                except Exception as e:
                    print(f"Error predicting opening price for {etf}: {e}")
                    predicted_openings[etf] = None
            else:
                predicted_openings[etf] = "Market Closed or Model Not Available"
        return predicted_openings

class ETFVolumeAnalyzer:
    """Analyzes ETF trading volume and calculates safe volume."""

    def __init__(self, assets, start_date="2025-01-01"):
        self.etf_symbols = list(assets.values())  # ETFs only (excluding indices)
        self.start_date = start_date
        self.end_date = datetime.today().strftime("%Y-%m-%d")
        self.average_volumes = {}
        self.safe_volumes = {}

    def fetch_average_volumes(self):
        """Fetches daily ETF trading volumes and calculates the average volume for each ETF."""
        try:
            volume_data = yf.download(self.etf_symbols, start=self.start_date, end=self.end_date)["Volume"]
            self.average_volumes = volume_data.mean().to_dict()  # Calculate average volume
        except Exception as e:
            print(f"Error fetching ETF volumes: {e}")

    def calculate_safe_volumes(self):
        """Calculates safe volume using the formula: Average Volume / 4500."""
        for etf, avg_volume in self.average_volumes.items():
            self.safe_volumes[etf] = int(avg_volume / 4500)  # Ensure integer output
            # 6.25 hours = 22,500 seconds | 22500/5 = 4500

    def get_safe_volumes(self):
        """Returns the calculated safe volumes."""
        return self.safe_volumes

class ZerodhaLogin:
    """Handles Zerodha Kite login and maintains a session for order placement."""
    
    LOGIN_URL = "https://kite.zerodha.com/api/login"
    TOTP_URL = "https://kite.zerodha.com/api/twofa"

    def __init__(self, username, password, totp_key):
        self.username = username
        self.password = password
        self.totp_key = totp_key
        self.session = requests.Session()
        self.enctoken = None  # Will store the authentication token after login
        self.headers = None  # Store headers after login

    def login(self):
        """Performs login using Zerodha credentials and TOTP authentication."""
        try:
            # Step 1: Submit username & password
            res1 = self.session.post(self.LOGIN_URL, data={
                "user_id": self.username,
                "password": self.password,
                "type": "user_id"
            })
            res1.raise_for_status()  # Raise error for HTTP failures
            loginRes = res1.json()

            if "data" not in loginRes or "request_id" not in loginRes["data"]:
                raise ValueError("Login failed: Invalid response from server")

            # Step 2: Submit TOTP for 2FA authentication
            totp_value = pyotp.TOTP(self.totp_key).now()
            finalRes = self.session.post(self.TOTP_URL, data={
                "request_id": loginRes["data"]["request_id"],
                "twofa_value": totp_value,
                "user_id": loginRes["data"]["user_id"],
                "twofa_type": "totp"
            })
            finalRes.raise_for_status()
            authRes = finalRes.json()

            if "status" not in authRes or authRes["status"] != "success":
                raise ValueError("TOTP Authentication failed")

            # Step 3: Extract encrypted token from cookies
            self.enctoken = self.session.cookies.get_dict().get("enctoken", None)
            if not self.enctoken:
                raise ValueError("Failed to retrieve enctoken")

            print("Login successful!")
            return self.session, self.enctoken

        except requests.exceptions.RequestException as e:
            print(f"HTTP Request Failed: {e}")
        except ValueError as ve:
            print(f"Error: {ve}")

def main():
    """Main execution function"""
    assets = {
        "^NSEI": "NIFTYBEES.NS",
        "^NSMIDCP": "JUNIORBEES.NS",
        "^NSEBANK": "BANKBEES.NS"
    }

    # Log in to Zerodha
    zerodha = ZerodhaLogin("DXU151", "Pratibha", "FLJBDJNEBOIMZZZPE25YYYR72Y2B2IAP")
    session, enctoken = zerodha.login()

    # Predict ETF opening prices
    predictor = ETFPricePredictor(assets)
    predictor.fetch_closing_prices()
    predictor.fetch_opening_prices()
    predictor.train_models()
    
    predicted_prices = predictor.predict_opening_prices()

    # Analyze ETF trading volumes
    volume_analyzer = ETFVolumeAnalyzer(assets)
    volume_analyzer.fetch_average_volumes()
    volume_analyzer.calculate_safe_volumes()
    
    safe_volumes = volume_analyzer.get_safe_volumes()

if __name__ == "__main__":
    main()

# %% [raw]
# manual changes

# %%
import yfinance as yf
from datetime import datetime
import numpy as np
import pandas as pd
import requests
import pyotp
from sklearn.linear_model import LinearRegression

class ETFPricePredictor:
    """Predicts ETF opening prices using linear regression based on underlying index data."""

    def __init__(self, assets, start_date="2025-01-01"):
        self.assets = assets
        self.start_date = start_date
        self.end_date = datetime.today().strftime("%Y-%m-%d")
        self.closing_prices = None
        self.opening_prices = {}
        self.models = {}

    def fetch_closing_prices(self):
        """Fetches daily closing prices for underlying indices and ETFs."""
        symbols = list(self.assets.keys()) + list(self.assets.values())  # Get all required symbols
        try:
            data = yf.download(symbols, start=self.start_date, end=self.end_date)["Close"]
            data.dropna(inplace=True)  # Remove missing values to align data
            self.closing_prices = data
        except Exception as e:
            print(f"Error fetching closing prices: {e}")

    def fetch_opening_prices(self):
        """Fetches today's opening prices for the underlying indices."""
        for index in self.assets.keys():
            try:
                data = yf.Ticker(index).history(period="1d")
                self.opening_prices[index] = data["Open"].iloc[0] if not data.empty else None
            except Exception as e:
                print(f"Error fetching opening price for {index}: {e}")
                self.opening_prices[index] = None  # Handle missing data safely

    def train_models(self):
        """Trains a Linear Regression model for each ETF based on its underlying index."""
        if self.closing_prices is None:
            print("Error: Closing prices not available. Fetch data first.")
            return
        
        for index, etf in self.assets.items():
            try:
                X = self.closing_prices[index].values.reshape(-1, 1)  # Independent variable (Index closing)
                y = self.closing_prices[etf].values.reshape(-1, 1)  # Dependent variable (ETF closing)
                
                model = LinearRegression()
                model.fit(X, y)  # Train the model
                self.models[etf] = model
            except Exception as e:
                print(f"Error training model for {etf}: {e}")

    def predict_opening_prices(self):
        """Predicts today's opening price for ETFs using the trained regression models."""
        predicted_openings = {}
        for index, etf in self.assets.items():
            if self.opening_prices.get(index) is not None and etf in self.models:
                try:
                    predicted_openings[etf] = self.models[etf].predict(np.array([[self.opening_prices[index]]]))[0][0]
                except Exception as e:
                    print(f"Error predicting opening price for {etf}: {e}")
                    predicted_openings[etf] = None
            else:
                predicted_openings[etf] = "Market Closed or Model Not Available"
        return predicted_openings

class ETFVolumeAnalyzer:
    """Analyzes ETF trading volume and calculates safe volume."""

    def __init__(self, assets, start_date="2025-01-01"):
        self.etf_symbols = list(assets.values())  # ETFs only (excluding indices)
        self.start_date = start_date
        self.end_date = datetime.today().strftime("%Y-%m-%d")
        self.average_volumes = {}
        self.safe_volumes = {}

    def fetch_average_volumes(self):
        """Fetches daily ETF trading volumes and calculates the average volume for each ETF."""
        try:
            volume_data = yf.download(self.etf_symbols, start=self.start_date, end=self.end_date)["Volume"]
            self.average_volumes = volume_data.mean().to_dict()  # Calculate average volume
        except Exception as e:
            print(f"Error fetching ETF volumes: {e}")

    def calculate_safe_volumes(self):
        """Calculates safe volume using the formula: Average Volume / 4500."""
        for etf, avg_volume in self.average_volumes.items():
            self.safe_volumes[etf] = int(avg_volume / 4500)  # Ensure integer output
            # 6.25 hours = 22,500 seconds | 22500/5 = 4500

    def get_safe_volumes(self):
        """Returns the calculated safe volumes."""
        return self.safe_volumes

class ZerodhaLogin:
    """Handles Zerodha Kite login and maintains a session for order placement."""
    
    LOGIN_URL = "https://kite.zerodha.com/api/login"
    TOTP_URL = "https://kite.zerodha.com/api/twofa"

    def __init__(self, username, password, totp_key):
        self.username = username
        self.password = password
        self.totp_key = totp_key
        self.session = requests.Session()
        self.enctoken = None  # Will store the authentication token after login
        self.headers = None  # Store headers after login

    def login(self):
        """Performs login using Zerodha credentials and TOTP authentication."""
        try:
            # Step 1: Submit username & password
            res1 = self.session.post(self.LOGIN_URL, data={
                "user_id": self.username,
                "password": self.password,
                "type": "user_id"
            })
            res1.raise_for_status()  # Raise error for HTTP failures
            loginRes = res1.json()

            if "data" not in loginRes or "request_id" not in loginRes["data"]:
                raise ValueError("Login failed: Invalid response from server")

            # Step 2: Submit TOTP for 2FA authentication
            totp_value = pyotp.TOTP(self.totp_key).now()
            finalRes = self.session.post(self.TOTP_URL, data={
                "request_id": loginRes["data"]["request_id"],
                "twofa_value": totp_value,
                "user_id": loginRes["data"]["user_id"],
                "twofa_type": "totp"
            })
            finalRes.raise_for_status()
            authRes = finalRes.json()

            if "status" not in authRes or authRes["status"] != "success":
                raise ValueError("TOTP Authentication failed")

            # Step 3: Extract encrypted token from cookies
            self.enctoken = self.session.cookies.get_dict().get("enctoken", None)
            if not self.enctoken:
                raise ValueError("Failed to retrieve enctoken")

            print("Login successful!")
            return self.session, self.enctoken

        except requests.exceptions.RequestException as e:
            print(f"HTTP Request Failed: {e}")
        except ValueError as ve:
            print(f"Error: {ve}")

def main():
    """Main execution function"""
    assets = {
        "^NSEI": "NIFTYBEES.NS",      # Nifty 50 → Niftybees
        "^NSMIDCP": "JUNIORBEES.NS",   # Nifty Next 50 → Junior Bees
        "^NSEBANK": "BANKBEES.NS"      # Nifty Bank → Bank Bees
    }

    # Predict ETF opening prices
    predictor = ETFPricePredictor(assets)
    
    print("Fetching historical closing prices...")
    predictor.fetch_closing_prices()

    print("Fetching today's opening prices...")
    predictor.fetch_opening_prices()

    print("Training regression models...")
    predictor.train_models()

    print("\nToday's Opening Prices:")
    for index, price in predictor.opening_prices.items():
        print(f"{index}: {price}")

    print("\nPredicted ETF Opening Prices:")
    predicted_prices = predictor.predict_opening_prices()
    for etf, price in predicted_prices.items():
        print(f"{etf}: {price:.2f}" if isinstance(price, float) else f"{etf}: {price}")

    # Analyze ETF trading volumes
    volume_analyzer = ETFVolumeAnalyzer(assets)
    
    print("\nFetching ETF volume data...")
    volume_analyzer.fetch_average_volumes()

    print("Calculating safe volumes...")
    volume_analyzer.calculate_safe_volumes()

    print("\nAverage ETF Trading Volumes:")
    for etf, avg_volume in volume_analyzer.average_volumes.items():
        print(f"{etf}: {avg_volume:,.0f}")

    print("\nSafe Trading Volumes:")
    safe_volumes = volume_analyzer.get_safe_volumes()
    for etf, safe_vol in safe_volumes.items():
        print(f"{etf}: {safe_vol}")

    # Log in to Zerodha
    zerodha = ZerodhaLogin("DXU151", "Pratibha", "FLJBDJNEBOIMZZZPE25YYYR72Y2B2IAP")
    session, enctoken = zerodha.login()

if __name__ == "__main__":
    main()

# %% [raw]
# import requests
#
# class ZerodhaMargin:
#     """Fetches margin details from Zerodha Kite API using an existing session."""
#
#     MARGIN_URL = "https://kite.zerodha.com/oms/user/margins"
#
#     def __init__(self, session, enctoken, headers):
#         """Initialize with an existing authenticated session and headers."""
#         self.session = session
#         self.enctoken = enctoken
#         self.headers = headers
#
#         if not self.enctoken or not self.headers:
#             raise ValueError("Authentication token or headers are missing. Cannot fetch margin data.")
#
#     def fetch_margin(self):
#         """Fetches margin details and extracts net margin for equity and commodity."""
#         try:
#             response = self.session.get(self.MARGIN_URL, headers=self.headers)
#             response.raise_for_status()
#             data = response.json()
#
#             if "data" not in data or "equity" not in data["data"] or "commodity" not in data["data"]:
#                 raise ValueError("Unexpected response format from Zerodha.")
#
#             # Extract net margin values
#             equity_margin = data["data"]["equity"]["net"]
#             commodity_margin = data["data"]["commodity"]["net"]
#
#             return equity_margin, commodity_margin
#
#         except requests.exceptions.RequestException as e:
#             print(f"HTTP Request Failed: {e}")
#             return None, None
#         except ValueError as ve:
#             print(f"Error: {ve}")
#             return None, None
#
# above code is to fetch margin at zerodha. i dont want any changes in ETFPricePredictor, ETFVolumeAnalyzer, ZerodhaLogin and ZerodhaMargin classes. i want to add ZerodhaLogin class to the selected code. make appropriate modification and changes.

# %%
import yfinance as yf
from datetime import datetime
import numpy as np
import pandas as pd
import requests
import pyotp
from sklearn.linear_model import LinearRegression

class ETFPricePredictor:
    """Predicts ETF opening prices using linear regression based on underlying index data."""

    def __init__(self, assets, start_date="2025-01-01"):
        self.assets = assets
        self.start_date = start_date
        self.end_date = datetime.today().strftime("%Y-%m-%d")
        self.closing_prices = None
        self.opening_prices = {}
        self.models = {}

    def fetch_closing_prices(self):
        """Fetches daily closing prices for underlying indices and ETFs."""
        symbols = list(self.assets.keys()) + list(self.assets.values())  
        try:
            data = yf.download(symbols, start=self.start_date, end=self.end_date)["Close"]
            data.dropna(inplace=True)  
            self.closing_prices = data
        except Exception as e:
            print(f"Error fetching closing prices: {e}")

    def fetch_opening_prices(self):
        """Fetches today's opening prices for the underlying indices."""
        for index in self.assets.keys():
            try:
                data = yf.Ticker(index).history(period="1d")
                self.opening_prices[index] = data["Open"].iloc[0] if not data.empty else None
            except Exception as e:
                print(f"Error fetching opening price for {index}: {e}")
                self.opening_prices[index] = None  

    def train_models(self):
        """Trains a Linear Regression model for each ETF based on its underlying index."""
        if self.closing_prices is None:
            print("Error: Closing prices not available. Fetch data first.")
            return
        
        for index, etf in self.assets.items():
            try:
                X = self.closing_prices[index].values.reshape(-1, 1)  
                y = self.closing_prices[etf].values.reshape(-1, 1)  
                
                model = LinearRegression()
                model.fit(X, y)  
                self.models[etf] = model
            except Exception as e:
                print(f"Error training model for {etf}: {e}")

    def predict_opening_prices(self):
        """Predicts today's opening price for ETFs using the trained regression models."""
        predicted_openings = {}
        for index, etf in self.assets.items():
            if self.opening_prices.get(index) is not None and etf in self.models:
                try:
                    predicted_openings[etf] = self.models[etf].predict(np.array([[self.opening_prices[index]]]))[0][0]
                except Exception as e:
                    print(f"Error predicting opening price for {etf}: {e}")
                    predicted_openings[etf] = None
            else:
                predicted_openings[etf] = "Market Closed or Model Not Available"
        return predicted_openings

class ETFVolumeAnalyzer:
    """Analyzes ETF trading volume and calculates safe volume."""

    def __init__(self, assets, start_date="2025-01-01"):
        self.etf_symbols = list(assets.values())  
        self.start_date = start_date
        self.end_date = datetime.today().strftime("%Y-%m-%d")
        self.average_volumes = {}
        self.safe_volumes = {}

    def fetch_average_volumes(self):
        """Fetches daily ETF trading volumes and calculates the average volume for each ETF."""
        try:
            volume_data = yf.download(self.etf_symbols, start=self.start_date, end=self.end_date)["Volume"]
            self.average_volumes = volume_data.mean().to_dict()  
        except Exception as e:
            print(f"Error fetching ETF volumes: {e}")

    def calculate_safe_volumes(self):
        """Calculates safe volume using the formula: Average Volume / 4500."""
        for etf, avg_volume in self.average_volumes.items():
            self.safe_volumes[etf] = int(avg_volume / 4500)  
            # 6.25 hours = 22,500 seconds | 22500/5 = 4500

    def get_safe_volumes(self):
        """Returns the calculated safe volumes."""
        return self.safe_volumes

class ZerodhaLogin:
    """Handles Zerodha Kite login and maintains a session for order placement."""
    
    LOGIN_URL = "https://kite.zerodha.com/api/login"
    TOTP_URL = "https://kite.zerodha.com/api/twofa"

    def __init__(self, username, password, totp_key):
        self.username = username
        self.password = password
        self.totp_key = totp_key
        self.session = requests.Session()
        self.enctoken = None  
        self.headers = None  

    def login(self):
        """Performs login using Zerodha credentials and TOTP authentication."""
        try:
            res1 = self.session.post(self.LOGIN_URL, data={
                "user_id": self.username,
                "password": self.password,
                "type": "user_id"
            })
            res1.raise_for_status()  
            loginRes = res1.json()

            if "data" not in loginRes or "request_id" not in loginRes["data"]:
                raise ValueError("Login failed: Invalid response from server")

            totp_value = pyotp.TOTP(self.totp_key).now()
            finalRes = self.session.post(self.TOTP_URL, data={
                "request_id": loginRes["data"]["request_id"],
                "twofa_value": totp_value,
                "user_id": loginRes["data"]["user_id"],
                "twofa_type": "totp"
            })
            finalRes.raise_for_status()
            authRes = finalRes.json()

            if "status" not in authRes or authRes["status"] != "success":
                raise ValueError("TOTP Authentication failed")

            self.enctoken = self.session.cookies.get_dict().get("enctoken", None)
            if not self.enctoken:
                raise ValueError("Failed to retrieve enctoken")

            print("Login successful!")
            return self.session, self.enctoken

        except requests.exceptions.RequestException as e:
            print(f"HTTP Request Failed: {e}")
        except ValueError as ve:
            print(f"Error: {ve}")

class ZerodhaMargin:
    """Fetches margin details from Zerodha Kite API using an existing session."""

    MARGIN_URL = "https://kite.zerodha.com/oms/user/margins"

    def __init__(self, session, enctoken, headers):
        """Initialize with an existing authenticated session and headers."""
        self.session = session
        self.enctoken = enctoken
        self.headers = headers

        if not self.enctoken or not self.headers:
            raise ValueError("Authentication token or headers are missing. Cannot fetch margin data.")

    def fetch_margin(self):
        """Fetches margin details and extracts net margin for equity and commodity."""
        try:
            response = self.session.get(self.MARGIN_URL, headers=self.headers)
            response.raise_for_status()
            data = response.json()

            equity_margin = data["data"]["equity"]["net"]
            commodity_margin = data["data"]["commodity"]["net"]

            return equity_margin, commodity_margin

        except requests.exceptions.RequestException as e:
            print(f"HTTP Request Failed: {e}")
            return None, None

def main():
    assets = {
        "^NSEI": "NIFTYBEES.NS",
        "^NSMIDCP": "JUNIORBEES.NS",
        "^NSEBANK": "BANKBEES.NS"
    }

    zerodha = ZerodhaLogin("DXU151", "Pratibha", "FLJBDJNEBOIMZZZPE25YYYR72Y2B2IAP")
    session, enctoken = zerodha.login()

    zerodha_margin = ZerodhaMargin(session, enctoken, {})
    equity_margin, commodity_margin = zerodha_margin.fetch_margin()

if __name__ == "__main__":
    main()

# %% [raw]
# above error

# %%
def main():
    assets = {
        "^NSEI": "NIFTYBEES.NS",
        "^NSMIDCP": "JUNIORBEES.NS",
        "^NSEBANK": "BANKBEES.NS"
    }

    # Log in to Zerodha
    zerodha = ZerodhaLogin("DXU151", "Pratibha", "FLJBDJNEBOIMZZZPE25YYYR72Y2B2IAP")
    session, enctoken = zerodha.login()

    # Ensure successful login before proceeding
    if not enctoken:
        print("Zerodha login failed. Exiting...")
        return  

    # Initialize ZerodhaMargin with correct headers
    headers = {
        "Authorization": f"enctoken {enctoken}",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36",
        "Referer": "https://kite.zerodha.com/dashboard",
        "Accept-Language": "en-US,en;q=0.6",
        "Content-type": "application/x-www-form-urlencoded",
        "Accept": "application/json, text/plain, */*",
    }

    zerodha_margin = ZerodhaMargin(session, enctoken, headers)
    equity_margin, commodity_margin = zerodha_margin.fetch_margin()

    print("\nZerodha Margin Details:")
    print(f"Equity Margin: {equity_margin}")
    print(f"Commodity Margin: {commodity_margin}")

if __name__ == "__main__":
    main()

# %% [raw]
# update code

# %%
import yfinance as yf
from datetime import datetime
import numpy as np
import pandas as pd
import requests
import pyotp
from sklearn.linear_model import LinearRegression

class ETFPricePredictor:
    """Predicts ETF opening prices using linear regression based on underlying index data."""

    def __init__(self, assets, start_date="2025-01-01"):
        self.assets = assets
        self.start_date = start_date
        self.end_date = datetime.today().strftime("%Y-%m-%d")
        self.closing_prices = None
        self.opening_prices = {}
        self.models = {}

    def fetch_closing_prices(self):
        """Fetches daily closing prices for underlying indices and ETFs."""
        symbols = list(self.assets.keys()) + list(self.assets.values())  
        try:
            data = yf.download(symbols, start=self.start_date, end=self.end_date)["Close"]
            data.dropna(inplace=True)  
            self.closing_prices = data
        except Exception as e:
            print(f"Error fetching closing prices: {e}")

    def fetch_opening_prices(self):
        """Fetches today's opening prices for the underlying indices."""
        for index in self.assets.keys():
            try:
                data = yf.Ticker(index).history(period="1d")
                self.opening_prices[index] = data["Open"].iloc[0] if not data.empty else None
            except Exception as e:
                print(f"Error fetching opening price for {index}: {e}")
                self.opening_prices[index] = None  

    def train_models(self):
        """Trains a Linear Regression model for each ETF based on its underlying index."""
        if self.closing_prices is None:
            print("Error: Closing prices not available. Fetch data first.")
            return
        
        for index, etf in self.assets.items():
            try:
                X = self.closing_prices[index].values.reshape(-1, 1)  
                y = self.closing_prices[etf].values.reshape(-1, 1)  
                
                model = LinearRegression()
                model.fit(X, y)  
                self.models[etf] = model
            except Exception as e:
                print(f"Error training model for {etf}: {e}")

    def predict_opening_prices(self):
        """Predicts today's opening price for ETFs using the trained regression models."""
        predicted_openings = {}
        for index, etf in self.assets.items():
            if self.opening_prices.get(index) is not None and etf in self.models:
                try:
                    predicted_openings[etf] = self.models[etf].predict(np.array([[self.opening_prices[index]]]))[0][0]
                except Exception as e:
                    print(f"Error predicting opening price for {etf}: {e}")
                    predicted_openings[etf] = None
            else:
                predicted_openings[etf] = "Market Closed or Model Not Available"
        return predicted_openings

class ETFVolumeAnalyzer:
    """Analyzes ETF trading volume and calculates safe volume."""

    def __init__(self, assets, start_date="2025-01-01"):
        self.etf_symbols = list(assets.values())  
        self.start_date = start_date
        self.end_date = datetime.today().strftime("%Y-%m-%d")
        self.average_volumes = {}
        self.safe_volumes = {}

    def fetch_average_volumes(self):
        """Fetches daily ETF trading volumes and calculates the average volume for each ETF."""
        try:
            volume_data = yf.download(self.etf_symbols, start=self.start_date, end=self.end_date)["Volume"]
            self.average_volumes = volume_data.mean().to_dict()  
        except Exception as e:
            print(f"Error fetching ETF volumes: {e}")

    def calculate_safe_volumes(self):
        """Calculates safe volume using the formula: Average Volume / 4500."""
        for etf, avg_volume in self.average_volumes.items():
            self.safe_volumes[etf] = int(avg_volume / 4500)  
            # 6.25 hours = 22,500 seconds | 22500/5 = 4500

    def get_safe_volumes(self):
        """Returns the calculated safe volumes."""
        return self.safe_volumes

class ZerodhaLogin:
    """Handles Zerodha Kite login and maintains a session for order placement."""
    
    LOGIN_URL = "https://kite.zerodha.com/api/login"
    TOTP_URL = "https://kite.zerodha.com/api/twofa"

    def __init__(self, username, password, totp_key):
        self.username = username
        self.password = password
        self.totp_key = totp_key
        self.session = requests.Session()
        self.enctoken = None  
        self.headers = None  

    def login(self):
        """Performs login using Zerodha credentials and TOTP authentication."""
        try:
            res1 = self.session.post(self.LOGIN_URL, data={
                "user_id": self.username,
                "password": self.password,
                "type": "user_id"
            })
            res1.raise_for_status()  
            loginRes = res1.json()

            if "data" not in loginRes or "request_id" not in loginRes["data"]:
                raise ValueError("Login failed: Invalid response from server")

            totp_value = pyotp.TOTP(self.totp_key).now()
            finalRes = self.session.post(self.TOTP_URL, data={
                "request_id": loginRes["data"]["request_id"],
                "twofa_value": totp_value,
                "user_id": loginRes["data"]["user_id"],
                "twofa_type": "totp"
            })
            finalRes.raise_for_status()
            authRes = finalRes.json()

            if "status" not in authRes or authRes["status"] != "success":
                raise ValueError("TOTP Authentication failed")

            self.enctoken = self.session.cookies.get_dict().get("enctoken", None)
            if not self.enctoken:
                raise ValueError("Failed to retrieve enctoken")

            print("Login successful!")
            return self.session, self.enctoken

        except requests.exceptions.RequestException as e:
            print(f"HTTP Request Failed: {e}")
        except ValueError as ve:
            print(f"Error: {ve}")

class ZerodhaMargin:
    """Fetches margin details from Zerodha Kite API using an existing session."""

    MARGIN_URL = "https://kite.zerodha.com/oms/user/margins"

    def __init__(self, session, enctoken, headers):
        """Initialize with an existing authenticated session and headers."""
        self.session = session
        self.enctoken = enctoken
        self.headers = headers

        if not self.enctoken or not self.headers:
            raise ValueError("Authentication token or headers are missing. Cannot fetch margin data.")

    def fetch_margin(self):
        """Fetches margin details and extracts net margin for equity and commodity."""
        try:
            response = self.session.get(self.MARGIN_URL, headers=self.headers)
            response.raise_for_status()
            data = response.json()

            equity_margin = data["data"]["equity"]["net"]
            commodity_margin = data["data"]["commodity"]["net"]

            return equity_margin, commodity_margin

        except requests.exceptions.RequestException as e:
            print(f"HTTP Request Failed: {e}")
            return None, None

def main():
    """Main execution function"""
    assets = {
        "^NSEI": "NIFTYBEES.NS",      # Nifty 50 → Niftybees
        "^NSMIDCP": "JUNIORBEES.NS",   # Nifty Next 50 → Junior Bees
        "^NSEBANK": "BANKBEES.NS"      # Nifty Bank → Bank Bees
    }

    # Predict ETF opening prices
    predictor = ETFPricePredictor(assets)
    
    print("Fetching historical closing prices...")
    predictor.fetch_closing_prices()

    print("Fetching today's opening prices...")
    predictor.fetch_opening_prices()

    print("Training regression models...")
    predictor.train_models()

    print("\nToday's Opening Prices:")
    for index, price in predictor.opening_prices.items():
        print(f"{index}: {price}")

    print("\nPredicted ETF Opening Prices:")
    predicted_prices = predictor.predict_opening_prices()
    for etf, price in predicted_prices.items():
        print(f"{etf}: {price:.2f}" if isinstance(price, float) else f"{etf}: {price}")

    # Analyze ETF trading volumes
    volume_analyzer = ETFVolumeAnalyzer(assets)
    
    print("\nFetching ETF volume data...")
    volume_analyzer.fetch_average_volumes()

    print("Calculating safe volumes...")
    volume_analyzer.calculate_safe_volumes()

    print("\nAverage ETF Trading Volumes:")
    for etf, avg_volume in volume_analyzer.average_volumes.items():
        print(f"{etf}: {avg_volume:,.0f}")

    print("\nSafe Trading Volumes:")
    safe_volumes = volume_analyzer.get_safe_volumes()
    for etf, safe_vol in safe_volumes.items():
        print(f"{etf}: {safe_vol}")

    # Log in to Zerodha
    zerodha = ZerodhaLogin("DXU151", "Pratibha", "FLJBDJNEBOIMZZZPE25YYYR72Y2B2IAP")
    session, enctoken = zerodha.login()

    # Ensure successful login before proceeding
    if not enctoken:
        print("Zerodha login failed. Exiting...")
        return  

    # Initialize ZerodhaMargin with correct headers
    headers = {
        "Authorization": f"enctoken {enctoken}",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36",
        "Referer": "https://kite.zerodha.com/dashboard",
        "Accept-Language": "en-US,en;q=0.6",
        "Content-type": "application/x-www-form-urlencoded",
        "Accept": "application/json, text/plain, */*",
    }

    zerodha_margin = ZerodhaMargin(session, enctoken, headers)
    equity_margin, commodity_margin = zerodha_margin.fetch_margin()

    print("\nZerodha Margin Details:")
    print(f"Equity Margin: {equity_margin}")
    print(f"Commodity Margin: {commodity_margin}")

if __name__ == "__main__":
    main()

# %% [raw]
# import time
# from datetime import datetime, timedelta
#
# def calculate_current_datetime_hh_mm_ss_ms():
#     return datetime.now()
#
# def calculate_current_datetime_hh_mm_ss():
#     current_time = datetime.now()
#     return current_time.strftime("%H:%M:%S")
#
# def print_current_datetime_hh_mm_ss_ms():
#     current_time = calculate_current_datetime_hh_mm_ss_ms()
#     print(current_time.strftime("%H:%M:%S.%f"))
#
# def print_current_datetime_hh_mm_ss():
#     formatted_time = calculate_current_datetime_hh_mm_ss()
#     print(formatted_time)
#
# def execute_at_precise_time(target_time, func):
#
#     delay = (target_time - datetime.now()).total_seconds()
#
#     time.sleep(max(0, delay - 0.1))
#
#     while datetime.now() < target_time:
#         pass
#
#     func()
#
# above is the code of time related functions. create class time utils and add above code in it.

# %%
import time
from datetime import datetime, timedelta

class TimeUtils:
    """Utility class for time-related functions."""
    
    @staticmethod
    def get_current_datetime_hh_mm_ss_ms():
        """Returns the current datetime with milliseconds."""
        return datetime.now()

    @staticmethod
    def get_current_datetime_hh_mm_ss():
        """Returns the current time in HH:MM:SS format."""
        return datetime.now().strftime("%H:%M:%S")

    @staticmethod
    def print_current_datetime_hh_mm_ss_ms():
        """Prints the current datetime with milliseconds."""
        print(TimeUtils.get_current_datetime_hh_mm_ss_ms().strftime("%H:%M:%S.%f"))

    @staticmethod
    def print_current_datetime_hh_mm_ss():
        """Prints the current time in HH:MM:SS format."""
        print(TimeUtils.get_current_datetime_hh_mm_ss())

    @staticmethod
    def execute_at_precise_time(target_time, func):
        """
        Executes a given function at a precise target time.

        :param target_time: Datetime object specifying the execution time.
        :param func: Function to execute.
        """
        delay = (target_time - datetime.now()).total_seconds()
        
        # Sleep until just before the target time
        time.sleep(max(0, delay - 0.1))
        
        # Busy-wait until the exact moment
        while datetime.now() < target_time:
            pass

        func()

# Example Usage
# TimeUtils.print_current_datetime_hh_mm_ss()
# TimeUtils.execute_at_precise_time(datetime.now() + timedelta(seconds=5), lambda: print("Executed!"))

# %% [raw]
# manual update

# %%
import yfinance as yf
from datetime import datetime
import numpy as np
import pandas as pd
import requests
import pyotp
from sklearn.linear_model import LinearRegression

import time
from datetime import datetime, timedelta

class TimeUtils:
    """Utility class for time-related functions."""
    
    @staticmethod
    def get_current_datetime_hh_mm_ss_ms():
        """Returns the current datetime with milliseconds."""
        return datetime.now()

    @staticmethod
    def get_current_datetime_hh_mm_ss():
        """Returns the current time in HH:MM:SS format."""
        return datetime.now().strftime("%H:%M:%S")

    @staticmethod
    def print_current_datetime_hh_mm_ss_ms():
        """Prints the current datetime with milliseconds."""
        print(TimeUtils.get_current_datetime_hh_mm_ss_ms().strftime("%H:%M:%S.%f"))

    @staticmethod
    def print_current_datetime_hh_mm_ss():
        """Prints the current time in HH:MM:SS format."""
        print(TimeUtils.get_current_datetime_hh_mm_ss())

    @staticmethod
    def execute_at_precise_time(target_time, func):
        """
        Executes a given function at a precise target time.

        :param target_time: Datetime object specifying the execution time.
        :param func: Function to execute.
        """
        delay = (target_time - datetime.now()).total_seconds()
        
        # Sleep until just before the target time
        time.sleep(max(0, delay - 0.1))
        
        # Busy-wait until the exact moment
        while datetime.now() < target_time:
            pass

        func()

class ETFPricePredictor:
    """Predicts ETF opening prices using linear regression based on underlying index data."""

    def __init__(self, assets, start_date="2025-01-01"):
        self.assets = assets
        self.start_date = start_date
        self.end_date = datetime.today().strftime("%Y-%m-%d")
        self.closing_prices = None
        self.opening_prices = {}
        self.models = {}

    def fetch_closing_prices(self):
        """Fetches daily closing prices for underlying indices and ETFs."""
        symbols = list(self.assets.keys()) + list(self.assets.values())  
        try:
            data = yf.download(symbols, start=self.start_date, end=self.end_date)["Close"]
            data.dropna(inplace=True)  
            self.closing_prices = data
        except Exception as e:
            print(f"Error fetching closing prices: {e}")

    def fetch_opening_prices(self):
        """Fetches today's opening prices for the underlying indices."""
        for index in self.assets.keys():
            try:
                data = yf.Ticker(index).history(period="1d")
                self.opening_prices[index] = data["Open"].iloc[0] if not data.empty else None
            except Exception as e:
                print(f"Error fetching opening price for {index}: {e}")
                self.opening_prices[index] = None  

    def train_models(self):
        """Trains a Linear Regression model for each ETF based on its underlying index."""
        if self.closing_prices is None:
            print("Error: Closing prices not available. Fetch data first.")
            return
        
        for index, etf in self.assets.items():
            try:
                X = self.closing_prices[index].values.reshape(-1, 1)  
                y = self.closing_prices[etf].values.reshape(-1, 1)  
                
                model = LinearRegression()
                model.fit(X, y)  
                self.models[etf] = model
            except Exception as e:
                print(f"Error training model for {etf}: {e}")

    def predict_opening_prices(self):
        """Predicts today's opening price for ETFs using the trained regression models."""
        predicted_openings = {}
        for index, etf in self.assets.items():
            if self.opening_prices.get(index) is not None and etf in self.models:
                try:
                    predicted_openings[etf] = self.models[etf].predict(np.array([[self.opening_prices[index]]]))[0][0]
                except Exception as e:
                    print(f"Error predicting opening price for {etf}: {e}")
                    predicted_openings[etf] = None
            else:
                predicted_openings[etf] = "Market Closed or Model Not Available"
        return predicted_openings

class ETFVolumeAnalyzer:
    """Analyzes ETF trading volume and calculates safe volume."""

    def __init__(self, assets, start_date="2025-01-01"):
        self.etf_symbols = list(assets.values())  
        self.start_date = start_date
        self.end_date = datetime.today().strftime("%Y-%m-%d")
        self.average_volumes = {}
        self.safe_volumes = {}

    def fetch_average_volumes(self):
        """Fetches daily ETF trading volumes and calculates the average volume for each ETF."""
        try:
            volume_data = yf.download(self.etf_symbols, start=self.start_date, end=self.end_date)["Volume"]
            self.average_volumes = volume_data.mean().to_dict()  
        except Exception as e:
            print(f"Error fetching ETF volumes: {e}")

    def calculate_safe_volumes(self):
        """Calculates safe volume using the formula: Average Volume / 4500."""
        for etf, avg_volume in self.average_volumes.items():
            self.safe_volumes[etf] = int(avg_volume / 4500)  
            # 6.25 hours = 22,500 seconds | 22500/5 = 4500

    def get_safe_volumes(self):
        """Returns the calculated safe volumes."""
        return self.safe_volumes

class ZerodhaLogin:
    """Handles Zerodha Kite login and maintains a session for order placement."""
    
    LOGIN_URL = "https://kite.zerodha.com/api/login"
    TOTP_URL = "https://kite.zerodha.com/api/twofa"

    def __init__(self, username, password, totp_key):
        self.username = username
        self.password = password
        self.totp_key = totp_key
        self.session = requests.Session()
        self.enctoken = None  
        self.headers = None  

    def login(self):
        """Performs login using Zerodha credentials and TOTP authentication."""
        try:
            res1 = self.session.post(self.LOGIN_URL, data={
                "user_id": self.username,
                "password": self.password,
                "type": "user_id"
            })
            res1.raise_for_status()  
            loginRes = res1.json()

            if "data" not in loginRes or "request_id" not in loginRes["data"]:
                raise ValueError("Login failed: Invalid response from server")

            totp_value = pyotp.TOTP(self.totp_key).now()
            finalRes = self.session.post(self.TOTP_URL, data={
                "request_id": loginRes["data"]["request_id"],
                "twofa_value": totp_value,
                "user_id": loginRes["data"]["user_id"],
                "twofa_type": "totp"
            })
            finalRes.raise_for_status()
            authRes = finalRes.json()

            if "status" not in authRes or authRes["status"] != "success":
                raise ValueError("TOTP Authentication failed")

            self.enctoken = self.session.cookies.get_dict().get("enctoken", None)
            if not self.enctoken:
                raise ValueError("Failed to retrieve enctoken")

            print("Login successful!")
            return self.session, self.enctoken

        except requests.exceptions.RequestException as e:
            print(f"HTTP Request Failed: {e}")
        except ValueError as ve:
            print(f"Error: {ve}")

class ZerodhaMargin:
    """Fetches margin details from Zerodha Kite API using an existing session."""

    MARGIN_URL = "https://kite.zerodha.com/oms/user/margins"

    def __init__(self, session, enctoken, headers):
        """Initialize with an existing authenticated session and headers."""
        self.session = session
        self.enctoken = enctoken
        self.headers = headers

        if not self.enctoken or not self.headers:
            raise ValueError("Authentication token or headers are missing. Cannot fetch margin data.")

    def fetch_margin(self):
        """Fetches margin details and extracts net margin for equity and commodity."""
        try:
            response = self.session.get(self.MARGIN_URL, headers=self.headers)
            response.raise_for_status()
            data = response.json()

            equity_margin = data["data"]["equity"]["net"]
            commodity_margin = data["data"]["commodity"]["net"]

            return equity_margin, commodity_margin

        except requests.exceptions.RequestException as e:
            print(f"HTTP Request Failed: {e}")
            return None, None

def main():
    """Main execution function"""
    assets = {
        "^NSEI": "NIFTYBEES.NS",      # Nifty 50 → Niftybees
        "^NSMIDCP": "JUNIORBEES.NS",   # Nifty Next 50 → Junior Bees
        "^NSEBANK": "BANKBEES.NS"      # Nifty Bank → Bank Bees
    }

    # Predict ETF opening prices
    predictor = ETFPricePredictor(assets)
    
    print("Fetching historical closing prices...")
    predictor.fetch_closing_prices()

    print("Fetching today's opening prices...")
    predictor.fetch_opening_prices()

    print("Training regression models...")
    predictor.train_models()

    print("\nToday's Opening Prices:")
    for index, price in predictor.opening_prices.items():
        print(f"{index}: {price}")

    print("\nPredicted ETF Opening Prices:")
    predicted_prices = predictor.predict_opening_prices()
    for etf, price in predicted_prices.items():
        print(f"{etf}: {price:.2f}" if isinstance(price, float) else f"{etf}: {price}")

    # Analyze ETF trading volumes
    volume_analyzer = ETFVolumeAnalyzer(assets)
    
    print("\nFetching ETF volume data...")
    volume_analyzer.fetch_average_volumes()

    print("Calculating safe volumes...")
    volume_analyzer.calculate_safe_volumes()

    print("\nAverage ETF Trading Volumes:")
    for etf, avg_volume in volume_analyzer.average_volumes.items():
        print(f"{etf}: {avg_volume:,.0f}")

    print("\nSafe Trading Volumes:")
    safe_volumes = volume_analyzer.get_safe_volumes()
    for etf, safe_vol in safe_volumes.items():
        print(f"{etf}: {safe_vol}")

    # Log in to Zerodha
    zerodha = ZerodhaLogin("DXU151", "Pratibha", "FLJBDJNEBOIMZZZPE25YYYR72Y2B2IAP")
    session, enctoken = zerodha.login()

    # Ensure successful login before proceeding
    if not enctoken:
        print("Zerodha login failed. Exiting...")
        return  

    # Initialize ZerodhaMargin with correct headers
    headers = {
        "Authorization": f"enctoken {enctoken}",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36",
        "Referer": "https://kite.zerodha.com/dashboard",
        "Accept-Language": "en-US,en;q=0.6",
        "Content-type": "application/x-www-form-urlencoded",
        "Accept": "application/json, text/plain, */*",
    }

    zerodha_margin = ZerodhaMargin(session, enctoken, headers)
    equity_margin, commodity_margin = zerodha_margin.fetch_margin()

    print("\nZerodha Margin Details:")
    print(f"Equity Margin: {equity_margin}")
    print(f"Commodity Margin: {commodity_margin}")

if __name__ == "__main__":
    main()

# %%
import yfinance as yf
from datetime import datetime
import numpy as np
import pandas as pd
import requests
import pyotp
from sklearn.linear_model import LinearRegression

import time
from datetime import datetime, timedelta

class TimeUtils:
    """Utility class for time-related functions."""
    
    @staticmethod
    def get_current_datetime_hh_mm_ss_ms():
        """Returns the current datetime with milliseconds."""
        return datetime.now()

    @staticmethod
    def get_current_datetime_hh_mm_ss():
        """Returns the current time in HH:MM:SS format."""
        return datetime.now().strftime("%H:%M:%S")

    @staticmethod
    def print_current_datetime_hh_mm_ss_ms():
        """Prints the current datetime with milliseconds."""
        print(TimeUtils.get_current_datetime_hh_mm_ss_ms().strftime("%H:%M:%S.%f"))

    @staticmethod
    def print_current_datetime_hh_mm_ss():
        """Prints the current time in HH:MM:SS format."""
        print(TimeUtils.get_current_datetime_hh_mm_ss())

    @staticmethod
    def execute_at_precise_time(target_time, func):
        """
        Executes a given function at a precise target time.

        :param target_time: Datetime object specifying the execution time.
        :param func: Function to execute.
        """
        delay = (target_time - datetime.now()).total_seconds()
        
        # Sleep until just before the target time
        time.sleep(max(0, delay - 0.1))
        
        # Busy-wait until the exact moment
        while datetime.now() < target_time:
            pass

        func()

class ETFPricePredictor:
    """Predicts ETF opening prices using linear regression based on underlying index data."""

    def __init__(self, assets, start_date="2025-01-01"):
        self.assets = assets
        self.start_date = start_date
        self.end_date = datetime.today().strftime("%Y-%m-%d")
        self.closing_prices = None
        self.opening_prices = {}
        self.models = {}

    def fetch_closing_prices(self):
        """Fetches daily closing prices for underlying indices and ETFs."""
        symbols = list(self.assets.keys()) + list(self.assets.values())  
        try:
            data = yf.download(symbols, start=self.start_date, end=self.end_date)["Close"]
            data.dropna(inplace=True)  
            self.closing_prices = data
        except Exception as e:
            print(f"Error fetching closing prices: {e}")

    def fetch_opening_prices(self):
        """Fetches today's opening prices for the underlying indices."""
        for index in self.assets.keys():
            try:
                data = yf.Ticker(index).history(period="1d")
                self.opening_prices[index] = data["Open"].iloc[0] if not data.empty else None
            except Exception as e:
                print(f"Error fetching opening price for {index}: {e}")
                self.opening_prices[index] = None  

    def train_models(self):
        """Trains a Linear Regression model for each ETF based on its underlying index."""
        if self.closing_prices is None:
            print("Error: Closing prices not available. Fetch data first.")
            return
        
        for index, etf in self.assets.items():
            try:
                X = self.closing_prices[index].values.reshape(-1, 1)  
                y = self.closing_prices[etf].values.reshape(-1, 1)  
                
                model = LinearRegression()
                model.fit(X, y)  
                self.models[etf] = model
            except Exception as e:
                print(f"Error training model for {etf}: {e}")

    def predict_opening_prices(self):
        """Predicts today's opening price for ETFs using the trained regression models."""
        predicted_openings = {}
        for index, etf in self.assets.items():
            if self.opening_prices.get(index) is not None and etf in self.models:
                try:
                    predicted_openings[etf] = self.models[etf].predict(np.array([[self.opening_prices[index]]]))[0][0]
                except Exception as e:
                    print(f"Error predicting opening price for {etf}: {e}")
                    predicted_openings[etf] = None
            else:
                predicted_openings[etf] = "Market Closed or Model Not Available"
        return predicted_openings

class ETFVolumeAnalyzer:
    """Analyzes ETF trading volume and calculates safe volume."""

    def __init__(self, assets, start_date="2025-01-01"):
        self.etf_symbols = list(assets.values())  
        self.start_date = start_date
        self.end_date = datetime.today().strftime("%Y-%m-%d")
        self.average_volumes = {}
        self.safe_volumes = {}

    def fetch_average_volumes(self):
        """Fetches daily ETF trading volumes and calculates the average volume for each ETF."""
        try:
            volume_data = yf.download(self.etf_symbols, start=self.start_date, end=self.end_date)["Volume"]
            self.average_volumes = volume_data.mean().to_dict()  
        except Exception as e:
            print(f"Error fetching ETF volumes: {e}")

    def calculate_safe_volumes(self):
        """Calculates safe volume using the formula: Average Volume / 4500."""
        for etf, avg_volume in self.average_volumes.items():
            self.safe_volumes[etf] = int(avg_volume / 4500)  
            # 6.25 hours = 22,500 seconds | 22500/5 = 4500

    def get_safe_volumes(self):
        """Returns the calculated safe volumes."""
        return self.safe_volumes

class ZerodhaLogin:
    """Handles Zerodha Kite login and maintains a session for order placement."""
    
    LOGIN_URL = "https://kite.zerodha.com/api/login"
    TOTP_URL = "https://kite.zerodha.com/api/twofa"

    def __init__(self, username, password, totp_key):
        self.username = username
        self.password = password
        self.totp_key = totp_key
        self.session = requests.Session()
        self.enctoken = None  
        self.headers = None  

    def login(self):
        """Performs login using Zerodha credentials and TOTP authentication."""
        try:
            res1 = self.session.post(self.LOGIN_URL, data={
                "user_id": self.username,
                "password": self.password,
                "type": "user_id"
            })
            res1.raise_for_status()  
            loginRes = res1.json()

            if "data" not in loginRes or "request_id" not in loginRes["data"]:
                raise ValueError("Login failed: Invalid response from server")

            totp_value = pyotp.TOTP(self.totp_key).now()
            finalRes = self.session.post(self.TOTP_URL, data={
                "request_id": loginRes["data"]["request_id"],
                "twofa_value": totp_value,
                "user_id": loginRes["data"]["user_id"],
                "twofa_type": "totp"
            })
            finalRes.raise_for_status()
            authRes = finalRes.json()

            if "status" not in authRes or authRes["status"] != "success":
                raise ValueError("TOTP Authentication failed")

            self.enctoken = self.session.cookies.get_dict().get("enctoken", None)
            if not self.enctoken:
                raise ValueError("Failed to retrieve enctoken")

            print("Login successful!")
            return self.session, self.enctoken

        except requests.exceptions.RequestException as e:
            print(f"HTTP Request Failed: {e}")
        except ValueError as ve:
            print(f"Error: {ve}")

class ZerodhaMargin:
    """Fetches margin details from Zerodha Kite API using an existing session."""

    MARGIN_URL = "https://kite.zerodha.com/oms/user/margins"

    def __init__(self, session, enctoken, headers):
        """Initialize with an existing authenticated session and headers."""
        self.session = session
        self.enctoken = enctoken
        self.headers = headers

        if not self.enctoken or not self.headers:
            raise ValueError("Authentication token or headers are missing. Cannot fetch margin data.")

    def fetch_margin(self):
        """Fetches margin details and extracts net margin for equity and commodity."""
        try:
            response = self.session.get(self.MARGIN_URL, headers=self.headers)
            response.raise_for_status()
            data = response.json()

            equity_margin = data["data"]["equity"]["net"]
            commodity_margin = data["data"]["commodity"]["net"]

            return equity_margin, commodity_margin

        except requests.exceptions.RequestException as e:
            print(f"HTTP Request Failed: {e}")
            return None, None

def main():
    """Main execution function"""
    assets = {
        "^NSEI": "NIFTYBEES.NS",      # Nifty 50 → Niftybees
        "^NSMIDCP": "JUNIORBEES.NS",   # Nifty Next 50 → Junior Bees
        "^NSEBANK": "BANKBEES.NS"      # Nifty Bank → Bank Bees
    }

    # Predict ETF opening prices
    predictor = ETFPricePredictor(assets)
    
    print("Fetching historical closing prices...")
    predictor.fetch_closing_prices()

    print("Fetching today's opening prices...")
    predictor.fetch_opening_prices()

    print("Training regression models...")
    predictor.train_models()

    print("\nToday's Opening Prices:")
    for index, price in predictor.opening_prices.items():
        print(f"{index}: {price}")

    print("\nPredicted ETF Opening Prices:")
    predicted_prices = predictor.predict_opening_prices()
    for etf, price in predicted_prices.items():
        print(f"{etf}: {price:.2f}" if isinstance(price, float) else f"{etf}: {price}")

    # Analyze ETF trading volumes
    volume_analyzer = ETFVolumeAnalyzer(assets)
    
    print("\nFetching ETF volume data...")
    volume_analyzer.fetch_average_volumes()

    print("Calculating safe volumes...")
    volume_analyzer.calculate_safe_volumes()

    print("\nAverage ETF Trading Volumes:")
    for etf, avg_volume in volume_analyzer.average_volumes.items():
        print(f"{etf}: {avg_volume:,.0f}")

    print("\nSafe Trading Volumes:")
    safe_volumes = volume_analyzer.get_safe_volumes()
    for etf, safe_vol in safe_volumes.items():
        print(f"{etf}: {safe_vol}")

    # Log in to Zerodha
    zerodha = ZerodhaLogin("DXU151", "Pratibha", "FLJBDJNEBOIMZZZPE25YYYR72Y2B2IAP")
    session, enctoken = zerodha.login()

    # Ensure successful login before proceeding
    if not enctoken:
        print("Zerodha login failed. Exiting...")
        return  

    # Initialize ZerodhaMargin with correct headers
    headers = {
        "Authorization": f"enctoken {enctoken}",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36",
        "Referer": "https://kite.zerodha.com/dashboard",
        "Accept-Language": "en-US,en;q=0.6",
        "Content-type": "application/x-www-form-urlencoded",
        "Accept": "application/json, text/plain, */*",
    }

    zerodha_margin = ZerodhaMargin(session, enctoken, headers)
    equity_margin, commodity_margin = zerodha_margin.fetch_margin()

    print("\nZerodha Margin Details:")
    print(f"Equity Margin: {equity_margin}")
    print(f"Commodity Margin: {commodity_margin}")

if __name__ == "__main__":
    main()

# %%
import yfinance as yf
from datetime import datetime
import numpy as np
import pandas as pd
import requests
import pyotp
from sklearn.linear_model import LinearRegression

import time
from datetime import datetime, timedelta

class TimeUtils:
    """Utility class for time-related functions."""
    
    @staticmethod
    def get_current_datetime_hh_mm_ss_ms():
        """Returns the current datetime with milliseconds."""
        return datetime.now()

    @staticmethod
    def get_current_datetime_hh_mm_ss():
        """Returns the current time in HH:MM:SS format."""
        return datetime.now().strftime("%H:%M:%S")

    @staticmethod
    def print_current_datetime_hh_mm_ss_ms():
        """Prints the current datetime with milliseconds."""
        print(TimeUtils.get_current_datetime_hh_mm_ss_ms().strftime("%H:%M:%S.%f"))

    @staticmethod
    def print_current_datetime_hh_mm_ss():
        """Prints the current time in HH:MM:SS format."""
        print(TimeUtils.get_current_datetime_hh_mm_ss())

    @staticmethod
    def execute_at_precise_time(target_time, func):
        """
        Executes a given function at a precise target time.

        :param target_time: Datetime object specifying the execution time.
        :param func: Function to execute.
        """
        delay = (target_time - datetime.now()).total_seconds()
        
        # Sleep until just before the target time
        time.sleep(max(0, delay - 0.1))
        
        # Busy-wait until the exact moment
        while datetime.now() < target_time:
            pass

        func()

class ETFPricePredictor:
    """Predicts ETF opening prices using linear regression based on underlying index data."""

    def __init__(self, assets, start_date="2025-01-01"):
        self.assets = assets
        self.start_date = start_date
        self.end_date = datetime.today().strftime("%Y-%m-%d")
        self.closing_prices = None
        self.opening_prices = {}
        self.models = {}

    def fetch_closing_prices(self):
        """Fetches daily closing prices for underlying indices and ETFs."""
        symbols = list(self.assets.keys()) + list(self.assets.values())  
        try:
            data = yf.download(symbols, start=self.start_date, end=self.end_date)["Close"]
            data.dropna(inplace=True)  
            self.closing_prices = data
        except Exception as e:
            print(f"Error fetching closing prices: {e}")

    def fetch_opening_prices(self):
        """Fetches today's opening prices for the underlying indices."""
        for index in self.assets.keys():
            try:
                data = yf.Ticker(index).history(period="1d")
                self.opening_prices[index] = data["Open"].iloc[0] if not data.empty else None
            except Exception as e:
                print(f"Error fetching opening price for {index}: {e}")
                self.opening_prices[index] = None  

    def train_models(self):
        """Trains a Linear Regression model for each ETF based on its underlying index."""
        if self.closing_prices is None:
            print("Error: Closing prices not available. Fetch data first.")
            return
        
        for index, etf in self.assets.items():
            try:
                X = self.closing_prices[index].values.reshape(-1, 1)  
                y = self.closing_prices[etf].values.reshape(-1, 1)  
                
                model = LinearRegression()
                model.fit(X, y)  
                self.models[etf] = model
            except Exception as e:
                print(f"Error training model for {etf}: {e}")

    def predict_opening_prices(self):
        """Predicts today's opening price for ETFs using the trained regression models."""
        predicted_openings = {}
        for index, etf in self.assets.items():
            if self.opening_prices.get(index) is not None and etf in self.models:
                try:
                    predicted_openings[etf] = self.models[etf].predict(np.array([[self.opening_prices[index]]]))[0][0]
                except Exception as e:
                    print(f"Error predicting opening price for {etf}: {e}")
                    predicted_openings[etf] = None
            else:
                predicted_openings[etf] = "Market Closed or Model Not Available"
        return predicted_openings

class ETFVolumeAnalyzer:
    """Analyzes ETF trading volume and calculates safe volume."""

    def __init__(self, assets, start_date="2025-01-01"):
        self.etf_symbols = list(assets.values())  
        self.start_date = start_date
        self.end_date = datetime.today().strftime("%Y-%m-%d")
        self.average_volumes = {}
        self.safe_volumes = {}

    def fetch_average_volumes(self):
        """Fetches daily ETF trading volumes and calculates the average volume for each ETF."""
        try:
            volume_data = yf.download(self.etf_symbols, start=self.start_date, end=self.end_date)["Volume"]
            self.average_volumes = volume_data.mean().to_dict()  
        except Exception as e:
            print(f"Error fetching ETF volumes: {e}")

    def calculate_safe_volumes(self):
        """Calculates safe volume using the formula: Average Volume / 4500."""
        for etf, avg_volume in self.average_volumes.items():
            self.safe_volumes[etf] = int(avg_volume / 4500)  
            # 6.25 hours = 22,500 seconds | 22500/5 = 4500

    def get_safe_volumes(self):
        """Returns the calculated safe volumes."""
        return self.safe_volumes

class ZerodhaLogin:
    """Handles Zerodha Kite login and maintains a session for order placement."""
    
    LOGIN_URL = "https://kite.zerodha.com/api/login"
    TOTP_URL = "https://kite.zerodha.com/api/twofa"

    def __init__(self, username, password, totp_key):
        self.username = username
        self.password = password
        self.totp_key = totp_key
        self.session = requests.Session()
        self.enctoken = None  
        self.headers = None  

    def login(self):
        """Performs login using Zerodha credentials and TOTP authentication."""
        try:
            res1 = self.session.post(self.LOGIN_URL, data={
                "user_id": self.username,
                "password": self.password,
                "type": "user_id"
            })
            res1.raise_for_status()  
            loginRes = res1.json()

            if "data" not in loginRes or "request_id" not in loginRes["data"]:
                raise ValueError("Login failed: Invalid response from server")

            totp_value = pyotp.TOTP(self.totp_key).now()
            finalRes = self.session.post(self.TOTP_URL, data={
                "request_id": loginRes["data"]["request_id"],
                "twofa_value": totp_value,
                "user_id": loginRes["data"]["user_id"],
                "twofa_type": "totp"
            })
            finalRes.raise_for_status()
            authRes = finalRes.json()

            if "status" not in authRes or authRes["status"] != "success":
                raise ValueError("TOTP Authentication failed")

            self.enctoken = self.session.cookies.get_dict().get("enctoken", None)
            if not self.enctoken:
                raise ValueError("Failed to retrieve enctoken")

            print("Login successful!")
            return self.session, self.enctoken

        except requests.exceptions.RequestException as e:
            print(f"HTTP Request Failed: {e}")
        except ValueError as ve:
            print(f"Error: {ve}")

class ZerodhaMargin:
    """Fetches margin details from Zerodha Kite API using an existing session."""

    MARGIN_URL = "https://kite.zerodha.com/oms/user/margins"

    def __init__(self, session, enctoken, headers):
        """Initialize with an existing authenticated session and headers."""
        self.session = session
        self.enctoken = enctoken
        self.headers = headers

        if not self.enctoken or not self.headers:
            raise ValueError("Authentication token or headers are missing. Cannot fetch margin data.")

    def fetch_margin(self):
        """Fetches margin details and extracts net margin for equity and commodity."""
        try:
            response = self.session.get(self.MARGIN_URL, headers=self.headers)
            response.raise_for_status()
            data = response.json()

            equity_margin = data["data"]["equity"]["net"]
            commodity_margin = data["data"]["commodity"]["net"]

            return equity_margin, commodity_margin

        except requests.exceptions.RequestException as e:
            print(f"HTTP Request Failed: {e}")
            return None, None

def main():
    """Main execution function"""
    assets = {
        "^NSEI": "NIFTYBEES.NS",      # Nifty 50 → Niftybees
        "^NSMIDCP": "JUNIORBEES.NS",   # Nifty Next 50 → Junior Bees
        "^NSEBANK": "BANKBEES.NS"      # Nifty Bank → Bank Bees
    }

    # Predict ETF opening prices
    predictor = ETFPricePredictor(assets)
    
    print("Fetching historical closing prices...")
    predictor.fetch_closing_prices()

    print("Fetching today's opening prices...")
    predictor.fetch_opening_prices()

    print("Training regression models...")
    predictor.train_models()

    print("\nToday's Opening Prices:")
    for index, price in predictor.opening_prices.items():
        print(f"{index}: {price}")

    print("\nPredicted ETF Opening Prices:")
    predicted_prices = predictor.predict_opening_prices()
    for etf, price in predicted_prices.items():
        print(f"{etf}: {price:.2f}" if isinstance(price, float) else f"{etf}: {price}")

    # Analyze ETF trading volumes
    volume_analyzer = ETFVolumeAnalyzer(assets)
    
    print("\nFetching ETF volume data...")
    volume_analyzer.fetch_average_volumes()

    print("Calculating safe volumes...")
    volume_analyzer.calculate_safe_volumes()

    print("\nAverage ETF Trading Volumes:")
    for etf, avg_volume in volume_analyzer.average_volumes.items():
        print(f"{etf}: {avg_volume:,.0f}")

    print("\nSafe Trading Volumes:")
    safe_volumes = volume_analyzer.get_safe_volumes()
    for etf, safe_vol in safe_volumes.items():
        print(f"{etf}: {safe_vol}")

    # Log in to Zerodha
    zerodha = ZerodhaLogin("DXU151", "Pratibha", "FLJBDJNEBOIMZZZPE25YYYR72Y2B2IAP")
    session, enctoken = zerodha.login()

    # Ensure successful login before proceeding
    if not enctoken:
        print("Zerodha login failed. Exiting...")
        return  

    # Initialize ZerodhaMargin with correct headers
    headers = {
        "Authorization": f"enctoken {enctoken}",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36",
        "Referer": "https://kite.zerodha.com/dashboard",
        "Accept-Language": "en-US,en;q=0.6",
        "Content-type": "application/x-www-form-urlencoded",
        "Accept": "application/json, text/plain, */*",
    }

    zerodha_margin = ZerodhaMargin(session, enctoken, headers)
    equity_margin, commodity_margin = zerodha_margin.fetch_margin()

    print("\nZerodha Margin Details:")
    print(f"Equity Margin: {equity_margin}")
    print(f"Commodity Margin: {commodity_margin}")

if __name__ == "__main__":
    main()

# %% [raw]
# step 1: calculate leveraged_margin = equity_margin * 5
# step 2: calculate trade_value = predicted_openings * safe_volumes (for each etf)
# step 3: calculate total_trade_value = sum of all the trade_value (sum of trade_value of all the etfs)
# step 4: calculate allocation_ratio = leveraged_margin / total_trade_value
# step 5: adjusted_quantity = allocation_ratio * safe_volumes
#
# create a python class by name VolumeCalculation and write code for above functionality and append in the below code. make only necessary changes in the existing classes of below code. it is going to get equity_margin from ZerodhaMargin class, predicted_openings from ETFPricePredictor, safe_volume from ETFVolumeAnalyzer
#
# import yfinance as yf
# from datetime import datetime
# import numpy as np
# import pandas as pd
# import requests
# import pyotp
# from sklearn.linear_model import LinearRegression
#
# import time
# from datetime import datetime, timedelta
#
# class TimeUtils:
#     """Utility class for time-related functions."""
#
#     @staticmethod
#     def get_current_datetime_hh_mm_ss_ms():
#         """Returns the current datetime with milliseconds."""
#         return datetime.now()
#
#     @staticmethod
#     def get_current_datetime_hh_mm_ss():
#         """Returns the current time in HH:MM:SS format."""
#         return datetime.now().strftime("%H:%M:%S")
#
#     @staticmethod
#     def print_current_datetime_hh_mm_ss_ms():
#         """Prints the current datetime with milliseconds."""
#         print(TimeUtils.get_current_datetime_hh_mm_ss_ms().strftime("%H:%M:%S.%f"))
#
#     @staticmethod
#     def print_current_datetime_hh_mm_ss():
#         """Prints the current time in HH:MM:SS format."""
#         print(TimeUtils.get_current_datetime_hh_mm_ss())
#
#     @staticmethod
#     def execute_at_precise_time(target_time, func):
#         """
#         Executes a given function at a precise target time.
#
#         :param target_time: Datetime object specifying the execution time.
#         :param func: Function to execute.
#         """
#         delay = (target_time - datetime.now()).total_seconds()
#
#         # Sleep until just before the target time
#         time.sleep(max(0, delay - 0.1))
#
#         # Busy-wait until the exact moment
#         while datetime.now() < target_time:
#             pass
#
#         func()
#
# class ETFPricePredictor:
#     """Predicts ETF opening prices using linear regression based on underlying index data."""
#
#     def __init__(self, assets, start_date="2025-01-01"):
#         self.assets = assets
#         self.start_date = start_date
#         self.end_date = datetime.today().strftime("%Y-%m-%d")
#         self.closing_prices = None
#         self.opening_prices = {}
#         self.models = {}
#
#     def fetch_closing_prices(self):
#         """Fetches daily closing prices for underlying indices and ETFs."""
#         symbols = list(self.assets.keys()) + list(self.assets.values())
#         try:
#             data = yf.download(symbols, start=self.start_date, end=self.end_date)["Close"]
#             data.dropna(inplace=True)
#             self.closing_prices = data
#         except Exception as e:
#             print(f"Error fetching closing prices: {e}")
#
#     def fetch_opening_prices(self):
#         """Fetches today's opening prices for the underlying indices."""
#         for index in self.assets.keys():
#             try:
#                 data = yf.Ticker(index).history(period="1d")
#                 self.opening_prices[index] = data["Open"].iloc[0] if not data.empty else None
#             except Exception as e:
#                 print(f"Error fetching opening price for {index}: {e}")
#                 self.opening_prices[index] = None
#
#     def train_models(self):
#         """Trains a Linear Regression model for each ETF based on its underlying index."""
#         if self.closing_prices is None:
#             print("Error: Closing prices not available. Fetch data first.")
#             return
#
#         for index, etf in self.assets.items():
#             try:
#                 X = self.closing_prices[index].values.reshape(-1, 1)
#                 y = self.closing_prices[etf].values.reshape(-1, 1)
#
#                 model = LinearRegression()
#                 model.fit(X, y)
#                 self.models[etf] = model
#             except Exception as e:
#                 print(f"Error training model for {etf}: {e}")
#
#     def predict_opening_prices(self):
#         """Predicts today's opening price for ETFs using the trained regression models."""
#         predicted_openings = {}
#         for index, etf in self.assets.items():
#             if self.opening_prices.get(index) is not None and etf in self.models:
#                 try:
#                     predicted_openings[etf] = self.models[etf].predict(np.array([[self.opening_prices[index]]]))[0][0]
#                 except Exception as e:
#                     print(f"Error predicting opening price for {etf}: {e}")
#                     predicted_openings[etf] = None
#             else:
#                 predicted_openings[etf] = "Market Closed or Model Not Available"
#         return predicted_openings
#
# class ETFVolumeAnalyzer:
#     """Analyzes ETF trading volume and calculates safe volume."""
#
#     def __init__(self, assets, start_date="2025-01-01"):
#         self.etf_symbols = list(assets.values())
#         self.start_date = start_date
#         self.end_date = datetime.today().strftime("%Y-%m-%d")
#         self.average_volumes = {}
#         self.safe_volumes = {}
#
#     def fetch_average_volumes(self):
#         """Fetches daily ETF trading volumes and calculates the average volume for each ETF."""
#         try:
#             volume_data = yf.download(self.etf_symbols, start=self.start_date, end=self.end_date)["Volume"]
#             self.average_volumes = volume_data.mean().to_dict()
#         except Exception as e:
#             print(f"Error fetching ETF volumes: {e}")
#
#     def calculate_safe_volumes(self):
#         """Calculates safe volume using the formula: Average Volume / 4500."""
#         for etf, avg_volume in self.average_volumes.items():
#             self.safe_volumes[etf] = int(avg_volume / 4500)
#             # 6.25 hours = 22,500 seconds | 22500/5 = 4500
#
#     def get_safe_volumes(self):
#         """Returns the calculated safe volumes."""
#         return self.safe_volumes
#
# class ZerodhaLogin:
#     """Handles Zerodha Kite login and maintains a session for order placement."""
#
#     LOGIN_URL = "https://kite.zerodha.com/api/login"
#     TOTP_URL = "https://kite.zerodha.com/api/twofa"
#
#     def __init__(self, username, password, totp_key):
#         self.username = username
#         self.password = password
#         self.totp_key = totp_key
#         self.session = requests.Session()
#         self.enctoken = None
#         self.headers = None
#
#     def login(self):
#         """Performs login using Zerodha credentials and TOTP authentication."""
#         try:
#             res1 = self.session.post(self.LOGIN_URL, data={
#                 "user_id": self.username,
#                 "password": self.password,
#                 "type": "user_id"
#             })
#             res1.raise_for_status()
#             loginRes = res1.json()
#
#             if "data" not in loginRes or "request_id" not in loginRes["data"]:
#                 raise ValueError("Login failed: Invalid response from server")
#
#             totp_value = pyotp.TOTP(self.totp_key).now()
#             finalRes = self.session.post(self.TOTP_URL, data={
#                 "request_id": loginRes["data"]["request_id"],
#                 "twofa_value": totp_value,
#                 "user_id": loginRes["data"]["user_id"],
#                 "twofa_type": "totp"
#             })
#             finalRes.raise_for_status()
#             authRes = finalRes.json()
#
#             if "status" not in authRes or authRes["status"] != "success":
#                 raise ValueError("TOTP Authentication failed")
#
#             self.enctoken = self.session.cookies.get_dict().get("enctoken", None)
#             if not self.enctoken:
#                 raise ValueError("Failed to retrieve enctoken")
#
#             print("Login successful!")
#             return self.session, self.enctoken
#
#         except requests.exceptions.RequestException as e:
#             print(f"HTTP Request Failed: {e}")
#         except ValueError as ve:
#             print(f"Error: {ve}")
#
# class ZerodhaMargin:
#     """Fetches margin details from Zerodha Kite API using an existing session."""
#
#     MARGIN_URL = "https://kite.zerodha.com/oms/user/margins"
#
#     def __init__(self, session, enctoken, headers):
#         """Initialize with an existing authenticated session and headers."""
#         self.session = session
#         self.enctoken = enctoken
#         self.headers = headers
#
#         if not self.enctoken or not self.headers:
#             raise ValueError("Authentication token or headers are missing. Cannot fetch margin data.")
#
#     def fetch_margin(self):
#         """Fetches margin details and extracts net margin for equity and commodity."""
#         try:
#             response = self.session.get(self.MARGIN_URL, headers=self.headers)
#             response.raise_for_status()
#             data = response.json()
#
#             equity_margin = data["data"]["equity"]["net"]
#             commodity_margin = data["data"]["commodity"]["net"]
#
#             return equity_margin, commodity_margin
#
#         except requests.exceptions.RequestException as e:
#             print(f"HTTP Request Failed: {e}")
#             return None, None
#
# def main():
#     """Main execution function"""
#     assets = {
#         "^NSEI": "NIFTYBEES.NS",      # Nifty 50 → Niftybees
#         "^NSMIDCP": "JUNIORBEES.NS",   # Nifty Next 50 → Junior Bees
#         "^NSEBANK": "BANKBEES.NS"      # Nifty Bank → Bank Bees
#     }
#
#     # Predict ETF opening prices
#     predictor = ETFPricePredictor(assets)
#
#     print("Fetching historical closing prices...")
#     predictor.fetch_closing_prices()
#
#     print("Fetching today's opening prices...")
#     predictor.fetch_opening_prices()
#
#     print("Training regression models...")
#     predictor.train_models()
#
#     print("\nToday's Opening Prices:")
#     for index, price in predictor.opening_prices.items():
#         print(f"{index}: {price}")
#
#     print("\nPredicted ETF Opening Prices:")
#     predicted_prices = predictor.predict_opening_prices()
#     for etf, price in predicted_prices.items():
#         print(f"{etf}: {price:.2f}" if isinstance(price, float) else f"{etf}: {price}")
#
#     # Analyze ETF trading volumes
#     volume_analyzer = ETFVolumeAnalyzer(assets)
#
#     print("\nFetching ETF volume data...")
#     volume_analyzer.fetch_average_volumes()
#
#     print("Calculating safe volumes...")
#     volume_analyzer.calculate_safe_volumes()
#
#     print("\nAverage ETF Trading Volumes:")
#     for etf, avg_volume in volume_analyzer.average_volumes.items():
#         print(f"{etf}: {avg_volume:,.0f}")
#
#     print("\nSafe Trading Volumes:")
#     safe_volumes = volume_analyzer.get_safe_volumes()
#     for etf, safe_vol in safe_volumes.items():
#         print(f"{etf}: {safe_vol}")
#
#     # Log in to Zerodha
#     zerodha = ZerodhaLogin("DXU151", "Pratibha", "FLJBDJNEBOIMZZZPE25YYYR72Y2B2IAP")
#     session, enctoken = zerodha.login()
#
#     # Ensure successful login before proceeding
#     if not enctoken:
#         print("Zerodha login failed. Exiting...")
#         return
#
#     # Initialize ZerodhaMargin with correct headers
#     headers = {
#         "Authorization": f"enctoken {enctoken}",
#         "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36",
#         "Referer": "https://kite.zerodha.com/dashboard",
#         "Accept-Language": "en-US,en;q=0.6",
#         "Content-type": "application/x-www-form-urlencoded",
#         "Accept": "application/json, text/plain, */*",
#     }
#
#     zerodha_margin = ZerodhaMargin(session, enctoken, headers)
#     equity_margin, commodity_margin = zerodha_margin.fetch_margin()
#
#     print("\nZerodha Margin Details:")
#     print(f"Equity Margin: {equity_margin}")
#     print(f"Commodity Margin: {commodity_margin}")}")
#
# if __name__ == "__main__":
#     main()

# %%
class VolumeCalculation:
    """Calculates adjusted trading volumes based on margin and safe volumes."""

    def __init__(self, equity_margin, predicted_openings, safe_volumes):
        self.equity_margin = equity_margin
        self.predicted_openings = predicted_openings
        self.safe_volumes = safe_volumes

    def calculate_leveraged_margin(self):
        """Calculates leveraged margin as equity margin multiplied by 5."""
        return self.equity_margin * 5

    def calculate_trade_values(self):
        """Calculates trade value for each ETF as predicted_openings * safe_volumes."""
        return {etf: self.predicted_openings[etf] * self.safe_volumes[etf] for etf in self.safe_volumes}

    def calculate_total_trade_value(self, trade_values):
        """Calculates total trade value as the sum of all individual trade values."""
        return sum(trade_values.values())

    def calculate_allocation_ratio(self, leveraged_margin, total_trade_value):
        """Calculates allocation ratio as leveraged_margin / total_trade_value."""
        return leveraged_margin / total_trade_value if total_trade_value > 0 else 0

    def calculate_adjusted_quantities(self, allocation_ratio):
        """Calculates adjusted quantity for each ETF as allocation_ratio * safe_volumes."""
        return {etf: int(allocation_ratio * self.safe_volumes[etf]) for etf in self.safe_volumes}

    def execute_volume_calculation(self):
        """Executes all calculations and returns adjusted quantities."""
        leveraged_margin = self.calculate_leveraged_margin()
        trade_values = self.calculate_trade_values()
        total_trade_value = self.calculate_total_trade_value(trade_values)
        allocation_ratio = self.calculate_allocation_ratio(leveraged_margin, total_trade_value)
        adjusted_quantities = self.calculate_adjusted_quantities(allocation_ratio)
        
        return adjusted_quantities

# %% [raw]
# below is the python code class VolumeCalculation. tell me how to call it from main and print it.
#
# class VolumeCalculation:
#     """Calculates adjusted trading volumes based on margin and safe volumes."""
#
#     def __init__(self, equity_margin, predicted_openings, safe_volumes):
#         self.equity_margin = equity_margin
#         self.predicted_openings = predicted_openings
#         self.safe_volumes = safe_volumes
#
#     def calculate_leveraged_margin(self):
#         """Calculates leveraged margin as equity margin multiplied by 5."""
#         return self.equity_margin * 5
#
#     def calculate_trade_values(self):
#         """Calculates trade value for each ETF as predicted_openings * safe_volumes."""
#         return {etf: self.predicted_openings[etf] * self.safe_volumes[etf] for etf in self.safe_volumes}
#
#     def calculate_total_trade_value(self, trade_values):
#         """Calculates total trade value as the sum of all individual trade values."""
#         return sum(trade_values.values())
#
#     def calculate_allocation_ratio(self, leveraged_margin, total_trade_value):
#         """Calculates allocation ratio as leveraged_margin / total_trade_value."""
#         return leveraged_margin / total_trade_value if total_trade_value > 0 else 0
#
#     def calculate_adjusted_quantities(self, allocation_ratio):
#         """Calculates adjusted quantity for each ETF as allocation_ratio * safe_volumes."""
#         return {etf: int(allocation_ratio * self.safe_volumes[etf]) for etf in self.safe_volumes}
#
#     def execute_volume_calculation(self):
#         """Executes all calculations and returns adjusted quantities."""
#         leveraged_margin = self.calculate_leveraged_margin()
#         trade_values = self.calculate_trade_values()
#         total_trade_value = self.calculate_total_trade_value(trade_values)
#         allocation_ratio = self.calculate_allocation_ratio(leveraged_margin, total_trade_value)
#         adjusted_quantities = self.calculate_adjusted_quantities(allocation_ratio)
#
#         return adjusted_quantities

# %%
def main():
    """Main execution function"""
    assets = {
        "^NSEI": "NIFTYBEES.NS",      # Nifty 50 → Niftybees
        "^NSMIDCP": "JUNIORBEES.NS",   # Nifty Next 50 → Junior Bees
        "^NSEBANK": "BANKBEES.NS"      # Nifty Bank → Bank Bees
    }

    # Predict ETF opening prices
    predictor = ETFPricePredictor(assets)
    
    print("Fetching historical closing prices...")
    predictor.fetch_closing_prices()

    print("Fetching today's opening prices...")
    predictor.fetch_opening_prices()

    print("Training regression models...")
    predictor.train_models()

    print("\nToday's Opening Prices:")
    for index, price in predictor.opening_prices.items():
        print(f"{index}: {price}")

    print("\nPredicted ETF Opening Prices:")
    predicted_prices = predictor.predict_opening_prices()
    for etf, price in predicted_prices.items():
        print(f"{etf}: {price:.2f}" if isinstance(price, float) else f"{etf}: {price}")

    # Analyze ETF trading volumes
    volume_analyzer = ETFVolumeAnalyzer(assets)
    
    print("\nFetching ETF volume data...")
    volume_analyzer.fetch_average_volumes()

    print("Calculating safe volumes...")
    volume_analyzer.calculate_safe_volumes()

    print("\nAverage ETF Trading Volumes:")
    for etf, avg_volume in volume_analyzer.average_volumes.items():
        print(f"{etf}: {avg_volume:,.0f}")

    print("\nSafe Trading Volumes:")
    safe_volumes = volume_analyzer.get_safe_volumes()
    for etf, safe_vol in safe_volumes.items():
        print(f"{etf}: {safe_vol}")

    # Log in to Zerodha
    zerodha = ZerodhaLogin("DXU151", "Pratibha", "FLJBDJNEBOIMZZZPE25YYYR72Y2B2IAP")
    session, enctoken = zerodha.login()

    # Ensure successful login before proceeding
    if not enctoken:
        print("Zerodha login failed. Exiting...")
        return  

    # Initialize ZerodhaMargin with correct headers
    headers = {
        "Authorization": f"enctoken {enctoken}",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36",
        "Referer": "https://kite.zerodha.com/dashboard",
        "Accept-Language": "en-US,en;q=0.6",
        "Content-type": "application/x-www-form-urlencoded",
        "Accept": "application/json, text/plain, */*",
    }

    zerodha_margin = ZerodhaMargin(session, enctoken, headers)
    equity_margin, _ = zerodha_margin.fetch_margin()  # Fetch only equity margin

    # Initialize VolumeCalculation with necessary data
    volume_calculator = VolumeCalculation(equity_margin, predicted_prices, safe_volumes)

    # Calculate adjusted quantities
    adjusted_quantities = volume_calculator.execute_volume_calculation()

    print("\nAdjusted Quantities for Each ETF:")
    for etf, adjusted_quantity in adjusted_quantities.items():
        print(f"{etf}: {adjusted_quantity}")

# %% [raw]
# manual update

# %%
import yfinance as yf
from datetime import datetime
import numpy as np
import pandas as pd
import requests
import pyotp
from sklearn.linear_model import LinearRegression

import time
from datetime import datetime, timedelta

class TimeUtils:
    """Utility class for time-related functions."""
    
    @staticmethod
    def get_current_datetime_hh_mm_ss_ms():
        """Returns the current datetime with milliseconds."""
        return datetime.now()

    @staticmethod
    def get_current_datetime_hh_mm_ss():
        """Returns the current time in HH:MM:SS format."""
        return datetime.now().strftime("%H:%M:%S")

    @staticmethod
    def print_current_datetime_hh_mm_ss_ms():
        """Prints the current datetime with milliseconds."""
        print(TimeUtils.get_current_datetime_hh_mm_ss_ms().strftime("%H:%M:%S.%f"))

    @staticmethod
    def print_current_datetime_hh_mm_ss():
        """Prints the current time in HH:MM:SS format."""
        print(TimeUtils.get_current_datetime_hh_mm_ss())

    @staticmethod
    def execute_at_precise_time(target_time, func):
        """
        Executes a given function at a precise target time.

        :param target_time: Datetime object specifying the execution time.
        :param func: Function to execute.
        """
        delay = (target_time - datetime.now()).total_seconds()
        
        # Sleep until just before the target time
        time.sleep(max(0, delay - 0.1))
        
        # Busy-wait until the exact moment
        while datetime.now() < target_time:
            pass

        func()

class ETFPricePredictor:
    """Predicts ETF opening prices using linear regression based on underlying index data."""

    def __init__(self, assets, start_date="2025-01-01"):
        self.assets = assets
        self.start_date = start_date
        self.end_date = datetime.today().strftime("%Y-%m-%d")
        self.closing_prices = None
        self.opening_prices = {}
        self.models = {}

    def fetch_closing_prices(self):
        """Fetches daily closing prices for underlying indices and ETFs."""
        symbols = list(self.assets.keys()) + list(self.assets.values())  
        try:
            data = yf.download(symbols, start=self.start_date, end=self.end_date)["Close"]
            data.dropna(inplace=True)  
            self.closing_prices = data
        except Exception as e:
            print(f"Error fetching closing prices: {e}")

    def fetch_opening_prices(self):
        """Fetches today's opening prices for the underlying indices."""
        for index in self.assets.keys():
            try:
                data = yf.Ticker(index).history(period="1d")
                self.opening_prices[index] = data["Open"].iloc[0] if not data.empty else None
            except Exception as e:
                print(f"Error fetching opening price for {index}: {e}")
                self.opening_prices[index] = None  

    def train_models(self):
        """Trains a Linear Regression model for each ETF based on its underlying index."""
        if self.closing_prices is None:
            print("Error: Closing prices not available. Fetch data first.")
            return
        
        for index, etf in self.assets.items():
            try:
                X = self.closing_prices[index].values.reshape(-1, 1)  
                y = self.closing_prices[etf].values.reshape(-1, 1)  
                
                model = LinearRegression()
                model.fit(X, y)  
                self.models[etf] = model
            except Exception as e:
                print(f"Error training model for {etf}: {e}")

    def predict_opening_prices(self):
        """Predicts today's opening price for ETFs using the trained regression models."""
        predicted_openings = {}
        for index, etf in self.assets.items():
            if self.opening_prices.get(index) is not None and etf in self.models:
                try:
                    predicted_openings[etf] = self.models[etf].predict(np.array([[self.opening_prices[index]]]))[0][0]
                except Exception as e:
                    print(f"Error predicting opening price for {etf}: {e}")
                    predicted_openings[etf] = None
            else:
                predicted_openings[etf] = "Market Closed or Model Not Available"
        return predicted_openings

class ETFVolumeAnalyzer:
    """Analyzes ETF trading volume and calculates safe volume."""

    def __init__(self, assets, start_date="2025-01-01"):
        self.etf_symbols = list(assets.values())  
        self.start_date = start_date
        self.end_date = datetime.today().strftime("%Y-%m-%d")
        self.average_volumes = {}
        self.safe_volumes = {}

    def fetch_average_volumes(self):
        """Fetches daily ETF trading volumes and calculates the average volume for each ETF."""
        try:
            volume_data = yf.download(self.etf_symbols, start=self.start_date, end=self.end_date)["Volume"]
            self.average_volumes = volume_data.mean().to_dict()  
        except Exception as e:
            print(f"Error fetching ETF volumes: {e}")

    def calculate_safe_volumes(self):
        """Calculates safe volume using the formula: Average Volume / 4500."""
        for etf, avg_volume in self.average_volumes.items():
            self.safe_volumes[etf] = int(avg_volume / 4500)  
            # 6.25 hours = 22,500 seconds | 22500/5 = 4500

    def get_safe_volumes(self):
        """Returns the calculated safe volumes."""
        return self.safe_volumes

class ZerodhaLogin:
    """Handles Zerodha Kite login and maintains a session for order placement."""
    
    LOGIN_URL = "https://kite.zerodha.com/api/login"
    TOTP_URL = "https://kite.zerodha.com/api/twofa"

    def __init__(self, username, password, totp_key):
        self.username = username
        self.password = password
        self.totp_key = totp_key
        self.session = requests.Session()
        self.enctoken = None  
        self.headers = None  

    def login(self):
        """Performs login using Zerodha credentials and TOTP authentication."""
        try:
            res1 = self.session.post(self.LOGIN_URL, data={
                "user_id": self.username,
                "password": self.password,
                "type": "user_id"
            })
            res1.raise_for_status()  
            loginRes = res1.json()

            if "data" not in loginRes or "request_id" not in loginRes["data"]:
                raise ValueError("Login failed: Invalid response from server")

            totp_value = pyotp.TOTP(self.totp_key).now()
            finalRes = self.session.post(self.TOTP_URL, data={
                "request_id": loginRes["data"]["request_id"],
                "twofa_value": totp_value,
                "user_id": loginRes["data"]["user_id"],
                "twofa_type": "totp"
            })
            finalRes.raise_for_status()
            authRes = finalRes.json()

            if "status" not in authRes or authRes["status"] != "success":
                raise ValueError("TOTP Authentication failed")

            self.enctoken = self.session.cookies.get_dict().get("enctoken", None)
            if not self.enctoken:
                raise ValueError("Failed to retrieve enctoken")

            print("Login successful!")
            return self.session, self.enctoken

        except requests.exceptions.RequestException as e:
            print(f"HTTP Request Failed: {e}")
        except ValueError as ve:
            print(f"Error: {ve}")

class ZerodhaMargin:
    """Fetches margin details from Zerodha Kite API using an existing session."""

    MARGIN_URL = "https://kite.zerodha.com/oms/user/margins"

    def __init__(self, session, enctoken, headers):
        """Initialize with an existing authenticated session and headers."""
        self.session = session
        self.enctoken = enctoken
        self.headers = headers

        if not self.enctoken or not self.headers:
            raise ValueError("Authentication token or headers are missing. Cannot fetch margin data.")

    def fetch_margin(self):
        """Fetches margin details and extracts net margin for equity and commodity."""
        try:
            response = self.session.get(self.MARGIN_URL, headers=self.headers)
            response.raise_for_status()
            data = response.json()

            equity_margin = data["data"]["equity"]["net"]
            commodity_margin = data["data"]["commodity"]["net"]

            return equity_margin, commodity_margin

        except requests.exceptions.RequestException as e:
            print(f"HTTP Request Failed: {e}")
            return None, None

class VolumeCalculation:
    """Calculates adjusted trading volumes based on margin and safe volumes."""

    def __init__(self, equity_margin, predicted_openings, safe_volumes):
        self.equity_margin = equity_margin
        self.predicted_openings = predicted_openings
        self.safe_volumes = safe_volumes

    def calculate_leveraged_margin(self):
        """Calculates leveraged margin as equity margin multiplied by 5."""
        return self.equity_margin * 5

    def calculate_trade_values(self):
        """Calculates trade value for each ETF as predicted_openings * safe_volumes."""
        return {etf: self.predicted_openings[etf] * self.safe_volumes[etf] for etf in self.safe_volumes}

    def calculate_total_trade_value(self, trade_values):
        """Calculates total trade value as the sum of all individual trade values."""
        return sum(trade_values.values())

    def calculate_allocation_ratio(self, leveraged_margin, total_trade_value):
        """Calculates allocation ratio as leveraged_margin / total_trade_value."""
        return leveraged_margin / total_trade_value if total_trade_value > 0 else 0

    def calculate_adjusted_quantities(self, allocation_ratio):
        """Calculates adjusted quantity for each ETF as allocation_ratio * safe_volumes."""
        return {etf: int(allocation_ratio * self.safe_volumes[etf]) for etf in self.safe_volumes}

    def execute_volume_calculation(self):
        """Executes all calculations and returns adjusted quantities."""
        leveraged_margin = self.calculate_leveraged_margin()
        trade_values = self.calculate_trade_values()
        total_trade_value = self.calculate_total_trade_value(trade_values)
        allocation_ratio = self.calculate_allocation_ratio(leveraged_margin, total_trade_value)
        adjusted_quantities = self.calculate_adjusted_quantities(allocation_ratio)
        
        return adjusted_quantities

    
def main():
    """Main execution function"""
    assets = {
        "^NSEI": "NIFTYBEES.NS",      # Nifty 50 → Niftybees
        "^NSMIDCP": "JUNIORBEES.NS",   # Nifty Next 50 → Junior Bees
        "^NSEBANK": "BANKBEES.NS"      # Nifty Bank → Bank Bees
    }

    # Predict ETF opening prices
    predictor = ETFPricePredictor(assets)
    
    print("Fetching historical closing prices...")
    predictor.fetch_closing_prices()

    print("Fetching today's opening prices...")
    predictor.fetch_opening_prices()

    print("Training regression models...")
    predictor.train_models()

    print("\nToday's Opening Prices:")
    for index, price in predictor.opening_prices.items():
        print(f"{index}: {price}")

    print("\nPredicted ETF Opening Prices:")
    predicted_prices = predictor.predict_opening_prices()
    for etf, price in predicted_prices.items():
        print(f"{etf}: {price:.2f}" if isinstance(price, float) else f"{etf}: {price}")

    # Analyze ETF trading volumes
    volume_analyzer = ETFVolumeAnalyzer(assets)
    
    print("\nFetching ETF volume data...")
    volume_analyzer.fetch_average_volumes()

    print("Calculating safe volumes...")
    volume_analyzer.calculate_safe_volumes()

    print("\nAverage ETF Trading Volumes:")
    for etf, avg_volume in volume_analyzer.average_volumes.items():
        print(f"{etf}: {avg_volume:,.0f}")

    print("\nSafe Trading Volumes:")
    safe_volumes = volume_analyzer.get_safe_volumes()
    for etf, safe_vol in safe_volumes.items():
        print(f"{etf}: {safe_vol}")

    # Log in to Zerodha
    zerodha = ZerodhaLogin("DXU151", "Pratibha", "FLJBDJNEBOIMZZZPE25YYYR72Y2B2IAP")
    session, enctoken = zerodha.login()

    # Ensure successful login before proceeding
    if not enctoken:
        print("Zerodha login failed. Exiting...")
        return  

    # Initialize ZerodhaMargin with correct headers
    headers = {
        "Authorization": f"enctoken {enctoken}",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36",
        "Referer": "https://kite.zerodha.com/dashboard",
        "Accept-Language": "en-US,en;q=0.6",
        "Content-type": "application/x-www-form-urlencoded",
        "Accept": "application/json, text/plain, */*",
    }

    zerodha_margin = ZerodhaMargin(session, enctoken, headers)
    equity_margin, commodity_margin = zerodha_margin.fetch_margin()

    print("\nZerodha Margin Details:")
    print(f"Equity Margin: {equity_margin}")
    print(f"Commodity Margin: {commodity_margin}")

    # Initialize VolumeCalculation with necessary data
    volume_calculator = VolumeCalculation(equity_margin, predicted_prices, safe_volumes)

    # Calculate adjusted quantities
    adjusted_quantities = volume_calculator.execute_volume_calculation()

    print("\nAdjusted Quantities for Each ETF:")
    for etf, adjusted_quantity in adjusted_quantities.items():
        print(f"{etf}: {adjusted_quantity}")

if __name__ == "__main__":
    main()

# %% [raw]
# class VolumeCalculation:
#     """Calculates adjusted trading volumes based on margin and safe volumes."""
#
#     def __init__(self, equity_margin, predicted_openings, safe_volumes):
#         self.equity_margin = equity_margin
#         self.predicted_openings = predicted_openings
#         self.safe_volumes = safe_volumes
#
#     def calculate_leveraged_margin(self):
#         """Calculates leveraged margin as equity margin multiplied by 5."""
#         return self.equity_margin * 5
#
#     def calculate_trade_values(self):
#         """Calculates trade value for each ETF as predicted_openings * safe_volumes."""
#         return {etf: self.predicted_openings[etf] * self.safe_volumes[etf] for etf in self.safe_volumes}
#
#     def calculate_total_trade_value(self, trade_values):
#         """Calculates total trade value as the sum of all individual trade values."""
#         return sum(trade_values.values())
#
#     def calculate_allocation_ratio(self, leveraged_margin, total_trade_value):
#         """Calculates allocation ratio as leveraged_margin / total_trade_value."""
#         return leveraged_margin / total_trade_value if total_trade_value > 0 else 0
#
#     def calculate_adjusted_quantities(self, allocation_ratio):
#         """Calculates adjusted quantity for each ETF as allocation_ratio * safe_volumes."""
#         return {etf: int(allocation_ratio * self.safe_volumes[etf]) for etf in self.safe_volumes}
#
#     def execute_volume_calculation(self):
#         """Executes all calculations and returns adjusted quantities."""
#         leveraged_margin = self.calculate_leveraged_margin()
#         trade_values = self.calculate_trade_values()
#         total_trade_value = self.calculate_total_trade_value(trade_values)
#         allocation_ratio = self.calculate_allocation_ratio(leveraged_margin, total_trade_value)
#         adjusted_quantities = self.calculate_adjusted_quantities(allocation_ratio)
#
#         return adjusted_quantities
#
# above is the python VolumeCalculation class. create function calculate_dicount_margin (after calculate_leveraged_margin) which is calculating dicount using formula (equity_margin * 5) - 5% of equity_margin. discount is used for further calcuation instead of calculate_leveraged_margin whereever it is used.

# %%
class VolumeCalculation:
    """Calculates adjusted trading volumes based on margin and safe volumes."""

    def __init__(self, equity_margin, predicted_openings, safe_volumes):
        self.equity_margin = equity_margin
        self.predicted_openings = predicted_openings
        self.safe_volumes = safe_volumes

    def calculate_leveraged_margin(self):
        """Calculates leveraged margin as equity margin multiplied by 5."""
        return self.equity_margin * 5

    def calculate_discount_margin(self):
        """Calculates discounted margin as (equity margin * 5) - 5% of equity margin."""
        return (self.equity_margin * 5) - (self.equity_margin * 0.05)

    def calculate_trade_values(self):
        """Calculates trade value for each ETF as predicted_openings * safe_volumes."""
        return {etf: self.predicted_openings[etf] * self.safe_volumes[etf] for etf in self.safe_volumes}

    def calculate_total_trade_value(self, trade_values):
        """Calculates total trade value as the sum of all individual trade values."""
        return sum(trade_values.values())

    def calculate_allocation_ratio(self, discount_margin, total_trade_value):
        """Calculates allocation ratio as discount_margin / total_trade_value."""
        return discount_margin / total_trade_value if total_trade_value > 0 else 0

    def calculate_adjusted_quantities(self, allocation_ratio):
        """Calculates adjusted quantity for each ETF as allocation_ratio * safe_volumes."""
        return {etf: int(allocation_ratio * self.safe_volumes[etf]) for etf in self.safe_volumes}

    def execute_volume_calculation(self):
        """Executes all calculations and returns adjusted quantities."""
        discount_margin = self.calculate_discount_margin()  # Use discount margin instead of leveraged margin
        trade_values = self.calculate_trade_values()
        total_trade_value = self.calculate_total_trade_value(trade_values)
        allocation_ratio = self.calculate_allocation_ratio(discount_margin, total_trade_value)
        adjusted_quantities = self.calculate_adjusted_quantities(allocation_ratio)
        
        return adjusted_quantities

"""
# Initialize VolumeCalculation with necessary data
volume_calculator = VolumeCalculation(equity_margin, predicted_prices, safe_volumes)

# Calculate adjusted quantities
adjusted_quantities = volume_calculator.execute_volume_calculation()

print("\nAdjusted Quantities for Each ETF:")
for etf, adjusted_quantity in adjusted_quantities.items():
    print(f"{etf}: {adjusted_quantity}")
"""

# %%
manual update

# %%
import yfinance as yf
from datetime import datetime
import numpy as np
import pandas as pd
import requests
import pyotp
from sklearn.linear_model import LinearRegression

import time
from datetime import datetime, timedelta

class TimeUtils:
    """Utility class for time-related functions."""
    
    @staticmethod
    def get_current_datetime_hh_mm_ss_ms():
        """Returns the current datetime with milliseconds."""
        return datetime.now()

    @staticmethod
    def get_current_datetime_hh_mm_ss():
        """Returns the current time in HH:MM:SS format."""
        return datetime.now().strftime("%H:%M:%S")

    @staticmethod
    def print_current_datetime_hh_mm_ss_ms():
        """Prints the current datetime with milliseconds."""
        print(TimeUtils.get_current_datetime_hh_mm_ss_ms().strftime("%H:%M:%S.%f"))

    @staticmethod
    def print_current_datetime_hh_mm_ss():
        """Prints the current time in HH:MM:SS format."""
        print(TimeUtils.get_current_datetime_hh_mm_ss())

    @staticmethod
    def execute_at_precise_time(target_time, func):
        """
        Executes a given function at a precise target time.

        :param target_time: Datetime object specifying the execution time.
        :param func: Function to execute.
        """
        delay = (target_time - datetime.now()).total_seconds()
        
        # Sleep until just before the target time
        time.sleep(max(0, delay - 0.1))
        
        # Busy-wait until the exact moment
        while datetime.now() < target_time:
            pass

        func()

class ETFPricePredictor:
    """Predicts ETF opening prices using linear regression based on underlying index data."""

    def __init__(self, assets, start_date="2025-01-01"):
        self.assets = assets
        self.start_date = start_date
        self.end_date = datetime.today().strftime("%Y-%m-%d")
        self.closing_prices = None
        self.opening_prices = {}
        self.models = {}

    def fetch_closing_prices(self):
        """Fetches daily closing prices for underlying indices and ETFs."""
        symbols = list(self.assets.keys()) + list(self.assets.values())  
        try:
            data = yf.download(symbols, start=self.start_date, end=self.end_date)["Close"]
            data.dropna(inplace=True)  
            self.closing_prices = data
        except Exception as e:
            print(f"Error fetching closing prices: {e}")

    def fetch_opening_prices(self):
        """Fetches today's opening prices for the underlying indices."""
        for index in self.assets.keys():
            try:
                data = yf.Ticker(index).history(period="1d")
                self.opening_prices[index] = data["Open"].iloc[0] if not data.empty else None
            except Exception as e:
                print(f"Error fetching opening price for {index}: {e}")
                self.opening_prices[index] = None  

    def train_models(self):
        """Trains a Linear Regression model for each ETF based on its underlying index."""
        if self.closing_prices is None:
            print("Error: Closing prices not available. Fetch data first.")
            return
        
        for index, etf in self.assets.items():
            try:
                X = self.closing_prices[index].values.reshape(-1, 1)  
                y = self.closing_prices[etf].values.reshape(-1, 1)  
                
                model = LinearRegression()
                model.fit(X, y)  
                self.models[etf] = model
            except Exception as e:
                print(f"Error training model for {etf}: {e}")

    def predict_opening_prices(self):
        """Predicts today's opening price for ETFs using the trained regression models."""
        predicted_openings = {}
        for index, etf in self.assets.items():
            if self.opening_prices.get(index) is not None and etf in self.models:
                try:
                    predicted_openings[etf] = self.models[etf].predict(np.array([[self.opening_prices[index]]]))[0][0]
                except Exception as e:
                    print(f"Error predicting opening price for {etf}: {e}")
                    predicted_openings[etf] = None
            else:
                predicted_openings[etf] = "Market Closed or Model Not Available"
        return predicted_openings

class ETFVolumeAnalyzer:
    """Analyzes ETF trading volume and calculates safe volume."""

    def __init__(self, assets, start_date="2025-01-01"):
        self.etf_symbols = list(assets.values())  
        self.start_date = start_date
        self.end_date = datetime.today().strftime("%Y-%m-%d")
        self.average_volumes = {}
        self.safe_volumes = {}

    def fetch_average_volumes(self):
        """Fetches daily ETF trading volumes and calculates the average volume for each ETF."""
        try:
            volume_data = yf.download(self.etf_symbols, start=self.start_date, end=self.end_date)["Volume"]
            self.average_volumes = volume_data.mean().to_dict()  
        except Exception as e:
            print(f"Error fetching ETF volumes: {e}")

    def calculate_safe_volumes(self):
        """Calculates safe volume using the formula: Average Volume / 4500."""
        for etf, avg_volume in self.average_volumes.items():
            self.safe_volumes[etf] = int(avg_volume / 4500)  
            # 6.25 hours = 22,500 seconds | 22500/5 = 4500

    def get_safe_volumes(self):
        """Returns the calculated safe volumes."""
        return self.safe_volumes

class ZerodhaLogin:
    """Handles Zerodha Kite login and maintains a session for order placement."""
    
    LOGIN_URL = "https://kite.zerodha.com/api/login"
    TOTP_URL = "https://kite.zerodha.com/api/twofa"

    def __init__(self, username, password, totp_key):
        self.username = username
        self.password = password
        self.totp_key = totp_key
        self.session = requests.Session()
        self.enctoken = None  
        self.headers = None  

    def login(self):
        """Performs login using Zerodha credentials and TOTP authentication."""
        try:
            res1 = self.session.post(self.LOGIN_URL, data={
                "user_id": self.username,
                "password": self.password,
                "type": "user_id"
            })
            res1.raise_for_status()  
            loginRes = res1.json()

            if "data" not in loginRes or "request_id" not in loginRes["data"]:
                raise ValueError("Login failed: Invalid response from server")

            totp_value = pyotp.TOTP(self.totp_key).now()
            finalRes = self.session.post(self.TOTP_URL, data={
                "request_id": loginRes["data"]["request_id"],
                "twofa_value": totp_value,
                "user_id": loginRes["data"]["user_id"],
                "twofa_type": "totp"
            })
            finalRes.raise_for_status()
            authRes = finalRes.json()

            if "status" not in authRes or authRes["status"] != "success":
                raise ValueError("TOTP Authentication failed")

            self.enctoken = self.session.cookies.get_dict().get("enctoken", None)
            if not self.enctoken:
                raise ValueError("Failed to retrieve enctoken")

            print("Login successful!")
            return self.session, self.enctoken

        except requests.exceptions.RequestException as e:
            print(f"HTTP Request Failed: {e}")
        except ValueError as ve:
            print(f"Error: {ve}")

class ZerodhaMargin:
    """Fetches margin details from Zerodha Kite API using an existing session."""

    MARGIN_URL = "https://kite.zerodha.com/oms/user/margins"

    def __init__(self, session, enctoken, headers):
        """Initialize with an existing authenticated session and headers."""
        self.session = session
        self.enctoken = enctoken
        self.headers = headers

        if not self.enctoken or not self.headers:
            raise ValueError("Authentication token or headers are missing. Cannot fetch margin data.")

    def fetch_margin(self):
        """Fetches margin details and extracts net margin for equity and commodity."""
        try:
            response = self.session.get(self.MARGIN_URL, headers=self.headers)
            response.raise_for_status()
            data = response.json()

            equity_margin = data["data"]["equity"]["net"]
            commodity_margin = data["data"]["commodity"]["net"]

            return equity_margin, commodity_margin

        except requests.exceptions.RequestException as e:
            print(f"HTTP Request Failed: {e}")
            return None, None

class VolumeCalculation:
    """Calculates adjusted trading volumes based on margin and safe volumes."""

    def __init__(self, equity_margin, predicted_openings, safe_volumes):
        self.equity_margin = equity_margin
        self.predicted_openings = predicted_openings
        self.safe_volumes = safe_volumes

    def calculate_leveraged_margin(self):
        """Calculates leveraged margin as equity margin multiplied by 5."""
        return self.equity_margin * 5

    def calculate_discount_margin(self):
        """Calculates discounted margin as (equity margin * 5) - 5% of equity margin."""
        return (self.equity_margin * 5) - (self.equity_margin * 0.05)

    def calculate_trade_values(self):
        """Calculates trade value for each ETF as predicted_openings * safe_volumes."""
        return {etf: self.predicted_openings[etf] * self.safe_volumes[etf] for etf in self.safe_volumes}

    def calculate_total_trade_value(self, trade_values):
        """Calculates total trade value as the sum of all individual trade values."""
        return sum(trade_values.values())

    def calculate_allocation_ratio(self, discount_margin, total_trade_value):
        """Calculates allocation ratio as discount_margin / total_trade_value."""
        return discount_margin / total_trade_value if total_trade_value > 0 else 0

    def calculate_adjusted_quantities(self, allocation_ratio):
        """Calculates adjusted quantity for each ETF as allocation_ratio * safe_volumes."""
        return {etf: int(allocation_ratio * self.safe_volumes[etf]) for etf in self.safe_volumes}

    def execute_volume_calculation(self):
        """Executes all calculations and returns adjusted quantities."""
        discount_margin = self.calculate_discount_margin()  # Use discount margin instead of leveraged margin
        trade_values = self.calculate_trade_values()
        total_trade_value = self.calculate_total_trade_value(trade_values)
        allocation_ratio = self.calculate_allocation_ratio(discount_margin, total_trade_value)
        adjusted_quantities = self.calculate_adjusted_quantities(allocation_ratio)
        
        return adjusted_quantities


    
def main():
    """Main execution function"""
    assets = {
        "^NSEI": "NIFTYBEES.NS",      # Nifty 50 → Niftybees
        "^NSMIDCP": "JUNIORBEES.NS",   # Nifty Next 50 → Junior Bees
        "^NSEBANK": "BANKBEES.NS"      # Nifty Bank → Bank Bees
    }

    # Predict ETF opening prices
    predictor = ETFPricePredictor(assets)
    
    print("Fetching historical closing prices...")
    predictor.fetch_closing_prices()

    print("Fetching today's opening prices...")
    predictor.fetch_opening_prices()

    print("Training regression models...")
    predictor.train_models()

    print("\nToday's Opening Prices:")
    for index, price in predictor.opening_prices.items():
        print(f"{index}: {price}")

    print("\nPredicted ETF Opening Prices:")
    predicted_prices = predictor.predict_opening_prices()
    for etf, price in predicted_prices.items():
        print(f"{etf}: {price:.2f}" if isinstance(price, float) else f"{etf}: {price}")

    # Analyze ETF trading volumes
    volume_analyzer = ETFVolumeAnalyzer(assets)
    
    print("\nFetching ETF volume data...")
    volume_analyzer.fetch_average_volumes()

    print("Calculating safe volumes...")
    volume_analyzer.calculate_safe_volumes()

    print("\nAverage ETF Trading Volumes:")
    for etf, avg_volume in volume_analyzer.average_volumes.items():
        print(f"{etf}: {avg_volume:,.0f}")

    print("\nSafe Trading Volumes:")
    safe_volumes = volume_analyzer.get_safe_volumes()
    for etf, safe_vol in safe_volumes.items():
        print(f"{etf}: {safe_vol}")

    # Log in to Zerodha
    zerodha = ZerodhaLogin("DXU151", "Pratibha", "FLJBDJNEBOIMZZZPE25YYYR72Y2B2IAP")
    session, enctoken = zerodha.login()

    # Ensure successful login before proceeding
    if not enctoken:
        print("Zerodha login failed. Exiting...")
        return  

    # Initialize ZerodhaMargin with correct headers
    headers = {
        "Authorization": f"enctoken {enctoken}",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36",
        "Referer": "https://kite.zerodha.com/dashboard",
        "Accept-Language": "en-US,en;q=0.6",
        "Content-type": "application/x-www-form-urlencoded",
        "Accept": "application/json, text/plain, */*",
    }

    zerodha_margin = ZerodhaMargin(session, enctoken, headers)
    equity_margin, commodity_margin = zerodha_margin.fetch_margin()

    print("\nZerodha Margin Details:")
    print(f"Equity Margin: {equity_margin}")
    print(f"Commodity Margin: {commodity_margin}")

    # Initialize VolumeCalculation with necessary data
    volume_calculator = VolumeCalculation(equity_margin, predicted_prices, safe_volumes)

    # Calculate adjusted quantities
    adjusted_quantities = volume_calculator.execute_volume_calculation()

    print("\nAdjusted Quantities for Each ETF:")
    for etf, adjusted_quantity in adjusted_quantities.items():
        print(f"{etf}: {adjusted_quantity}")

if __name__ == "__main__":
    main()

# %% [raw]
# manual update - function line to - return (self.equity_margin * 5) - (self.equity_margin * 5 * 0.05)

# %%
import yfinance as yf
from datetime import datetime
import numpy as np
import pandas as pd
import requests
import pyotp
from sklearn.linear_model import LinearRegression

import time
from datetime import datetime, timedelta

class TimeUtils:
    """Utility class for time-related functions."""
    
    @staticmethod
    def get_current_datetime_hh_mm_ss_ms():
        """Returns the current datetime with milliseconds."""
        return datetime.now()

    @staticmethod
    def get_current_datetime_hh_mm_ss():
        """Returns the current time in HH:MM:SS format."""
        return datetime.now().strftime("%H:%M:%S")

    @staticmethod
    def print_current_datetime_hh_mm_ss_ms():
        """Prints the current datetime with milliseconds."""
        print(TimeUtils.get_current_datetime_hh_mm_ss_ms().strftime("%H:%M:%S.%f"))

    @staticmethod
    def print_current_datetime_hh_mm_ss():
        """Prints the current time in HH:MM:SS format."""
        print(TimeUtils.get_current_datetime_hh_mm_ss())

    @staticmethod
    def execute_at_precise_time(target_time, func):
        """
        Executes a given function at a precise target time.

        :param target_time: Datetime object specifying the execution time.
        :param func: Function to execute.
        """
        delay = (target_time - datetime.now()).total_seconds()
        
        # Sleep until just before the target time
        time.sleep(max(0, delay - 0.1))
        
        # Busy-wait until the exact moment
        while datetime.now() < target_time:
            pass

        func()

class ETFPricePredictor:
    """Predicts ETF opening prices using linear regression based on underlying index data."""

    def __init__(self, assets, start_date="2025-01-01"):
        self.assets = assets
        self.start_date = start_date
        self.end_date = datetime.today().strftime("%Y-%m-%d")
        self.closing_prices = None
        self.opening_prices = {}
        self.models = {}

    def fetch_closing_prices(self):
        """Fetches daily closing prices for underlying indices and ETFs."""
        symbols = list(self.assets.keys()) + list(self.assets.values())  
        try:
            data = yf.download(symbols, start=self.start_date, end=self.end_date)["Close"]
            data.dropna(inplace=True)  
            self.closing_prices = data
        except Exception as e:
            print(f"Error fetching closing prices: {e}")

    def fetch_opening_prices(self):
        """Fetches today's opening prices for the underlying indices."""
        for index in self.assets.keys():
            try:
                data = yf.Ticker(index).history(period="1d")
                self.opening_prices[index] = data["Open"].iloc[0] if not data.empty else None
            except Exception as e:
                print(f"Error fetching opening price for {index}: {e}")
                self.opening_prices[index] = None  

    def train_models(self):
        """Trains a Linear Regression model for each ETF based on its underlying index."""
        if self.closing_prices is None:
            print("Error: Closing prices not available. Fetch data first.")
            return
        
        for index, etf in self.assets.items():
            try:
                X = self.closing_prices[index].values.reshape(-1, 1)  
                y = self.closing_prices[etf].values.reshape(-1, 1)  
                
                model = LinearRegression()
                model.fit(X, y)  
                self.models[etf] = model
            except Exception as e:
                print(f"Error training model for {etf}: {e}")

    def predict_opening_prices(self):
        """Predicts today's opening price for ETFs using the trained regression models."""
        predicted_openings = {}
        for index, etf in self.assets.items():
            if self.opening_prices.get(index) is not None and etf in self.models:
                try:
                    predicted_openings[etf] = self.models[etf].predict(np.array([[self.opening_prices[index]]]))[0][0]
                except Exception as e:
                    print(f"Error predicting opening price for {etf}: {e}")
                    predicted_openings[etf] = None
            else:
                predicted_openings[etf] = "Market Closed or Model Not Available"
        return predicted_openings

class ETFVolumeAnalyzer:
    """Analyzes ETF trading volume and calculates safe volume."""

    def __init__(self, assets, start_date="2025-01-01"):
        self.etf_symbols = list(assets.values())  
        self.start_date = start_date
        self.end_date = datetime.today().strftime("%Y-%m-%d")
        self.average_volumes = {}
        self.safe_volumes = {}

    def fetch_average_volumes(self):
        """Fetches daily ETF trading volumes and calculates the average volume for each ETF."""
        try:
            volume_data = yf.download(self.etf_symbols, start=self.start_date, end=self.end_date)["Volume"]
            self.average_volumes = volume_data.mean().to_dict()  
        except Exception as e:
            print(f"Error fetching ETF volumes: {e}")

    def calculate_safe_volumes(self):
        """Calculates safe volume using the formula: Average Volume / 4500."""
        for etf, avg_volume in self.average_volumes.items():
            self.safe_volumes[etf] = int(avg_volume / 4500)  
            # 6.25 hours = 22,500 seconds | 22500/5 = 4500

    def get_safe_volumes(self):
        """Returns the calculated safe volumes."""
        return self.safe_volumes

class ZerodhaLogin:
    """Handles Zerodha Kite login and maintains a session for order placement."""
    
    LOGIN_URL = "https://kite.zerodha.com/api/login"
    TOTP_URL = "https://kite.zerodha.com/api/twofa"

    def __init__(self, username, password, totp_key):
        self.username = username
        self.password = password
        self.totp_key = totp_key
        self.session = requests.Session()
        self.enctoken = None  
        self.headers = None  

    def login(self):
        """Performs login using Zerodha credentials and TOTP authentication."""
        try:
            res1 = self.session.post(self.LOGIN_URL, data={
                "user_id": self.username,
                "password": self.password,
                "type": "user_id"
            })
            res1.raise_for_status()  
            loginRes = res1.json()

            if "data" not in loginRes or "request_id" not in loginRes["data"]:
                raise ValueError("Login failed: Invalid response from server")

            totp_value = pyotp.TOTP(self.totp_key).now()
            finalRes = self.session.post(self.TOTP_URL, data={
                "request_id": loginRes["data"]["request_id"],
                "twofa_value": totp_value,
                "user_id": loginRes["data"]["user_id"],
                "twofa_type": "totp"
            })
            finalRes.raise_for_status()
            authRes = finalRes.json()

            if "status" not in authRes or authRes["status"] != "success":
                raise ValueError("TOTP Authentication failed")

            self.enctoken = self.session.cookies.get_dict().get("enctoken", None)
            if not self.enctoken:
                raise ValueError("Failed to retrieve enctoken")

            print("Login successful!")
            return self.session, self.enctoken

        except requests.exceptions.RequestException as e:
            print(f"HTTP Request Failed: {e}")
        except ValueError as ve:
            print(f"Error: {ve}")

class ZerodhaMargin:
    """Fetches margin details from Zerodha Kite API using an existing session."""

    MARGIN_URL = "https://kite.zerodha.com/oms/user/margins"

    def __init__(self, session, enctoken, headers):
        """Initialize with an existing authenticated session and headers."""
        self.session = session
        self.enctoken = enctoken
        self.headers = headers

        if not self.enctoken or not self.headers:
            raise ValueError("Authentication token or headers are missing. Cannot fetch margin data.")

    def fetch_margin(self):
        """Fetches margin details and extracts net margin for equity and commodity."""
        try:
            response = self.session.get(self.MARGIN_URL, headers=self.headers)
            response.raise_for_status()
            data = response.json()

            equity_margin = data["data"]["equity"]["net"]
            commodity_margin = data["data"]["commodity"]["net"]

            return equity_margin, commodity_margin

        except requests.exceptions.RequestException as e:
            print(f"HTTP Request Failed: {e}")
            return None, None

class VolumeCalculation:
    """Calculates adjusted trading volumes based on margin and safe volumes."""

    def __init__(self, equity_margin, predicted_openings, safe_volumes):
        self.equity_margin = equity_margin
        self.predicted_openings = predicted_openings
        self.safe_volumes = safe_volumes

    def calculate_leveraged_margin(self):
        """Calculates leveraged margin as equity margin multiplied by 5."""
        return self.equity_margin * 5

    def calculate_discount_margin(self):
        """Calculates discounted margin as (equity margin * 5) - 5% of equity margin."""
        return (self.equity_margin * 5) - (self.equity_margin * 5 * 0.05)

    def calculate_trade_values(self):
        """Calculates trade value for each ETF as predicted_openings * safe_volumes."""
        return {etf: self.predicted_openings[etf] * self.safe_volumes[etf] for etf in self.safe_volumes}

    def calculate_total_trade_value(self, trade_values):
        """Calculates total trade value as the sum of all individual trade values."""
        return sum(trade_values.values())

    def calculate_allocation_ratio(self, discount_margin, total_trade_value):
        """Calculates allocation ratio as discount_margin / total_trade_value."""
        return discount_margin / total_trade_value if total_trade_value > 0 else 0

    def calculate_adjusted_quantities(self, allocation_ratio):
        """Calculates adjusted quantity for each ETF as allocation_ratio * safe_volumes."""
        return {etf: int(allocation_ratio * self.safe_volumes[etf]) for etf in self.safe_volumes}

    def execute_volume_calculation(self):
        """Executes all calculations and returns adjusted quantities."""
        discount_margin = self.calculate_discount_margin()  # Use discount margin instead of leveraged margin
        trade_values = self.calculate_trade_values()
        total_trade_value = self.calculate_total_trade_value(trade_values)
        allocation_ratio = self.calculate_allocation_ratio(discount_margin, total_trade_value)
        adjusted_quantities = self.calculate_adjusted_quantities(allocation_ratio)
        
        return adjusted_quantities

class DataStore:
    """Class to store symbols, adjusted quantities, and predicted prices."""

    def __init__(self):
        self.data = []

    def format_symbol(self, symbol):
        """Formats the symbol by removing '.NS' from the end."""
        return symbol.split('.')[0]

    def add_data(self, symbol, adjusted_quantity, predicted_price):
        """Adds a new entry to the data store."""
        formatted_symbol = self.format_symbol(symbol)
        self.data.append({
            'symbol_a': formatted_symbol,
            'quantity_a': adjusted_quantity,
            'price_a': predicted_price
        })

    def get_data(self):
        """Returns all stored data."""
        return self.data
    
def main():
    """Main execution function"""
    assets = {
        "^NSEI": "NIFTYBEES.NS",      # Nifty 50 → Niftybees
        "^NSMIDCP": "JUNIORBEES.NS",   # Nifty Next 50 → Junior Bees
        "^NSEBANK": "BANKBEES.NS"      # Nifty Bank → Bank Bees
    }

    # Predict ETF opening prices
    predictor = ETFPricePredictor(assets)
    
    print("Fetching historical closing prices...")
    predictor.fetch_closing_prices()

    print("Fetching today's opening prices...")
    predictor.fetch_opening_prices()

    print("Training regression models...")
    predictor.train_models()

    print("\nToday's Opening Prices:")
    for index, price in predictor.opening_prices.items():
        print(f"{index}: {price}")

    print("\nPredicted ETF Opening Prices:")
    predicted_prices = predictor.predict_opening_prices()
    for etf, price in predicted_prices.items():
        print(f"{etf}: {price:.2f}" if isinstance(price, float) else f"{etf}: {price}")

    # Analyze ETF trading volumes
    volume_analyzer = ETFVolumeAnalyzer(assets)
    
    print("\nFetching ETF volume data...")
    volume_analyzer.fetch_average_volumes()

    print("Calculating safe volumes...")
    volume_analyzer.calculate_safe_volumes()

    print("\nAverage ETF Trading Volumes:")
    for etf, avg_volume in volume_analyzer.average_volumes.items():
        print(f"{etf}: {avg_volume:,.0f}")

    print("\nSafe Trading Volumes:")
    safe_volumes = volume_analyzer.get_safe_volumes()
    for etf, safe_vol in safe_volumes.items():
        print(f"{etf}: {safe_vol}")

    # Log in to Zerodha
    zerodha = ZerodhaLogin("DXU151", "Pratibha", "FLJBDJNEBOIMZZZPE25YYYR72Y2B2IAP")
    session, enctoken = zerodha.login()

    # Ensure successful login before proceeding
    if not enctoken:
        print("Zerodha login failed. Exiting...")
        return  

    # Initialize ZerodhaMargin with correct headers
    headers = {
        "Authorization": f"enctoken {enctoken}",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36",
        "Referer": "https://kite.zerodha.com/dashboard",
        "Accept-Language": "en-US,en;q=0.6",
        "Content-type": "application/x-www-form-urlencoded",
        "Accept": "application/json, text/plain, */*",
    }

    zerodha_margin = ZerodhaMargin(session, enctoken, headers)
    equity_margin, commodity_margin = zerodha_margin.fetch_margin()

    print("\nZerodha Margin Details:")
    print(f"Equity Margin: {equity_margin}")
    print(f"Commodity Margin: {commodity_margin}")

    # Initialize VolumeCalculation with necessary data
    volume_calculator = VolumeCalculation(equity_margin, predicted_prices, safe_volumes)

    # Calculate adjusted quantities
    adjusted_quantities = volume_calculator.execute_volume_calculation()

    print("\nAdjusted Quantities for Each ETF:")
    for etf, adjusted_quantity in adjusted_quantities.items():
        print(f"{etf}: {adjusted_quantity}")

if __name__ == "__main__":
    main()

# %% [raw]
# import yfinance as yf
# from datetime import datetime
# import numpy as np
# import pandas as pd
# import requests
# import pyotp
# from sklearn.linear_model import LinearRegression
#
# import time
# from datetime import datetime, timedelta
#
# class TimeUtils:
#     """Utility class for time-related functions."""
#
#     @staticmethod
#     def get_current_datetime_hh_mm_ss_ms():
#         """Returns the current datetime with milliseconds."""
#         return datetime.now()
#
#     @staticmethod
#     def get_current_datetime_hh_mm_ss():
#         """Returns the current time in HH:MM:SS format."""
#         return datetime.now().strftime("%H:%M:%S")
#
#     @staticmethod
#     def print_current_datetime_hh_mm_ss_ms():
#         """Prints the current datetime with milliseconds."""
#         print(TimeUtils.get_current_datetime_hh_mm_ss_ms().strftime("%H:%M:%S.%f"))
#
#     @staticmethod
#     def print_current_datetime_hh_mm_ss():
#         """Prints the current time in HH:MM:SS format."""
#         print(TimeUtils.get_current_datetime_hh_mm_ss())
#
#     @staticmethod
#     def execute_at_precise_time(target_time, func):
#         """
#         Executes a given function at a precise target time.
#
#         :param target_time: Datetime object specifying the execution time.
#         :param func: Function to execute.
#         """
#         delay = (target_time - datetime.now()).total_seconds()
#
#         # Sleep until just before the target time
#         time.sleep(max(0, delay - 0.1))
#
#         # Busy-wait until the exact moment
#         while datetime.now() < target_time:
#             pass
#
#         func()
#
# class ETFPricePredictor:
#     """Predicts ETF opening prices using linear regression based on underlying index data."""
#
#     def __init__(self, assets, start_date="2025-01-01"):
#         self.assets = assets
#         self.start_date = start_date
#         self.end_date = datetime.today().strftime("%Y-%m-%d")
#         self.closing_prices = None
#         self.opening_prices = {}
#         self.models = {}
#
#     def fetch_closing_prices(self):
#         """Fetches daily closing prices for underlying indices and ETFs."""
#         symbols = list(self.assets.keys()) + list(self.assets.values())
#         try:
#             data = yf.download(symbols, start=self.start_date, end=self.end_date)["Close"]
#             data.dropna(inplace=True)
#             self.closing_prices = data
#         except Exception as e:
#             print(f"Error fetching closing prices: {e}")
#
#     def fetch_opening_prices(self):
#         """Fetches today's opening prices for the underlying indices."""
#         for index in self.assets.keys():
#             try:
#                 data = yf.Ticker(index).history(period="1d")
#                 self.opening_prices[index] = data["Open"].iloc[0] if not data.empty else None
#             except Exception as e:
#                 print(f"Error fetching opening price for {index}: {e}")
#                 self.opening_prices[index] = None
#
#     def train_models(self):
#         """Trains a Linear Regression model for each ETF based on its underlying index."""
#         if self.closing_prices is None:
#             print("Error: Closing prices not available. Fetch data first.")
#             return
#
#         for index, etf in self.assets.items():
#             try:
#                 X = self.closing_prices[index].values.reshape(-1, 1)
#                 y = self.closing_prices[etf].values.reshape(-1, 1)
#
#                 model = LinearRegression()
#                 model.fit(X, y)
#                 self.models[etf] = model
#             except Exception as e:
#                 print(f"Error training model for {etf}: {e}")
#
#     def predict_opening_prices(self):
#         """Predicts today's opening price for ETFs using the trained regression models."""
#         predicted_openings = {}
#         for index, etf in self.assets.items():
#             if self.opening_prices.get(index) is not None and etf in self.models:
#                 try:
#                     predicted_openings[etf] = self.models[etf].predict(np.array([[self.opening_prices[index]]]))[0][0]
#                 except Exception as e:
#                     print(f"Error predicting opening price for {etf}: {e}")
#                     predicted_openings[etf] = None
#             else:
#                 predicted_openings[etf] = "Market Closed or Model Not Available"
#         return predicted_openings
#
# class ETFVolumeAnalyzer:
#     """Analyzes ETF trading volume and calculates safe volume."""
#
#     def __init__(self, assets, start_date="2025-01-01"):
#         self.etf_symbols = list(assets.values())
#         self.start_date = start_date
#         self.end_date = datetime.today().strftime("%Y-%m-%d")
#         self.average_volumes = {}
#         self.safe_volumes = {}
#
#     def fetch_average_volumes(self):
#         """Fetches daily ETF trading volumes and calculates the average volume for each ETF."""
#         try:
#             volume_data = yf.download(self.etf_symbols, start=self.start_date, end=self.end_date)["Volume"]
#             self.average_volumes = volume_data.mean().to_dict()
#         except Exception as e:
#             print(f"Error fetching ETF volumes: {e}")
#
#     def calculate_safe_volumes(self):
#         """Calculates safe volume using the formula: Average Volume / 4500."""
#         for etf, avg_volume in self.average_volumes.items():
#             self.safe_volumes[etf] = int(avg_volume / 4500)
#             # 6.25 hours = 22,500 seconds | 22500/5 = 4500
#
#     def get_safe_volumes(self):
#         """Returns the calculated safe volumes."""
#         return self.safe_volumes
#
# class ZerodhaLogin:
#     """Handles Zerodha Kite login and maintains a session for order placement."""
#
#     LOGIN_URL = "https://kite.zerodha.com/api/login"
#     TOTP_URL = "https://kite.zerodha.com/api/twofa"
#
#     def __init__(self, username, password, totp_key):
#         self.username = username
#         self.password = password
#         self.totp_key = totp_key
#         self.session = requests.Session()
#         self.enctoken = None
#         self.headers = None
#
#     def login(self):
#         """Performs login using Zerodha credentials and TOTP authentication."""
#         try:
#             res1 = self.session.post(self.LOGIN_URL, data={
#                 "user_id": self.username,
#                 "password": self.password,
#                 "type": "user_id"
#             })
#             res1.raise_for_status()
#             loginRes = res1.json()
#
#             if "data" not in loginRes or "request_id" not in loginRes["data"]:
#                 raise ValueError("Login failed: Invalid response from server")
#
#             totp_value = pyotp.TOTP(self.totp_key).now()
#             finalRes = self.session.post(self.TOTP_URL, data={
#                 "request_id": loginRes["data"]["request_id"],
#                 "twofa_value": totp_value,
#                 "user_id": loginRes["data"]["user_id"],
#                 "twofa_type": "totp"
#             })
#             finalRes.raise_for_status()
#             authRes = finalRes.json()
#
#             if "status" not in authRes or authRes["status"] != "success":
#                 raise ValueError("TOTP Authentication failed")
#
#             self.enctoken = self.session.cookies.get_dict().get("enctoken", None)
#             if not self.enctoken:
#                 raise ValueError("Failed to retrieve enctoken")
#
#             print("Login successful!")
#             return self.session, self.enctoken
#
#         except requests.exceptions.RequestException as e:
#             print(f"HTTP Request Failed: {e}")
#         except ValueError as ve:
#             print(f"Error: {ve}")
#
# class ZerodhaMargin:
#     """Fetches margin details from Zerodha Kite API using an existing session."""
#
#     MARGIN_URL = "https://kite.zerodha.com/oms/user/margins"
#
#     def __init__(self, session, enctoken, headers):
#         """Initialize with an existing authenticated session and headers."""
#         self.session = session
#         self.enctoken = enctoken
#         self.headers = headers
#
#         if not self.enctoken or not self.headers:
#             raise ValueError("Authentication token or headers are missing. Cannot fetch margin data.")
#
#     def fetch_margin(self):
#         """Fetches margin details and extracts net margin for equity and commodity."""
#         try:
#             response = self.session.get(self.MARGIN_URL, headers=self.headers)
#             response.raise_for_status()
#             data = response.json()
#
#             equity_margin = data["data"]["equity"]["net"]
#             commodity_margin = data["data"]["commodity"]["net"]
#
#             return equity_margin, commodity_margin
#
#         except requests.exceptions.RequestException as e:
#             print(f"HTTP Request Failed: {e}")
#             return None, None
#
# class VolumeCalculation:
#     """Calculates adjusted trading volumes based on margin and safe volumes."""
#
#     def __init__(self, equity_margin, predicted_openings, safe_volumes):
#         self.equity_margin = equity_margin
#         self.predicted_openings = predicted_openings
#         self.safe_volumes = safe_volumes
#
#     def calculate_leveraged_margin(self):
#         """Calculates leveraged margin as equity margin multiplied by 5."""
#         return self.equity_margin * 5
#
#     def calculate_discount_margin(self):
#         """Calculates discounted margin as (equity margin * 5) - 5% of equity margin."""
#         return (self.equity_margin * 5) - (self.equity_margin * 5 * 0.05)
#
#     def calculate_trade_values(self):
#         """Calculates trade value for each ETF as predicted_openings * safe_volumes."""
#         return {etf: self.predicted_openings[etf] * self.safe_volumes[etf] for etf in self.safe_volumes}
#
#     def calculate_total_trade_value(self, trade_values):
#         """Calculates total trade value as the sum of all individual trade values."""
#         return sum(trade_values.values())
#
#     def calculate_allocation_ratio(self, discount_margin, total_trade_value):
#         """Calculates allocation ratio as discount_margin / total_trade_value."""
#         return discount_margin / total_trade_value if total_trade_value > 0 else 0
#
#     def calculate_adjusted_quantities(self, allocation_ratio):
#         """Calculates adjusted quantity for each ETF as allocation_ratio * safe_volumes."""
#         return {etf: int(allocation_ratio * self.safe_volumes[etf]) for etf in self.safe_volumes}
#
#     def execute_volume_calculation(self):
#         """Executes all calculations and returns adjusted quantities."""
#         discount_margin = self.calculate_discount_margin()  # Use discount margin instead of leveraged margin
#         trade_values = self.calculate_trade_values()
#         total_trade_value = self.calculate_total_trade_value(trade_values)
#         allocation_ratio = self.calculate_allocation_ratio(discount_margin, total_trade_value)
#         adjusted_quantities = self.calculate_adjusted_quantities(allocation_ratio)
#
#         return adjusted_quantities
#
#
#
# def main():
#     """Main execution function"""
#     assets = {
#         "^NSEI": "NIFTYBEES.NS",      # Nifty 50 → Niftybees
#         "^NSMIDCP": "JUNIORBEES.NS",   # Nifty Next 50 → Junior Bees
#         "^NSEBANK": "BANKBEES.NS"      # Nifty Bank → Bank Bees
#     }
#
#     # Predict ETF opening prices
#     predictor = ETFPricePredictor(assets)
#
#     print("Fetching historical closing prices...")
#     predictor.fetch_closing_prices()
#
#     print("Fetching today's opening prices...")
#     predictor.fetch_opening_prices()
#
#     print("Training regression models...")
#     predictor.train_models()
#
#     print("\nToday's Opening Prices:")
#     for index, price in predictor.opening_prices.items():
#         print(f"{index}: {price}")
#
#     print("\nPredicted ETF Opening Prices:")
#     predicted_prices = predictor.predict_opening_prices()
#     for etf, price in predicted_prices.items():
#         print(f"{etf}: {price:.2f}" if isinstance(price, float) else f"{etf}: {price}")
#
#     # Analyze ETF trading volumes
#     volume_analyzer = ETFVolumeAnalyzer(assets)
#
#     print("\nFetching ETF volume data...")
#     volume_analyzer.fetch_average_volumes()
#
#     print("Calculating safe volumes...")
#     volume_analyzer.calculate_safe_volumes()
#
#     print("\nAverage ETF Trading Volumes:")
#     for etf, avg_volume in volume_analyzer.average_volumes.items():
#         print(f"{etf}: {avg_volume:,.0f}")
#
#     print("\nSafe Trading Volumes:")
#     safe_volumes = volume_analyzer.get_safe_volumes()
#     for etf, safe_vol in safe_volumes.items():
#         print(f"{etf}: {safe_vol}")
#
#     # Log in to Zerodha
#     zerodha = ZerodhaLogin("DXU151", "Pratibha", "FLJBDJNEBOIMZZZPE25YYYR72Y2B2IAP")
#     session, enctoken = zerodha.login()
#
#     # Ensure successful login before proceeding
#     if not enctoken:
#         print("Zerodha login failed. Exiting...")
#         return
#
#     # Initialize ZerodhaMargin with correct headers
#     headers = {
#         "Authorization": f"enctoken {enctoken}",
#         "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36",
#         "Referer": "https://kite.zerodha.com/dashboard",
#         "Accept-Language": "en-US,en;q=0.6",
#         "Content-type": "application/x-www-form-urlencoded",
#         "Accept": "application/json, text/plain, */*",
#     }
#
#     zerodha_margin = ZerodhaMargin(session, enctoken, headers)
#     equity_margin, commodity_margin = zerodha_margin.fetch_margin()
#
#     print("\nZerodha Margin Details:")
#     print(f"Equity Margin: {equity_margin}")
#     print(f"Commodity Margin: {commodity_margin}")
#
#     # Initialize VolumeCalculation with necessary data
#     volume_calculator = VolumeCalculation(equity_margin, predicted_prices, safe_volumes)
#
#     # Calculate adjusted quantities
#     adjusted_quantities = volume_calculator.execute_volume_calculation()
#
#     print("\nAdjusted Quantities for Each ETF:")
#     for etf, adjusted_quantity in adjusted_quantities.items():
#         print(f"{etf}: {adjusted_quantity}")
#
# if __name__ == "__main__":
#     main()
#
# act as a very clever python programmer and guide me further. create a class DataStore.
# symbols are in the form of "NIFTYBEES.NS" i want symbols in the form of "NIFTYBEES" write function for this by name "format_symbol".
# create function to create an array which stores three datapoints for each etf which i generated in above code. which are symbol, adjusted quantites, predicted price. use variable names as a symbol_a, quantity_a, price_a respectively.

# %%
class DataStore:
    """Class to store symbols, adjusted quantities, and predicted prices."""

    def __init__(self):
        self.data = []

    def format_symbol(self, symbol):
        """Formats the symbol by removing '.NS' from the end."""
        return symbol.split('.')[0]

    def add_data(self, symbol, adjusted_quantity, predicted_price):
        """Adds a new entry to the data store."""
        formatted_symbol = self.format_symbol(symbol)
        self.data.append({
            'symbol_a': formatted_symbol,
            'quantity_a': adjusted_quantity,
            'price_a': predicted_price
        })

    def get_data(self):
        """Returns all stored data."""
        return self.data

# %%
def main():
    """Main execution function"""
    assets = {
        "^NSEI": "NIFTYBEES.NS",      # Nifty 50 → Niftybees
        "^NSMIDCP": "JUNIORBEES.NS",   # Nifty Next 50 → Junior Bees
        "^NSEBANK": "BANKBEES.NS"      # Nifty Bank → Bank Bees
    }

    # Predict ETF opening prices
    predictor = ETFPricePredictor(assets)
    
    print("Fetching historical closing prices...")
    predictor.fetch_closing_prices()

    print("Fetching today's opening prices...")
    predictor.fetch_opening_prices()

    print("Training regression models...")
    predictor.train_models()

    print("\nToday's Opening Prices:")
    for index, price in predictor.opening_prices.items():
        print(f"{index}: {price}")

    print("\nPredicted ETF Opening Prices:")
    predicted_prices = predictor.predict_opening_prices()
    for etf, price in predicted_prices.items():
        print(f"{etf}: {price:.2f}" if isinstance(price, float) else f"{etf}: {price}")

    # Analyze ETF trading volumes
    volume_analyzer = ETFVolumeAnalyzer(assets)
    
    print("\nFetching ETF volume data...")
    volume_analyzer.fetch_average_volumes()

    print("Calculating safe volumes...")
    volume_analyzer.calculate_safe_volumes()

    print("\nAverage ETF Trading Volumes:")
    for etf, avg_volume in volume_analyzer.average_volumes.items():
        print(f"{etf}: {avg_volume:,.0f}")

    print("\nSafe Trading Volumes:")
    safe_volumes = volume_analyzer.get_safe_volumes()
    for etf, safe_vol in safe_volumes.items():
        print(f"{etf}: {safe_vol}")

    # Log in to Zerodha
    zerodha = ZerodhaLogin("DXU151", "Pratibha", "FLJBDJNEBOIMZZZPE25YYYR72Y2B2IAP")
    session, enctoken = zerodha.login()

    # Ensure successful login before proceeding
    if not enctoken:
        print("Zerodha login failed. Exiting...")
        return  

    # Initialize ZerodhaMargin with correct headers
    headers = {
        "Authorization": f"enctoken {enctoken}",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36",
        "Referer": "https://kite.zerodha.com/dashboard",
        "Accept-Language": "en-US,en;q=0.6",
        "Content-type": "application/x-www-form-urlencoded",
        "Accept": "application/json, text/plain, */*",
    }

    zerodha_margin = ZerodhaMargin(session, enctoken, headers)
    equity_margin, commodity_margin = zerodha_margin.fetch_margin()

    print("\nZerodha Margin Details:")
    print(f"Equity Margin: {equity_margin}")
    print(f"Commodity Margin: {commodity_margin}")

    # Initialize VolumeCalculation with necessary data
    volume_calculator = VolumeCalculation(equity_margin, predicted_prices, safe_volumes)

    # Calculate adjusted quantities
    adjusted_quantities = volume_calculator.execute_volume_calculation()

    print("\nAdjusted Quantities for Each ETF:")
    for etf, adjusted_quantity in adjusted_quantities.items():
        print(f"{etf}: {adjusted_quantity}")

    # Create DataStore and add data
    datastore = DataStore()
    
    for etf, adjusted_quantity in adjusted_quantities.items():
        predicted_price = predicted_prices.get(etf, None)
        datastore.add_data(etf, adjusted_quantity, predicted_price)

    # Get and display the stored data
    print("\nStored Data:")
    data = datastore.get_data()
    for entry in data:
        print(f"Symbol: {entry['symbol_a']}, Quantity: {entry['quantity_a']}, Predicted Price: {entry['price_a']}")

if __name__ == "__main__":
    main()

# %% [raw]
# manual update

# %%
import yfinance as yf
from datetime import datetime
import numpy as np
import pandas as pd
import requests
import pyotp
from sklearn.linear_model import LinearRegression

import time
from datetime import datetime, timedelta

class TimeUtils:
    """Utility class for time-related functions."""
    
    @staticmethod
    def get_current_datetime_hh_mm_ss_ms():
        """Returns the current datetime with milliseconds."""
        return datetime.now()

    @staticmethod
    def get_current_datetime_hh_mm_ss():
        """Returns the current time in HH:MM:SS format."""
        return datetime.now().strftime("%H:%M:%S")

    @staticmethod
    def print_current_datetime_hh_mm_ss_ms():
        """Prints the current datetime with milliseconds."""
        print(TimeUtils.get_current_datetime_hh_mm_ss_ms().strftime("%H:%M:%S.%f"))

    @staticmethod
    def print_current_datetime_hh_mm_ss():
        """Prints the current time in HH:MM:SS format."""
        print(TimeUtils.get_current_datetime_hh_mm_ss())

    @staticmethod
    def execute_at_precise_time(target_time, func):
        """
        Executes a given function at a precise target time.

        :param target_time: Datetime object specifying the execution time.
        :param func: Function to execute.
        """
        delay = (target_time - datetime.now()).total_seconds()
        
        # Sleep until just before the target time
        time.sleep(max(0, delay - 0.1))
        
        # Busy-wait until the exact moment
        while datetime.now() < target_time:
            pass

        func()

class ETFPricePredictor:
    """Predicts ETF opening prices using linear regression based on underlying index data."""

    def __init__(self, assets, start_date="2025-01-01"):
        self.assets = assets
        self.start_date = start_date
        self.end_date = datetime.today().strftime("%Y-%m-%d")
        self.closing_prices = None
        self.opening_prices = {}
        self.models = {}

    def fetch_closing_prices(self):
        """Fetches daily closing prices for underlying indices and ETFs."""
        symbols = list(self.assets.keys()) + list(self.assets.values())  
        try:
            data = yf.download(symbols, start=self.start_date, end=self.end_date)["Close"]
            data.dropna(inplace=True)  
            self.closing_prices = data
        except Exception as e:
            print(f"Error fetching closing prices: {e}")

    def fetch_opening_prices(self):
        """Fetches today's opening prices for the underlying indices."""
        for index in self.assets.keys():
            try:
                data = yf.Ticker(index).history(period="1d")
                self.opening_prices[index] = data["Open"].iloc[0] if not data.empty else None
            except Exception as e:
                print(f"Error fetching opening price for {index}: {e}")
                self.opening_prices[index] = None  

    def train_models(self):
        """Trains a Linear Regression model for each ETF based on its underlying index."""
        if self.closing_prices is None:
            print("Error: Closing prices not available. Fetch data first.")
            return
        
        for index, etf in self.assets.items():
            try:
                X = self.closing_prices[index].values.reshape(-1, 1)  
                y = self.closing_prices[etf].values.reshape(-1, 1)  
                
                model = LinearRegression()
                model.fit(X, y)  
                self.models[etf] = model
            except Exception as e:
                print(f"Error training model for {etf}: {e}")

    def predict_opening_prices(self):
        """Predicts today's opening price for ETFs using the trained regression models."""
        predicted_openings = {}
        for index, etf in self.assets.items():
            if self.opening_prices.get(index) is not None and etf in self.models:
                try:
                    predicted_openings[etf] = self.models[etf].predict(np.array([[self.opening_prices[index]]]))[0][0]
                except Exception as e:
                    print(f"Error predicting opening price for {etf}: {e}")
                    predicted_openings[etf] = None
            else:
                predicted_openings[etf] = "Market Closed or Model Not Available"
        return predicted_openings

class ETFVolumeAnalyzer:
    """Analyzes ETF trading volume and calculates safe volume."""

    def __init__(self, assets, start_date="2025-01-01"):
        self.etf_symbols = list(assets.values())  
        self.start_date = start_date
        self.end_date = datetime.today().strftime("%Y-%m-%d")
        self.average_volumes = {}
        self.safe_volumes = {}

    def fetch_average_volumes(self):
        """Fetches daily ETF trading volumes and calculates the average volume for each ETF."""
        try:
            volume_data = yf.download(self.etf_symbols, start=self.start_date, end=self.end_date)["Volume"]
            self.average_volumes = volume_data.mean().to_dict()  
        except Exception as e:
            print(f"Error fetching ETF volumes: {e}")

    def calculate_safe_volumes(self):
        """Calculates safe volume using the formula: Average Volume / 4500."""
        for etf, avg_volume in self.average_volumes.items():
            self.safe_volumes[etf] = int(avg_volume / 4500)  
            # 6.25 hours = 22,500 seconds | 22500/5 = 4500

    def get_safe_volumes(self):
        """Returns the calculated safe volumes."""
        return self.safe_volumes

class ZerodhaLogin:
    """Handles Zerodha Kite login and maintains a session for order placement."""
    
    LOGIN_URL = "https://kite.zerodha.com/api/login"
    TOTP_URL = "https://kite.zerodha.com/api/twofa"

    def __init__(self, username, password, totp_key):
        self.username = username
        self.password = password
        self.totp_key = totp_key
        self.session = requests.Session()
        self.enctoken = None  
        self.headers = None  

    def login(self):
        """Performs login using Zerodha credentials and TOTP authentication."""
        try:
            res1 = self.session.post(self.LOGIN_URL, data={
                "user_id": self.username,
                "password": self.password,
                "type": "user_id"
            })
            res1.raise_for_status()  
            loginRes = res1.json()

            if "data" not in loginRes or "request_id" not in loginRes["data"]:
                raise ValueError("Login failed: Invalid response from server")

            totp_value = pyotp.TOTP(self.totp_key).now()
            finalRes = self.session.post(self.TOTP_URL, data={
                "request_id": loginRes["data"]["request_id"],
                "twofa_value": totp_value,
                "user_id": loginRes["data"]["user_id"],
                "twofa_type": "totp"
            })
            finalRes.raise_for_status()
            authRes = finalRes.json()

            if "status" not in authRes or authRes["status"] != "success":
                raise ValueError("TOTP Authentication failed")

            self.enctoken = self.session.cookies.get_dict().get("enctoken", None)
            if not self.enctoken:
                raise ValueError("Failed to retrieve enctoken")

            print("Login successful!")
            return self.session, self.enctoken

        except requests.exceptions.RequestException as e:
            print(f"HTTP Request Failed: {e}")
        except ValueError as ve:
            print(f"Error: {ve}")

class ZerodhaMargin:
    """Fetches margin details from Zerodha Kite API using an existing session."""

    MARGIN_URL = "https://kite.zerodha.com/oms/user/margins"

    def __init__(self, session, enctoken, headers):
        """Initialize with an existing authenticated session and headers."""
        self.session = session
        self.enctoken = enctoken
        self.headers = headers

        if not self.enctoken or not self.headers:
            raise ValueError("Authentication token or headers are missing. Cannot fetch margin data.")

    def fetch_margin(self):
        """Fetches margin details and extracts net margin for equity and commodity."""
        try:
            response = self.session.get(self.MARGIN_URL, headers=self.headers)
            response.raise_for_status()
            data = response.json()

            equity_margin = data["data"]["equity"]["net"]
            commodity_margin = data["data"]["commodity"]["net"]

            return equity_margin, commodity_margin

        except requests.exceptions.RequestException as e:
            print(f"HTTP Request Failed: {e}")
            return None, None

class VolumeCalculation:
    """Calculates adjusted trading volumes based on margin and safe volumes."""

    def __init__(self, equity_margin, predicted_openings, safe_volumes):
        self.equity_margin = equity_margin
        self.predicted_openings = predicted_openings
        self.safe_volumes = safe_volumes

    def calculate_leveraged_margin(self):
        """Calculates leveraged margin as equity margin multiplied by 5."""
        return self.equity_margin * 5

    def calculate_discount_margin(self):
        """Calculates discounted margin as (equity margin * 5) - 5% of equity margin."""
        return (self.equity_margin * 5) - (self.equity_margin * 5 * 0.05)

    def calculate_trade_values(self):
        """Calculates trade value for each ETF as predicted_openings * safe_volumes."""
        return {etf: self.predicted_openings[etf] * self.safe_volumes[etf] for etf in self.safe_volumes}

    def calculate_total_trade_value(self, trade_values):
        """Calculates total trade value as the sum of all individual trade values."""
        return sum(trade_values.values())

    def calculate_allocation_ratio(self, discount_margin, total_trade_value):
        """Calculates allocation ratio as discount_margin / total_trade_value."""
        return discount_margin / total_trade_value if total_trade_value > 0 else 0

    def calculate_adjusted_quantities(self, allocation_ratio):
        """Calculates adjusted quantity for each ETF as allocation_ratio * safe_volumes."""
        return {etf: int(allocation_ratio * self.safe_volumes[etf]) for etf in self.safe_volumes}

    def execute_volume_calculation(self):
        """Executes all calculations and returns adjusted quantities."""
        discount_margin = self.calculate_discount_margin()  # Use discount margin instead of leveraged margin
        trade_values = self.calculate_trade_values()
        total_trade_value = self.calculate_total_trade_value(trade_values)
        allocation_ratio = self.calculate_allocation_ratio(discount_margin, total_trade_value)
        adjusted_quantities = self.calculate_adjusted_quantities(allocation_ratio)
        
        return adjusted_quantities

class DataStore:
    """Class to store symbols, adjusted quantities, and predicted prices."""

    def __init__(self):
        self.data = []

    def format_symbol(self, symbol):
        """Formats the symbol by removing '.NS' from the end."""
        return symbol.split('.')[0]

    def add_data(self, symbol, adjusted_quantity, predicted_price):
        """Adds a new entry to the data store."""
        formatted_symbol = self.format_symbol(symbol)
        self.data.append({
            'symbol_a': formatted_symbol,
            'quantity_a': adjusted_quantity,
            'price_a': predicted_price
        })

    def get_data(self):
        """Returns all stored data."""
        return self.data
    
def main():
    """Main execution function"""
    assets = {
        "^NSEI": "NIFTYBEES.NS",      # Nifty 50 → Niftybees
        "^NSMIDCP": "JUNIORBEES.NS",   # Nifty Next 50 → Junior Bees
        "^NSEBANK": "BANKBEES.NS"      # Nifty Bank → Bank Bees
    }

    # Predict ETF opening prices
    predictor = ETFPricePredictor(assets)
    
    print("Fetching historical closing prices...")
    predictor.fetch_closing_prices()

    print("Fetching today's opening prices...")
    predictor.fetch_opening_prices()

    print("Training regression models...")
    predictor.train_models()

    print("\nToday's Opening Prices:")
    for index, price in predictor.opening_prices.items():
        print(f"{index}: {price}")

    print("\nPredicted ETF Opening Prices:")
    predicted_prices = predictor.predict_opening_prices()
    for etf, price in predicted_prices.items():
        print(f"{etf}: {price:.2f}" if isinstance(price, float) else f"{etf}: {price}")

    # Analyze ETF trading volumes
    volume_analyzer = ETFVolumeAnalyzer(assets)
    
    print("\nFetching ETF volume data...")
    volume_analyzer.fetch_average_volumes()

    print("Calculating safe volumes...")
    volume_analyzer.calculate_safe_volumes()

    print("\nAverage ETF Trading Volumes:")
    for etf, avg_volume in volume_analyzer.average_volumes.items():
        print(f"{etf}: {avg_volume:,.0f}")

    print("\nSafe Trading Volumes:")
    safe_volumes = volume_analyzer.get_safe_volumes()
    for etf, safe_vol in safe_volumes.items():
        print(f"{etf}: {safe_vol}")

    # Log in to Zerodha
    zerodha = ZerodhaLogin("DXU151", "Pratibha", "FLJBDJNEBOIMZZZPE25YYYR72Y2B2IAP")
    session, enctoken = zerodha.login()

    # Ensure successful login before proceeding
    if not enctoken:
        print("Zerodha login failed. Exiting...")
        return  

    # Initialize ZerodhaMargin with correct headers
    headers = {
        "Authorization": f"enctoken {enctoken}",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36",
        "Referer": "https://kite.zerodha.com/dashboard",
        "Accept-Language": "en-US,en;q=0.6",
        "Content-type": "application/x-www-form-urlencoded",
        "Accept": "application/json, text/plain, */*",
    }

    zerodha_margin = ZerodhaMargin(session, enctoken, headers)
    equity_margin, commodity_margin = zerodha_margin.fetch_margin()

    print("\nZerodha Margin Details:")
    print(f"Equity Margin: {equity_margin}")
    print(f"Commodity Margin: {commodity_margin}")

    # Initialize VolumeCalculation with necessary data
    volume_calculator = VolumeCalculation(equity_margin, predicted_prices, safe_volumes)

    # Calculate adjusted quantities
    adjusted_quantities = volume_calculator.execute_volume_calculation()

    print("\nAdjusted Quantities for Each ETF:")
    for etf, adjusted_quantity in adjusted_quantities.items():
        print(f"{etf}: {adjusted_quantity}")

    # Create DataStore and add data
    datastore = DataStore()
    
    for etf, adjusted_quantity in adjusted_quantities.items():
        predicted_price = predicted_prices.get(etf, None)
        datastore.add_data(etf, adjusted_quantity, predicted_price)

    # Get and display the stored data
    print("\nStored Data:")
    data = datastore.get_data()
    for entry in data:
        print(f"Symbol: {entry['symbol_a']}, Quantity: {entry['quantity_a']}, Predicted Price: {entry['price_a']}")

if __name__ == "__main__":
    main()

# %% [raw]
# above code + update - round off prices to 2 decimal places. not for printing, in array only.

# %%
import yfinance as yf
from datetime import datetime
import numpy as np
import pandas as pd
import requests
import pyotp
from sklearn.linear_model import LinearRegression

import time
from datetime import datetime, timedelta

class TimeUtils:
    """Utility class for time-related functions."""
    
    @staticmethod
    def get_current_datetime_hh_mm_ss_ms():
        """Returns the current datetime with milliseconds."""
        return datetime.now()

    @staticmethod
    def get_current_datetime_hh_mm_ss():
        """Returns the current time in HH:MM:SS format."""
        return datetime.now().strftime("%H:%M:%S")

    @staticmethod
    def print_current_datetime_hh_mm_ss_ms():
        """Prints the current datetime with milliseconds."""
        print(TimeUtils.get_current_datetime_hh_mm_ss_ms().strftime("%H:%M:%S.%f"))

    @staticmethod
    def print_current_datetime_hh_mm_ss():
        """Prints the current time in HH:MM:SS format."""
        print(TimeUtils.get_current_datetime_hh_mm_ss())

    @staticmethod
    def execute_at_precise_time(target_time, func):
        """
        Executes a given function at a precise target time.

        :param target_time: Datetime object specifying the execution time.
        :param func: Function to execute.
        """
        delay = (target_time - datetime.now()).total_seconds()
        
        # Sleep until just before the target time
        time.sleep(max(0, delay - 0.1))
        
        # Busy-wait until the exact moment
        while datetime.now() < target_time:
            pass

        func()

class ETFPricePredictor:
    """Predicts ETF opening prices using linear regression based on underlying index data."""

    def __init__(self, assets, start_date="2025-01-01"):
        self.assets = assets
        self.start_date = start_date
        self.end_date = datetime.today().strftime("%Y-%m-%d")
        self.closing_prices = None
        self.opening_prices = {}
        self.models = {}

    def fetch_closing_prices(self):
        """Fetches daily closing prices for underlying indices and ETFs."""
        symbols = list(self.assets.keys()) + list(self.assets.values())  
        try:
            data = yf.download(symbols, start=self.start_date, end=self.end_date)["Close"]
            data.dropna(inplace=True)  
            self.closing_prices = data
        except Exception as e:
            print(f"Error fetching closing prices: {e}")

    def fetch_opening_prices(self):
        """Fetches today's opening prices for the underlying indices."""
        for index in self.assets.keys():
            try:
                data = yf.Ticker(index).history(period="1d")
                self.opening_prices[index] = data["Open"].iloc[0] if not data.empty else None
            except Exception as e:
                print(f"Error fetching opening price for {index}: {e}")
                self.opening_prices[index] = None  

    def train_models(self):
        """Trains a Linear Regression model for each ETF based on its underlying index."""
        if self.closing_prices is None:
            print("Error: Closing prices not available. Fetch data first.")
            return
        
        for index, etf in self.assets.items():
            try:
                X = self.closing_prices[index].values.reshape(-1, 1)  
                y = self.closing_prices[etf].values.reshape(-1, 1)  
                
                model = LinearRegression()
                model.fit(X, y)  
                self.models[etf] = model
            except Exception as e:
                print(f"Error training model for {etf}: {e}")

    def predict_opening_prices(self):
        """Predicts today's opening price for ETFs using the trained regression models."""
        predicted_openings = {}
        for index, etf in self.assets.items():
            if self.opening_prices.get(index) is not None and etf in self.models:
                try:
                    predicted_openings[etf] = self.models[etf].predict(np.array([[self.opening_prices[index]]]))[0][0]
                except Exception as e:
                    print(f"Error predicting opening price for {etf}: {e}")
                    predicted_openings[etf] = None
            else:
                predicted_openings[etf] = "Market Closed or Model Not Available"
        return predicted_openings

class ETFVolumeAnalyzer:
    """Analyzes ETF trading volume and calculates safe volume."""

    def __init__(self, assets, start_date="2025-01-01"):
        self.etf_symbols = list(assets.values())  
        self.start_date = start_date
        self.end_date = datetime.today().strftime("%Y-%m-%d")
        self.average_volumes = {}
        self.safe_volumes = {}

    def fetch_average_volumes(self):
        """Fetches daily ETF trading volumes and calculates the average volume for each ETF."""
        try:
            volume_data = yf.download(self.etf_symbols, start=self.start_date, end=self.end_date)["Volume"]
            self.average_volumes = volume_data.mean().to_dict()  
        except Exception as e:
            print(f"Error fetching ETF volumes: {e}")

    def calculate_safe_volumes(self):
        """Calculates safe volume using the formula: Average Volume / 4500."""
        for etf, avg_volume in self.average_volumes.items():
            self.safe_volumes[etf] = int(avg_volume / 4500)  
            # 6.25 hours = 22,500 seconds | 22500/5 = 4500

    def get_safe_volumes(self):
        """Returns the calculated safe volumes."""
        return self.safe_volumes

class ZerodhaLogin:
    """Handles Zerodha Kite login and maintains a session for order placement."""
    
    LOGIN_URL = "https://kite.zerodha.com/api/login"
    TOTP_URL = "https://kite.zerodha.com/api/twofa"

    def __init__(self, username, password, totp_key):
        self.username = username
        self.password = password
        self.totp_key = totp_key
        self.session = requests.Session()
        self.enctoken = None  
        self.headers = None  

    def login(self):
        """Performs login using Zerodha credentials and TOTP authentication."""
        try:
            res1 = self.session.post(self.LOGIN_URL, data={
                "user_id": self.username,
                "password": self.password,
                "type": "user_id"
            })
            res1.raise_for_status()  
            loginRes = res1.json()

            if "data" not in loginRes or "request_id" not in loginRes["data"]:
                raise ValueError("Login failed: Invalid response from server")

            totp_value = pyotp.TOTP(self.totp_key).now()
            finalRes = self.session.post(self.TOTP_URL, data={
                "request_id": loginRes["data"]["request_id"],
                "twofa_value": totp_value,
                "user_id": loginRes["data"]["user_id"],
                "twofa_type": "totp"
            })
            finalRes.raise_for_status()
            authRes = finalRes.json()

            if "status" not in authRes or authRes["status"] != "success":
                raise ValueError("TOTP Authentication failed")

            self.enctoken = self.session.cookies.get_dict().get("enctoken", None)
            if not self.enctoken:
                raise ValueError("Failed to retrieve enctoken")

            print("Login successful!")
            return self.session, self.enctoken

        except requests.exceptions.RequestException as e:
            print(f"HTTP Request Failed: {e}")
        except ValueError as ve:
            print(f"Error: {ve}")

class ZerodhaMargin:
    """Fetches margin details from Zerodha Kite API using an existing session."""

    MARGIN_URL = "https://kite.zerodha.com/oms/user/margins"

    def __init__(self, session, enctoken, headers):
        """Initialize with an existing authenticated session and headers."""
        self.session = session
        self.enctoken = enctoken
        self.headers = headers

        if not self.enctoken or not self.headers:
            raise ValueError("Authentication token or headers are missing. Cannot fetch margin data.")

    def fetch_margin(self):
        """Fetches margin details and extracts net margin for equity and commodity."""
        try:
            response = self.session.get(self.MARGIN_URL, headers=self.headers)
            response.raise_for_status()
            data = response.json()

            equity_margin = data["data"]["equity"]["net"]
            commodity_margin = data["data"]["commodity"]["net"]

            return equity_margin, commodity_margin

        except requests.exceptions.RequestException as e:
            print(f"HTTP Request Failed: {e}")
            return None, None

class VolumeCalculation:
    """Calculates adjusted trading volumes based on margin and safe volumes."""

    def __init__(self, equity_margin, predicted_openings, safe_volumes):
        self.equity_margin = equity_margin
        self.predicted_openings = predicted_openings
        self.safe_volumes = safe_volumes

    def calculate_leveraged_margin(self):
        """Calculates leveraged margin as equity margin multiplied by 5."""
        return self.equity_margin * 5

    def calculate_discount_margin(self):
        """Calculates discounted margin as (equity margin * 5) - 5% of equity margin."""
        return (self.equity_margin * 5) - (self.equity_margin * 5 * 0.05)

    def calculate_trade_values(self):
        """Calculates trade value for each ETF as predicted_openings * safe_volumes."""
        return {etf: self.predicted_openings[etf] * self.safe_volumes[etf] for etf in self.safe_volumes}

    def calculate_total_trade_value(self, trade_values):
        """Calculates total trade value as the sum of all individual trade values."""
        return sum(trade_values.values())

    def calculate_allocation_ratio(self, discount_margin, total_trade_value):
        """Calculates allocation ratio as discount_margin / total_trade_value."""
        return discount_margin / total_trade_value if total_trade_value > 0 else 0

    def calculate_adjusted_quantities(self, allocation_ratio):
        """Calculates adjusted quantity for each ETF as allocation_ratio * safe_volumes."""
        return {etf: int(allocation_ratio * self.safe_volumes[etf]) for etf in self.safe_volumes}

    def execute_volume_calculation(self):
        """Executes all calculations and returns adjusted quantities."""
        discount_margin = self.calculate_discount_margin()  # Use discount margin instead of leveraged margin
        trade_values = self.calculate_trade_values()
        total_trade_value = self.calculate_total_trade_value(trade_values)
        allocation_ratio = self.calculate_allocation_ratio(discount_margin, total_trade_value)
        adjusted_quantities = self.calculate_adjusted_quantities(allocation_ratio)
        
        return adjusted_quantities

class DataStore:
    """Stores data for symbols, adjusted quantities, and predicted prices."""

    def __init__(self):
        self.data = []  # List to hold the data
    
    def format_symbol(self, symbol):
        """Formats the symbol by removing '.NS'."""
        return symbol.split(".")[0]

    def add_data(self, symbol, adjusted_quantity, predicted_price):
        """Adds data to the data list."""
        symbol_a = self.format_symbol(symbol)  # Format symbol
        quantity_a = adjusted_quantity
        price_a = round(predicted_price, 2)  # Round price to 2 decimal places

        self.data.append({
            "symbol_a": symbol_a,
            "quantity_a": quantity_a,
            "price_a": price_a
        })

    def get_data(self):
        """Returns the stored data."""
        return self.data

def main():
    """Main execution function"""
    assets = {
        "^NSEI": "NIFTYBEES.NS",      # Nifty 50 → Niftybees
        "^NSMIDCP": "JUNIORBEES.NS",   # Nifty Next 50 → Junior Bees
        "^NSEBANK": "BANKBEES.NS"      # Nifty Bank → Bank Bees
    }

    # Predict ETF opening prices
    predictor = ETFPricePredictor(assets)
    
    print("Fetching historical closing prices...")
    predictor.fetch_closing_prices()

    print("Fetching today's opening prices...")
    predictor.fetch_opening_prices()

    print("Training regression models...")
    predictor.train_models()

    print("\nToday's Opening Prices:")
    for index, price in predictor.opening_prices.items():
        print(f"{index}: {price}")

    print("\nPredicted ETF Opening Prices:")
    predicted_prices = predictor.predict_opening_prices()
    for etf, price in predicted_prices.items():
        print(f"{etf}: {price:.2f}" if isinstance(price, float) else f"{etf}: {price}")

    # Analyze ETF trading volumes
    volume_analyzer = ETFVolumeAnalyzer(assets)
    
    print("\nFetching ETF volume data...")
    volume_analyzer.fetch_average_volumes()

    print("Calculating safe volumes...")
    volume_analyzer.calculate_safe_volumes()

    print("\nAverage ETF Trading Volumes:")
    for etf, avg_volume in volume_analyzer.average_volumes.items():
        print(f"{etf}: {avg_volume:,.0f}")

    print("\nSafe Trading Volumes:")
    safe_volumes = volume_analyzer.get_safe_volumes()
    for etf, safe_vol in safe_volumes.items():
        print(f"{etf}: {safe_vol}")

    # Log in to Zerodha
    zerodha = ZerodhaLogin("DXU151", "Pratibha", "FLJBDJNEBOIMZZZPE25YYYR72Y2B2IAP")
    session, enctoken = zerodha.login()

    # Ensure successful login before proceeding
    if not enctoken:
        print("Zerodha login failed. Exiting...")
        return  

    # Initialize ZerodhaMargin with correct headers
    headers = {
        "Authorization": f"enctoken {enctoken}",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36",
        "Referer": "https://kite.zerodha.com/dashboard",
        "Accept-Language": "en-US,en;q=0.6",
        "Content-type": "application/x-www-form-urlencoded",
        "Accept": "application/json, text/plain, */*",
    }

    zerodha_margin = ZerodhaMargin(session, enctoken, headers)
    equity_margin, commodity_margin = zerodha_margin.fetch_margin()

    print("\nZerodha Margin Details:")
    print(f"Equity Margin: {equity_margin}")
    print(f"Commodity Margin: {commodity_margin}")

    # Initialize VolumeCalculation with necessary data
    volume_calculator = VolumeCalculation(equity_margin, predicted_prices, safe_volumes)

    # Calculate adjusted quantities
    adjusted_quantities = volume_calculator.execute_volume_calculation()

    print("\nAdjusted Quantities for Each ETF:")
    for etf, adjusted_quantity in adjusted_quantities.items():
        print(f"{etf}: {adjusted_quantity}")

    # Create DataStore and add data
    datastore = DataStore()
    
    for etf, adjusted_quantity in adjusted_quantities.items():
        predicted_price = predicted_prices.get(etf, None)
        datastore.add_data(etf, adjusted_quantity, predicted_price)

    # Get and display the stored data
    print("\nStored Data:")
    data = datastore.get_data()
    for entry in data:
        print(f"Symbol: {entry['symbol_a']}, Quantity: {entry['quantity_a']}, Predicted Price: {entry['price_a']}")

if __name__ == "__main__":
    main()

# %% [raw]
# manual update

# %%
import yfinance as yf
from datetime import datetime
import numpy as np
import pandas as pd
import requests
import pyotp
from sklearn.linear_model import LinearRegression

import time
from datetime import datetime, timedelta

class TimeUtils:
    """Utility class for time-related functions."""
    
    @staticmethod
    def get_current_datetime_hh_mm_ss_ms():
        """Returns the current datetime with milliseconds."""
        return datetime.now()

    @staticmethod
    def get_current_datetime_hh_mm_ss():
        """Returns the current time in HH:MM:SS format."""
        return datetime.now().strftime("%H:%M:%S")

    @staticmethod
    def print_current_datetime_hh_mm_ss_ms():
        """Prints the current datetime with milliseconds."""
        print(TimeUtils.get_current_datetime_hh_mm_ss_ms().strftime("%H:%M:%S.%f"))

    @staticmethod
    def print_current_datetime_hh_mm_ss():
        """Prints the current time in HH:MM:SS format."""
        print(TimeUtils.get_current_datetime_hh_mm_ss())

    @staticmethod
    def execute_at_precise_time(target_time, func):
        """
        Executes a given function at a precise target time.

        :param target_time: Datetime object specifying the execution time.
        :param func: Function to execute.
        """
        delay = (target_time - datetime.now()).total_seconds()
        
        # Sleep until just before the target time
        time.sleep(max(0, delay - 0.1))
        
        # Busy-wait until the exact moment
        while datetime.now() < target_time:
            pass

        func()

class ETFPricePredictor:
    """Predicts ETF opening prices using linear regression based on underlying index data."""

    def __init__(self, assets, start_date="2025-01-01"):
        self.assets = assets
        self.start_date = start_date
        self.end_date = datetime.today().strftime("%Y-%m-%d")
        self.closing_prices = None
        self.opening_prices = {}
        self.models = {}

    def fetch_closing_prices(self):
        """Fetches daily closing prices for underlying indices and ETFs."""
        symbols = list(self.assets.keys()) + list(self.assets.values())  
        try:
            data = yf.download(symbols, start=self.start_date, end=self.end_date)["Close"]
            data.dropna(inplace=True)  
            self.closing_prices = data
        except Exception as e:
            print(f"Error fetching closing prices: {e}")

    def fetch_opening_prices(self):
        """Fetches today's opening prices for the underlying indices."""
        for index in self.assets.keys():
            try:
                data = yf.Ticker(index).history(period="1d")
                self.opening_prices[index] = data["Open"].iloc[0] if not data.empty else None
            except Exception as e:
                print(f"Error fetching opening price for {index}: {e}")
                self.opening_prices[index] = None  

    def train_models(self):
        """Trains a Linear Regression model for each ETF based on its underlying index."""
        if self.closing_prices is None:
            print("Error: Closing prices not available. Fetch data first.")
            return
        
        for index, etf in self.assets.items():
            try:
                X = self.closing_prices[index].values.reshape(-1, 1)  
                y = self.closing_prices[etf].values.reshape(-1, 1)  
                
                model = LinearRegression()
                model.fit(X, y)  
                self.models[etf] = model
            except Exception as e:
                print(f"Error training model for {etf}: {e}")

    def predict_opening_prices(self):
        """Predicts today's opening price for ETFs using the trained regression models."""
        predicted_openings = {}
        for index, etf in self.assets.items():
            if self.opening_prices.get(index) is not None and etf in self.models:
                try:
                    predicted_openings[etf] = self.models[etf].predict(np.array([[self.opening_prices[index]]]))[0][0]
                except Exception as e:
                    print(f"Error predicting opening price for {etf}: {e}")
                    predicted_openings[etf] = None
            else:
                predicted_openings[etf] = "Market Closed or Model Not Available"
        return predicted_openings

class ETFVolumeAnalyzer:
    """Analyzes ETF trading volume and calculates safe volume."""

    def __init__(self, assets, start_date="2025-01-01"):
        self.etf_symbols = list(assets.values())  
        self.start_date = start_date
        self.end_date = datetime.today().strftime("%Y-%m-%d")
        self.average_volumes = {}
        self.safe_volumes = {}

    def fetch_average_volumes(self):
        """Fetches daily ETF trading volumes and calculates the average volume for each ETF."""
        try:
            volume_data = yf.download(self.etf_symbols, start=self.start_date, end=self.end_date)["Volume"]
            self.average_volumes = volume_data.mean().to_dict()  
        except Exception as e:
            print(f"Error fetching ETF volumes: {e}")

    def calculate_safe_volumes(self):
        """Calculates safe volume using the formula: Average Volume / 4500."""
        for etf, avg_volume in self.average_volumes.items():
            self.safe_volumes[etf] = int(avg_volume / 4500)  
            # 6.25 hours = 22,500 seconds | 22500/5 = 4500

    def get_safe_volumes(self):
        """Returns the calculated safe volumes."""
        return self.safe_volumes

class ZerodhaLogin:
    """Handles Zerodha Kite login and maintains a session for order placement."""
    
    LOGIN_URL = "https://kite.zerodha.com/api/login"
    TOTP_URL = "https://kite.zerodha.com/api/twofa"

    def __init__(self, username, password, totp_key):
        self.username = username
        self.password = password
        self.totp_key = totp_key
        self.session = requests.Session()
        self.enctoken = None  
        self.headers = None  

    def login(self):
        """Performs login using Zerodha credentials and TOTP authentication."""
        try:
            res1 = self.session.post(self.LOGIN_URL, data={
                "user_id": self.username,
                "password": self.password,
                "type": "user_id"
            })
            res1.raise_for_status()  
            loginRes = res1.json()

            if "data" not in loginRes or "request_id" not in loginRes["data"]:
                raise ValueError("Login failed: Invalid response from server")

            totp_value = pyotp.TOTP(self.totp_key).now()
            finalRes = self.session.post(self.TOTP_URL, data={
                "request_id": loginRes["data"]["request_id"],
                "twofa_value": totp_value,
                "user_id": loginRes["data"]["user_id"],
                "twofa_type": "totp"
            })
            finalRes.raise_for_status()
            authRes = finalRes.json()

            if "status" not in authRes or authRes["status"] != "success":
                raise ValueError("TOTP Authentication failed")

            self.enctoken = self.session.cookies.get_dict().get("enctoken", None)
            if not self.enctoken:
                raise ValueError("Failed to retrieve enctoken")

            print("Login successful!")
            return self.session, self.enctoken

        except requests.exceptions.RequestException as e:
            print(f"HTTP Request Failed: {e}")
        except ValueError as ve:
            print(f"Error: {ve}")

class ZerodhaMargin:
    """Fetches margin details from Zerodha Kite API using an existing session."""

    MARGIN_URL = "https://kite.zerodha.com/oms/user/margins"

    def __init__(self, session, enctoken, headers):
        """Initialize with an existing authenticated session and headers."""
        self.session = session
        self.enctoken = enctoken
        self.headers = headers

        if not self.enctoken or not self.headers:
            raise ValueError("Authentication token or headers are missing. Cannot fetch margin data.")

    def fetch_margin(self):
        """Fetches margin details and extracts net margin for equity and commodity."""
        try:
            response = self.session.get(self.MARGIN_URL, headers=self.headers)
            response.raise_for_status()
            data = response.json()

            equity_margin = data["data"]["equity"]["net"]
            commodity_margin = data["data"]["commodity"]["net"]

            return equity_margin, commodity_margin

        except requests.exceptions.RequestException as e:
            print(f"HTTP Request Failed: {e}")
            return None, None

class VolumeCalculation:
    """Calculates adjusted trading volumes based on margin and safe volumes."""

    def __init__(self, equity_margin, predicted_openings, safe_volumes):
        self.equity_margin = equity_margin
        self.predicted_openings = predicted_openings
        self.safe_volumes = safe_volumes

    def calculate_leveraged_margin(self):
        """Calculates leveraged margin as equity margin multiplied by 5."""
        return self.equity_margin * 5

    def calculate_discount_margin(self):
        """Calculates discounted margin as (equity margin * 5) - 5% of equity margin."""
        return (self.equity_margin * 5) - (self.equity_margin * 5 * 0.05)

    def calculate_trade_values(self):
        """Calculates trade value for each ETF as predicted_openings * safe_volumes."""
        return {etf: self.predicted_openings[etf] * self.safe_volumes[etf] for etf in self.safe_volumes}

    def calculate_total_trade_value(self, trade_values):
        """Calculates total trade value as the sum of all individual trade values."""
        return sum(trade_values.values())

    def calculate_allocation_ratio(self, discount_margin, total_trade_value):
        """Calculates allocation ratio as discount_margin / total_trade_value."""
        return discount_margin / total_trade_value if total_trade_value > 0 else 0

    def calculate_adjusted_quantities(self, allocation_ratio):
        """Calculates adjusted quantity for each ETF as allocation_ratio * safe_volumes."""
        return {etf: int(allocation_ratio * self.safe_volumes[etf]) for etf in self.safe_volumes}

    def execute_volume_calculation(self):
        """Executes all calculations and returns adjusted quantities."""
        discount_margin = self.calculate_discount_margin()  # Use discount margin instead of leveraged margin
        trade_values = self.calculate_trade_values()
        total_trade_value = self.calculate_total_trade_value(trade_values)
        allocation_ratio = self.calculate_allocation_ratio(discount_margin, total_trade_value)
        adjusted_quantities = self.calculate_adjusted_quantities(allocation_ratio)
        
        return adjusted_quantities

class DataStore:
    """Class to store symbols, adjusted quantities, and predicted prices."""

    def __init__(self):
        self.data = []

    def add_data(self, symbol, adjusted_quantity, predicted_price):
        """Adds a new entry to the data store."""
        self.data.append({
            'symbol_a': symbol,
            'quantity_a': adjusted_quantity,
            'price_a': predicted_price
        })

    def get_data(self):
        """Returns all stored data."""
        return self.data
    
def main():
    """Main execution function"""
    assets = {
        "^NSEI": "NIFTYBEES.NS",      # Nifty 50 → Niftybees
        "^NSMIDCP": "JUNIORBEES.NS",   # Nifty Next 50 → Junior Bees
        "^NSEBANK": "BANKBEES.NS"      # Nifty Bank → Bank Bees
    }

    # Predict ETF opening prices
    predictor = ETFPricePredictor(assets)
    
    print("Fetching historical closing prices...")
    predictor.fetch_closing_prices()

    print("Fetching today's opening prices...")
    predictor.fetch_opening_prices()

    print("Training regression models...")
    predictor.train_models()

    print("\nToday's Opening Prices:")
    for index, price in predictor.opening_prices.items():
        print(f"{index}: {price}")

    print("\nPredicted ETF Opening Prices:")
    predicted_prices = predictor.predict_opening_prices()
    for etf, price in predicted_prices.items():
        print(f"{etf}: {price:.2f}" if isinstance(price, float) else f"{etf}: {price}")

    # Analyze ETF trading volumes
    volume_analyzer = ETFVolumeAnalyzer(assets)
    
    print("\nFetching ETF volume data...")
    volume_analyzer.fetch_average_volumes()

    print("Calculating safe volumes...")
    volume_analyzer.calculate_safe_volumes()

    print("\nAverage ETF Trading Volumes:")
    for etf, avg_volume in volume_analyzer.average_volumes.items():
        print(f"{etf}: {avg_volume:,.0f}")

    print("\nSafe Trading Volumes:")
    safe_volumes = volume_analyzer.get_safe_volumes()
    for etf, safe_vol in safe_volumes.items():
        print(f"{etf}: {safe_vol}")

    # Log in to Zerodha
    zerodha = ZerodhaLogin("DXU151", "Pratibha", "FLJBDJNEBOIMZZZPE25YYYR72Y2B2IAP")
    session, enctoken = zerodha.login()

    # Ensure successful login before proceeding
    if not enctoken:
        print("Zerodha login failed. Exiting...")
        return  

    # Initialize ZerodhaMargin with correct headers
    headers = {
        "Authorization": f"enctoken {enctoken}",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36",
        "Referer": "https://kite.zerodha.com/dashboard",
        "Accept-Language": "en-US,en;q=0.6",
        "Content-type": "application/x-www-form-urlencoded",
        "Accept": "application/json, text/plain, */*",
    }

    zerodha_margin = ZerodhaMargin(session, enctoken, headers)
    equity_margin, commodity_margin = zerodha_margin.fetch_margin()

    print("\nZerodha Margin Details:")
    print(f"Equity Margin: {equity_margin}")
    print(f"Commodity Margin: {commodity_margin}")

    # Initialize VolumeCalculation with necessary data
    volume_calculator = VolumeCalculation(equity_margin, predicted_prices, safe_volumes)

    # Calculate adjusted quantities
    adjusted_quantities = volume_calculator.execute_volume_calculation()

    print("\nAdjusted Quantities for Each ETF:")
    for etf, adjusted_quantity in adjusted_quantities.items():
        print(f"{etf}: {adjusted_quantity}")

    # Create DataStore and add data
    datastore = DataStore()
    
    for etf, adjusted_quantity in adjusted_quantities.items():
        predicted_price = predicted_prices.get(etf, None)
        datastore.add_data(etf, adjusted_quantity, predicted_price)

    # Get and display the stored data
    print("\nStored Data:")
    data = datastore.get_data()
    for entry in data:
        print(f"Symbol: {entry['symbol_a']}, Quantity: {entry['quantity_a']}, Predicted Price: {entry['price_a']}")

if __name__ == "__main__":
    main()

# %% [raw]
# import yfinance as yf
# from datetime import datetime
# import numpy as np
# import pandas as pd
# import requests
# import pyotp
# from sklearn.linear_model import LinearRegression
#
# import time
# from datetime import datetime, timedelta
#
# class TimeUtils:
#     """Utility class for time-related functions."""
#
#     @staticmethod
#     def get_current_datetime_hh_mm_ss_ms():
#         """Returns the current datetime with milliseconds."""
#         return datetime.now()
#
#     @staticmethod
#     def get_current_datetime_hh_mm_ss():
#         """Returns the current time in HH:MM:SS format."""
#         return datetime.now().strftime("%H:%M:%S")
#
#     @staticmethod
#     def print_current_datetime_hh_mm_ss_ms():
#         """Prints the current datetime with milliseconds."""
#         print(TimeUtils.get_current_datetime_hh_mm_ss_ms().strftime("%H:%M:%S.%f"))
#
#     @staticmethod
#     def print_current_datetime_hh_mm_ss():
#         """Prints the current time in HH:MM:SS format."""
#         print(TimeUtils.get_current_datetime_hh_mm_ss())
#
#     @staticmethod
#     def execute_at_precise_time(target_time, func):
#         """
#         Executes a given function at a precise target time.
#
#         :param target_time: Datetime object specifying the execution time.
#         :param func: Function to execute.
#         """
#         delay = (target_time - datetime.now()).total_seconds()
#
#         # Sleep until just before the target time
#         time.sleep(max(0, delay - 0.1))
#
#         # Busy-wait until the exact moment
#         while datetime.now() < target_time:
#             pass
#
#         func()
#
# class ETFPricePredictor:
#     """Predicts ETF opening prices using linear regression based on underlying index data."""
#
#     def __init__(self, assets, start_date="2025-01-01"):
#         self.assets = assets
#         self.start_date = start_date
#         self.end_date = datetime.today().strftime("%Y-%m-%d")
#         self.closing_prices = None
#         self.opening_prices = {}
#         self.models = {}
#
#     def fetch_closing_prices(self):
#         """Fetches daily closing prices for underlying indices and ETFs."""
#         symbols = list(self.assets.keys()) + list(self.assets.values())
#         try:
#             data = yf.download(symbols, start=self.start_date, end=self.end_date)["Close"]
#             data.dropna(inplace=True)
#             self.closing_prices = data
#         except Exception as e:
#             print(f"Error fetching closing prices: {e}")
#
#     def fetch_opening_prices(self):
#         """Fetches today's opening prices for the underlying indices."""
#         for index in self.assets.keys():
#             try:
#                 data = yf.Ticker(index).history(period="1d")
#                 self.opening_prices[index] = data["Open"].iloc[0] if not data.empty else None
#             except Exception as e:
#                 print(f"Error fetching opening price for {index}: {e}")
#                 self.opening_prices[index] = None
#
#     def train_models(self):
#         """Trains a Linear Regression model for each ETF based on its underlying index."""
#         if self.closing_prices is None:
#             print("Error: Closing prices not available. Fetch data first.")
#             return
#
#         for index, etf in self.assets.items():
#             try:
#                 X = self.closing_prices[index].values.reshape(-1, 1)
#                 y = self.closing_prices[etf].values.reshape(-1, 1)
#
#                 model = LinearRegression()
#                 model.fit(X, y)
#                 self.models[etf] = model
#             except Exception as e:
#                 print(f"Error training model for {etf}: {e}")
#
#     def predict_opening_prices(self):
#         """Predicts today's opening price for ETFs using the trained regression models."""
#         predicted_openings = {}
#         for index, etf in self.assets.items():
#             if self.opening_prices.get(index) is not None and etf in self.models:
#                 try:
#                     predicted_openings[etf] = self.models[etf].predict(np.array([[self.opening_prices[index]]]))[0][0]
#                 except Exception as e:
#                     print(f"Error predicting opening price for {etf}: {e}")
#                     predicted_openings[etf] = None
#             else:
#                 predicted_openings[etf] = "Market Closed or Model Not Available"
#         return predicted_openings
#
# class ETFVolumeAnalyzer:
#     """Analyzes ETF trading volume and calculates safe volume."""
#
#     def __init__(self, assets, start_date="2025-01-01"):
#         self.etf_symbols = list(assets.values())
#         self.start_date = start_date
#         self.end_date = datetime.today().strftime("%Y-%m-%d")
#         self.average_volumes = {}
#         self.safe_volumes = {}
#
#     def fetch_average_volumes(self):
#         """Fetches daily ETF trading volumes and calculates the average volume for each ETF."""
#         try:
#             volume_data = yf.download(self.etf_symbols, start=self.start_date, end=self.end_date)["Volume"]
#             self.average_volumes = volume_data.mean().to_dict()
#         except Exception as e:
#             print(f"Error fetching ETF volumes: {e}")
#
#     def calculate_safe_volumes(self):
#         """Calculates safe volume using the formula: Average Volume / 4500."""
#         for etf, avg_volume in self.average_volumes.items():
#             self.safe_volumes[etf] = int(avg_volume / 4500)
#             # 6.25 hours = 22,500 seconds | 22500/5 = 4500
#
#     def get_safe_volumes(self):
#         """Returns the calculated safe volumes."""
#         return self.safe_volumes
#
# class ZerodhaLogin:
#     """Handles Zerodha Kite login and maintains a session for order placement."""
#
#     LOGIN_URL = "https://kite.zerodha.com/api/login"
#     TOTP_URL = "https://kite.zerodha.com/api/twofa"
#
#     def __init__(self, username, password, totp_key):
#         self.username = username
#         self.password = password
#         self.totp_key = totp_key
#         self.session = requests.Session()
#         self.enctoken = None
#         self.headers = None
#
#     def login(self):
#         """Performs login using Zerodha credentials and TOTP authentication."""
#         try:
#             res1 = self.session.post(self.LOGIN_URL, data={
#                 "user_id": self.username,
#                 "password": self.password,
#                 "type": "user_id"
#             })
#             res1.raise_for_status()
#             loginRes = res1.json()
#
#             if "data" not in loginRes or "request_id" not in loginRes["data"]:
#                 raise ValueError("Login failed: Invalid response from server")
#
#             totp_value = pyotp.TOTP(self.totp_key).now()
#             finalRes = self.session.post(self.TOTP_URL, data={
#                 "request_id": loginRes["data"]["request_id"],
#                 "twofa_value": totp_value,
#                 "user_id": loginRes["data"]["user_id"],
#                 "twofa_type": "totp"
#             })
#             finalRes.raise_for_status()
#             authRes = finalRes.json()
#
#             if "status" not in authRes or authRes["status"] != "success":
#                 raise ValueError("TOTP Authentication failed")
#
#             self.enctoken = self.session.cookies.get_dict().get("enctoken", None)
#             if not self.enctoken:
#                 raise ValueError("Failed to retrieve enctoken")
#
#             print("Login successful!")
#             return self.session, self.enctoken
#
#         except requests.exceptions.RequestException as e:
#             print(f"HTTP Request Failed: {e}")
#         except ValueError as ve:
#             print(f"Error: {ve}")
#
# class ZerodhaMargin:
#     """Fetches margin details from Zerodha Kite API using an existing session."""
#
#     MARGIN_URL = "https://kite.zerodha.com/oms/user/margins"
#
#     def __init__(self, session, enctoken, headers):
#         """Initialize with an existing authenticated session and headers."""
#         self.session = session
#         self.enctoken = enctoken
#         self.headers = headers
#
#         if not self.enctoken or not self.headers:
#             raise ValueError("Authentication token or headers are missing. Cannot fetch margin data.")
#
#     def fetch_margin(self):
#         """Fetches margin details and extracts net margin for equity and commodity."""
#         try:
#             response = self.session.get(self.MARGIN_URL, headers=self.headers)
#             response.raise_for_status()
#             data = response.json()
#
#             equity_margin = data["data"]["equity"]["net"]
#             commodity_margin = data["data"]["commodity"]["net"]
#
#             return equity_margin, commodity_margin
#
#         except requests.exceptions.RequestException as e:
#             print(f"HTTP Request Failed: {e}")
#             return None, None
#
# class VolumeCalculation:
#     """Calculates adjusted trading volumes based on margin and safe volumes."""
#
#     def __init__(self, equity_margin, predicted_openings, safe_volumes):
#         self.equity_margin = equity_margin
#         self.predicted_openings = predicted_openings
#         self.safe_volumes = safe_volumes
#
#     def calculate_leveraged_margin(self):
#         """Calculates leveraged margin as equity margin multiplied by 5."""
#         return self.equity_margin * 5
#
#     def calculate_discount_margin(self):
#         """Calculates discounted margin as (equity margin * 5) - 5% of equity margin."""
#         return (self.equity_margin * 5) - (self.equity_margin * 5 * 0.05)
#
#     def calculate_trade_values(self):
#         """Calculates trade value for each ETF as predicted_openings * safe_volumes."""
#         return {etf: self.predicted_openings[etf] * self.safe_volumes[etf] for etf in self.safe_volumes}
#
#     def calculate_total_trade_value(self, trade_values):
#         """Calculates total trade value as the sum of all individual trade values."""
#         return sum(trade_values.values())
#
#     def calculate_allocation_ratio(self, discount_margin, total_trade_value):
#         """Calculates allocation ratio as discount_margin / total_trade_value."""
#         return discount_margin / total_trade_value if total_trade_value > 0 else 0
#
#     def calculate_adjusted_quantities(self, allocation_ratio):
#         """Calculates adjusted quantity for each ETF as allocation_ratio * safe_volumes."""
#         return {etf: int(allocation_ratio * self.safe_volumes[etf]) for etf in self.safe_volumes}
#
#     def execute_volume_calculation(self):
#         """Executes all calculations and returns adjusted quantities."""
#         discount_margin = self.calculate_discount_margin()  # Use discount margin instead of leveraged margin
#         trade_values = self.calculate_trade_values()
#         total_trade_value = self.calculate_total_trade_value(trade_values)
#         allocation_ratio = self.calculate_allocation_ratio(discount_margin, total_trade_value)
#         adjusted_quantities = self.calculate_adjusted_quantities(allocation_ratio)
#
#         return adjusted_quantities
#
# class DataStore:
#     """Class to store symbols, adjusted quantities, and predicted prices."""
#
#     def __init__(self):
#         self.data = []
#
#     def add_data(self, symbol, adjusted_quantity, predicted_price):
#         """Adds a new entry to the data store."""
#         self.data.append({
#             'symbol_a': symbol,
#             'quantity_a': adjusted_quantity,
#             'price_a': predicted_price
#         })
#
#     def get_data(self):
#         """Returns all stored data."""
#         return self.data
#
# def main():
#     """Main execution function"""
#     assets = {
#         "^NSEI": "NIFTYBEES.NS",      # Nifty 50 → Niftybees
#         "^NSMIDCP": "JUNIORBEES.NS",   # Nifty Next 50 → Junior Bees
#         "^NSEBANK": "BANKBEES.NS"      # Nifty Bank → Bank Bees
#     }
#
#     # Predict ETF opening prices
#     predictor = ETFPricePredictor(assets)
#
#     print("Fetching historical closing prices...")
#     predictor.fetch_closing_prices()
#
#     print("Fetching today's opening prices...")
#     predictor.fetch_opening_prices()
#
#     print("Training regression models...")
#     predictor.train_models()
#
#     print("\nToday's Opening Prices:")
#     for index, price in predictor.opening_prices.items():
#         print(f"{index}: {price}")
#
#     print("\nPredicted ETF Opening Prices:")
#     predicted_prices = predictor.predict_opening_prices()
#     for etf, price in predicted_prices.items():
#         print(f"{etf}: {price:.2f}" if isinstance(price, float) else f"{etf}: {price}")
#
#     # Analyze ETF trading volumes
#     volume_analyzer = ETFVolumeAnalyzer(assets)
#
#     print("\nFetching ETF volume data...")
#     volume_analyzer.fetch_average_volumes()
#
#     print("Calculating safe volumes...")
#     volume_analyzer.calculate_safe_volumes()
#
#     print("\nAverage ETF Trading Volumes:")
#     for etf, avg_volume in volume_analyzer.average_volumes.items():
#         print(f"{etf}: {avg_volume:,.0f}")
#
#     print("\nSafe Trading Volumes:")
#     safe_volumes = volume_analyzer.get_safe_volumes()
#     for etf, safe_vol in safe_volumes.items():
#         print(f"{etf}: {safe_vol}")
#
#     # Log in to Zerodha
#     zerodha = ZerodhaLogin("DXU151", "Pratibha", "FLJBDJNEBOIMZZZPE25YYYR72Y2B2IAP")
#     session, enctoken = zerodha.login()
#
#     # Ensure successful login before proceeding
#     if not enctoken:
#         print("Zerodha login failed. Exiting...")
#         return
#
#     # Initialize ZerodhaMargin with correct headers
#     headers = {
#         "Authorization": f"enctoken {enctoken}",
#         "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36",
#         "Referer": "https://kite.zerodha.com/dashboard",
#         "Accept-Language": "en-US,en;q=0.6",
#         "Content-type": "application/x-www-form-urlencoded",
#         "Accept": "application/json, text/plain, */*",
#     }
#
#     zerodha_margin = ZerodhaMargin(session, enctoken, headers)
#     equity_margin, commodity_margin = zerodha_margin.fetch_margin()
#
#     print("\nZerodha Margin Details:")
#     print(f"Equity Margin: {equity_margin}")
#     print(f"Commodity Margin: {commodity_margin}")
#
#     # Initialize VolumeCalculation with necessary data
#     volume_calculator = VolumeCalculation(equity_margin, predicted_prices, safe_volumes)
#
#     # Calculate adjusted quantities
#     adjusted_quantities = volume_calculator.execute_volume_calculation()
#
#     print("\nAdjusted Quantities for Each ETF:")
#     for etf, adjusted_quantity in adjusted_quantities.items():
#         print(f"{etf}: {adjusted_quantity}")
#
#     # Create DataStore and add data
#     datastore = DataStore()
#
#     for etf, adjusted_quantity in adjusted_quantities.items():
#         predicted_price = predicted_prices.get(etf, None)
#         datastore.add_data(etf, adjusted_quantity, predicted_price)
#
#     # Get and display the stored data
#     print("\nStored Data:")
#     data = datastore.get_data()
#     for entry in data:
#         print(f"Symbol: {entry['symbol_a']}, Quantity: {entry['quantity_a']}, Predicted Price: {entry['price_a']}")
#
# if __name__ == "__main__":
#     main()
#
#
# existing python code is given above. use it for below mentioned prompt.
#
# act as a very clever python programmer and guide me further. create a class OrderStore.
#
# whatever data we generated in DataStore will be used those data here which are symbol, quantity, price to generate new data
#
# symbols are in the form of "NIFTYBEES.NS" i want symbols in the form of "NIFTYBEES" write function for this by name "format_symbol".
#
# price is round off to two decimal places.
#
# create function to create an array which stores four datapoints which are symbol, quantity, price, txn.
#
# there are two possible txn types - BUY or SELL
#
# use variable names as a symbol_b, quantity_b, price_b, txn_b respectively.
#
# symbol_b = output symbol of format_symbol
# price_b = price_a - 0.5% of price_a
# quantity_b = quantity_a
# txn = BUY
#
# again for that same etf
# symbol_b = output symbol of format_symbol
# price_b = price_a + 0.5% of price_a
# quantity_b = quantity_a
# txn = SELL
#
# for each etf there will be two types of data
# e.g.
# symbol_b = NIFTYBEES
# price_b = 99.5
# quantity_b = 100
# txn = BUY
#
# symbol_b = NIFTYBEES
# price_b = 100.5
# quantity_b = 100
# txn = SELL
#
# repeat this for all the etfs

# %%
class OrderStore:
    """Generates order data using symbols, quantities, and prices from DataStore."""

    def __init__(self):
        self.orders = []  # List to store order data

    def format_symbol(self, symbol):
        """Removes '.NS' from the symbol."""
        return symbol.split(".")[0]

    def add_order(self, symbol, quantity, price):
        """Creates two order records (BUY and SELL) for each ETF."""
        symbol_b = self.format_symbol(symbol)  # Format symbol
        price_b_buy = round(price * 0.995, 2)  # 0.5% lower for BUY
        price_b_sell = round(price * 1.005, 2)  # 0.5% higher for SELL
        quantity_b = quantity

        # Add BUY order
        self.orders.append({
            "symbol_b": symbol_b,
            "price_b": price_b_buy,
            "quantity_b": quantity_b,
            "txn_b": "BUY"
        })

        # Add SELL order
        self.orders.append({
            "symbol_b": symbol_b,
            "price_b": price_b_sell,
            "quantity_b": quantity_b,
            "txn_b": "SELL"
        })

    def generate_orders(self, data_store):
        """Creates orders from data stored in DataStore."""
        for entry in data_store.get_data():
            self.add_order(entry['symbol_a'], entry['quantity_a'], entry['price_a'])

    def get_orders(self):
        """Returns the list of generated orders."""
        return self.orders

# %%
# Create an instance of OrderStore
order_store = OrderStore()

# Generate orders using data from DataStore
order_store.generate_orders(datastore)

# Retrieve and display the orders
print("\nGenerated Orders:")
for order in order_store.get_orders():
    print(f"Symbol: {order['symbol_b']}, Price: {order['price_b']}, Quantity: {order['quantity_b']}, TXN: {order['txn_b']}")

# %% [raw]
# manual update

# %%
import yfinance as yf
from datetime import datetime
import numpy as np
import pandas as pd
import requests
import pyotp
from sklearn.linear_model import LinearRegression

import time
from datetime import datetime, timedelta

class TimeUtils:
    """Utility class for time-related functions."""
    
    @staticmethod
    def get_current_datetime_hh_mm_ss_ms():
        """Returns the current datetime with milliseconds."""
        return datetime.now()

    @staticmethod
    def get_current_datetime_hh_mm_ss():
        """Returns the current time in HH:MM:SS format."""
        return datetime.now().strftime("%H:%M:%S")

    @staticmethod
    def print_current_datetime_hh_mm_ss_ms():
        """Prints the current datetime with milliseconds."""
        print(TimeUtils.get_current_datetime_hh_mm_ss_ms().strftime("%H:%M:%S.%f"))

    @staticmethod
    def print_current_datetime_hh_mm_ss():
        """Prints the current time in HH:MM:SS format."""
        print(TimeUtils.get_current_datetime_hh_mm_ss())

    @staticmethod
    def execute_at_precise_time(target_time, func):
        """
        Executes a given function at a precise target time.

        :param target_time: Datetime object specifying the execution time.
        :param func: Function to execute.
        """
        delay = (target_time - datetime.now()).total_seconds()
        
        # Sleep until just before the target time
        time.sleep(max(0, delay - 0.1))
        
        # Busy-wait until the exact moment
        while datetime.now() < target_time:
            pass

        func()

class ETFPricePredictor:
    """Predicts ETF opening prices using linear regression based on underlying index data."""

    def __init__(self, assets, start_date="2025-01-01"):
        self.assets = assets
        self.start_date = start_date
        self.end_date = datetime.today().strftime("%Y-%m-%d")
        self.closing_prices = None
        self.opening_prices = {}
        self.models = {}

    def fetch_closing_prices(self):
        """Fetches daily closing prices for underlying indices and ETFs."""
        symbols = list(self.assets.keys()) + list(self.assets.values())  
        try:
            data = yf.download(symbols, start=self.start_date, end=self.end_date)["Close"]
            data.dropna(inplace=True)  
            self.closing_prices = data
        except Exception as e:
            print(f"Error fetching closing prices: {e}")

    def fetch_opening_prices(self):
        """Fetches today's opening prices for the underlying indices."""
        for index in self.assets.keys():
            try:
                data = yf.Ticker(index).history(period="1d")
                self.opening_prices[index] = data["Open"].iloc[0] if not data.empty else None
            except Exception as e:
                print(f"Error fetching opening price for {index}: {e}")
                self.opening_prices[index] = None  

    def train_models(self):
        """Trains a Linear Regression model for each ETF based on its underlying index."""
        if self.closing_prices is None:
            print("Error: Closing prices not available. Fetch data first.")
            return
        
        for index, etf in self.assets.items():
            try:
                X = self.closing_prices[index].values.reshape(-1, 1)  
                y = self.closing_prices[etf].values.reshape(-1, 1)  
                
                model = LinearRegression()
                model.fit(X, y)  
                self.models[etf] = model
            except Exception as e:
                print(f"Error training model for {etf}: {e}")

    def predict_opening_prices(self):
        """Predicts today's opening price for ETFs using the trained regression models."""
        predicted_openings = {}
        for index, etf in self.assets.items():
            if self.opening_prices.get(index) is not None and etf in self.models:
                try:
                    predicted_openings[etf] = self.models[etf].predict(np.array([[self.opening_prices[index]]]))[0][0]
                except Exception as e:
                    print(f"Error predicting opening price for {etf}: {e}")
                    predicted_openings[etf] = None
            else:
                predicted_openings[etf] = "Market Closed or Model Not Available"
        return predicted_openings

class ETFVolumeAnalyzer:
    """Analyzes ETF trading volume and calculates safe volume."""

    def __init__(self, assets, start_date="2025-01-01"):
        self.etf_symbols = list(assets.values())  
        self.start_date = start_date
        self.end_date = datetime.today().strftime("%Y-%m-%d")
        self.average_volumes = {}
        self.safe_volumes = {}

    def fetch_average_volumes(self):
        """Fetches daily ETF trading volumes and calculates the average volume for each ETF."""
        try:
            volume_data = yf.download(self.etf_symbols, start=self.start_date, end=self.end_date)["Volume"]
            self.average_volumes = volume_data.mean().to_dict()  
        except Exception as e:
            print(f"Error fetching ETF volumes: {e}")

    def calculate_safe_volumes(self):
        """Calculates safe volume using the formula: Average Volume / 4500."""
        for etf, avg_volume in self.average_volumes.items():
            self.safe_volumes[etf] = int(avg_volume / 4500)  
            # 6.25 hours = 22,500 seconds | 22500/5 = 4500

    def get_safe_volumes(self):
        """Returns the calculated safe volumes."""
        return self.safe_volumes

class ZerodhaLogin:
    """Handles Zerodha Kite login and maintains a session for order placement."""
    
    LOGIN_URL = "https://kite.zerodha.com/api/login"
    TOTP_URL = "https://kite.zerodha.com/api/twofa"

    def __init__(self, username, password, totp_key):
        self.username = username
        self.password = password
        self.totp_key = totp_key
        self.session = requests.Session()
        self.enctoken = None  
        self.headers = None  

    def login(self):
        """Performs login using Zerodha credentials and TOTP authentication."""
        try:
            res1 = self.session.post(self.LOGIN_URL, data={
                "user_id": self.username,
                "password": self.password,
                "type": "user_id"
            })
            res1.raise_for_status()  
            loginRes = res1.json()

            if "data" not in loginRes or "request_id" not in loginRes["data"]:
                raise ValueError("Login failed: Invalid response from server")

            totp_value = pyotp.TOTP(self.totp_key).now()
            finalRes = self.session.post(self.TOTP_URL, data={
                "request_id": loginRes["data"]["request_id"],
                "twofa_value": totp_value,
                "user_id": loginRes["data"]["user_id"],
                "twofa_type": "totp"
            })
            finalRes.raise_for_status()
            authRes = finalRes.json()

            if "status" not in authRes or authRes["status"] != "success":
                raise ValueError("TOTP Authentication failed")

            self.enctoken = self.session.cookies.get_dict().get("enctoken", None)
            if not self.enctoken:
                raise ValueError("Failed to retrieve enctoken")

            print("Login successful!")
            return self.session, self.enctoken

        except requests.exceptions.RequestException as e:
            print(f"HTTP Request Failed: {e}")
        except ValueError as ve:
            print(f"Error: {ve}")

class ZerodhaMargin:
    """Fetches margin details from Zerodha Kite API using an existing session."""

    MARGIN_URL = "https://kite.zerodha.com/oms/user/margins"

    def __init__(self, session, enctoken, headers):
        """Initialize with an existing authenticated session and headers."""
        self.session = session
        self.enctoken = enctoken
        self.headers = headers

        if not self.enctoken or not self.headers:
            raise ValueError("Authentication token or headers are missing. Cannot fetch margin data.")

    def fetch_margin(self):
        """Fetches margin details and extracts net margin for equity and commodity."""
        try:
            response = self.session.get(self.MARGIN_URL, headers=self.headers)
            response.raise_for_status()
            data = response.json()

            equity_margin = data["data"]["equity"]["net"]
            commodity_margin = data["data"]["commodity"]["net"]

            return equity_margin, commodity_margin

        except requests.exceptions.RequestException as e:
            print(f"HTTP Request Failed: {e}")
            return None, None

class VolumeCalculation:
    """Calculates adjusted trading volumes based on margin and safe volumes."""

    def __init__(self, equity_margin, predicted_openings, safe_volumes):
        self.equity_margin = equity_margin
        self.predicted_openings = predicted_openings
        self.safe_volumes = safe_volumes

    def calculate_leveraged_margin(self):
        """Calculates leveraged margin as equity margin multiplied by 5."""
        return self.equity_margin * 5

    def calculate_discount_margin(self):
        """Calculates discounted margin as (equity margin * 5) - 5% of equity margin."""
        return (self.equity_margin * 5) - (self.equity_margin * 5 * 0.05)

    def calculate_trade_values(self):
        """Calculates trade value for each ETF as predicted_openings * safe_volumes."""
        return {etf: self.predicted_openings[etf] * self.safe_volumes[etf] for etf in self.safe_volumes}

    def calculate_total_trade_value(self, trade_values):
        """Calculates total trade value as the sum of all individual trade values."""
        return sum(trade_values.values())

    def calculate_allocation_ratio(self, discount_margin, total_trade_value):
        """Calculates allocation ratio as discount_margin / total_trade_value."""
        return discount_margin / total_trade_value if total_trade_value > 0 else 0

    def calculate_adjusted_quantities(self, allocation_ratio):
        """Calculates adjusted quantity for each ETF as allocation_ratio * safe_volumes."""
        return {etf: int(allocation_ratio * self.safe_volumes[etf]) for etf in self.safe_volumes}

    def execute_volume_calculation(self):
        """Executes all calculations and returns adjusted quantities."""
        discount_margin = self.calculate_discount_margin()  # Use discount margin instead of leveraged margin
        trade_values = self.calculate_trade_values()
        total_trade_value = self.calculate_total_trade_value(trade_values)
        allocation_ratio = self.calculate_allocation_ratio(discount_margin, total_trade_value)
        adjusted_quantities = self.calculate_adjusted_quantities(allocation_ratio)
        
        return adjusted_quantities

class DataStore:
    """Class to store symbols, adjusted quantities, and predicted prices."""

    def __init__(self):
        self.data = []

    def add_data(self, symbol, adjusted_quantity, predicted_price):
        """Adds a new entry to the data store."""
        self.data.append({
            'symbol_a': symbol,
            'quantity_a': adjusted_quantity,
            'price_a': predicted_price
        })

    def get_data(self):
        """Returns all stored data."""
        return self.data

class OrderStore:
    """Generates order data using symbols, quantities, and prices from DataStore."""

    def __init__(self):
        self.orders = []  # List to store order data

    def format_symbol(self, symbol):
        """Removes '.NS' from the symbol."""
        return symbol.split(".")[0]

    def add_order(self, symbol, quantity, price):
        """Creates two order records (BUY and SELL) for each ETF."""
        symbol_b = self.format_symbol(symbol)  # Format symbol
        price_b_buy = round(price * 0.995, 2)  # 0.5% lower for BUY
        price_b_sell = round(price * 1.005, 2)  # 0.5% higher for SELL
        quantity_b = quantity

        # Add BUY order
        self.orders.append({
            "symbol_b": symbol_b,
            "price_b": price_b_buy,
            "quantity_b": quantity_b,
            "txn_b": "BUY"
        })

        # Add SELL order
        self.orders.append({
            "symbol_b": symbol_b,
            "price_b": price_b_sell,
            "quantity_b": quantity_b,
            "txn_b": "SELL"
        })

    def generate_orders(self, data_store):
        """Creates orders from data stored in DataStore."""
        for entry in data_store.get_data():
            self.add_order(entry['symbol_a'], entry['quantity_a'], entry['price_a'])

    def get_orders(self):
        """Returns the list of generated orders."""
        return self.orders

def main():
    """Main execution function"""
    assets = {
        "^NSEI": "NIFTYBEES.NS",      # Nifty 50 → Niftybees
        "^NSMIDCP": "JUNIORBEES.NS",   # Nifty Next 50 → Junior Bees
        "^NSEBANK": "BANKBEES.NS"      # Nifty Bank → Bank Bees
    }

    # Predict ETF opening prices
    predictor = ETFPricePredictor(assets)
    
    print("Fetching historical closing prices...")
    predictor.fetch_closing_prices()

    print("Fetching today's opening prices...")
    predictor.fetch_opening_prices()

    print("Training regression models...")
    predictor.train_models()

    print("\nToday's Opening Prices:")
    for index, price in predictor.opening_prices.items():
        print(f"{index}: {price}")

    print("\nPredicted ETF Opening Prices:")
    predicted_prices = predictor.predict_opening_prices()
    for etf, price in predicted_prices.items():
        print(f"{etf}: {price:.2f}" if isinstance(price, float) else f"{etf}: {price}")

    # Analyze ETF trading volumes
    volume_analyzer = ETFVolumeAnalyzer(assets)
    
    print("\nFetching ETF volume data...")
    volume_analyzer.fetch_average_volumes()

    print("Calculating safe volumes...")
    volume_analyzer.calculate_safe_volumes()

    print("\nAverage ETF Trading Volumes:")
    for etf, avg_volume in volume_analyzer.average_volumes.items():
        print(f"{etf}: {avg_volume:,.0f}")

    print("\nSafe Trading Volumes:")
    safe_volumes = volume_analyzer.get_safe_volumes()
    for etf, safe_vol in safe_volumes.items():
        print(f"{etf}: {safe_vol}")

    # Log in to Zerodha
    zerodha = ZerodhaLogin("DXU151", "Pratibha", "FLJBDJNEBOIMZZZPE25YYYR72Y2B2IAP")
    session, enctoken = zerodha.login()

    # Ensure successful login before proceeding
    if not enctoken:
        print("Zerodha login failed. Exiting...")
        return  

    # Initialize ZerodhaMargin with correct headers
    headers = {
        "Authorization": f"enctoken {enctoken}",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36",
        "Referer": "https://kite.zerodha.com/dashboard",
        "Accept-Language": "en-US,en;q=0.6",
        "Content-type": "application/x-www-form-urlencoded",
        "Accept": "application/json, text/plain, */*",
    }

    zerodha_margin = ZerodhaMargin(session, enctoken, headers)
    equity_margin, commodity_margin = zerodha_margin.fetch_margin()

    print("\nZerodha Margin Details:")
    print(f"Equity Margin: {equity_margin}")
    print(f"Commodity Margin: {commodity_margin}")

    # Initialize VolumeCalculation with necessary data
    volume_calculator = VolumeCalculation(equity_margin, predicted_prices, safe_volumes)

    # Calculate adjusted quantities
    adjusted_quantities = volume_calculator.execute_volume_calculation()

    print("\nAdjusted Quantities for Each ETF:")
    for etf, adjusted_quantity in adjusted_quantities.items():
        print(f"{etf}: {adjusted_quantity}")

    # Create DataStore and add data
    datastore = DataStore()
    
    for etf, adjusted_quantity in adjusted_quantities.items():
        predicted_price = predicted_prices.get(etf, None)
        datastore.add_data(etf, adjusted_quantity, predicted_price)

    # Get and display the stored data
    print("\nStored Data:")
    data = datastore.get_data()
    for entry in data:
        print(f"Symbol: {entry['symbol_a']}, Quantity: {entry['quantity_a']}, Predicted Price: {entry['price_a']}")

    # Create an instance of OrderStore
    order_store = OrderStore()

    # Generate orders using data from DataStore
    order_store.generate_orders(datastore)

    # Retrieve and display the orders
    print("\nGenerated Orders:")
    for order in order_store.get_orders():
        print(f"Symbol: {order['symbol_b']}, Price: {order['price_b']}, Quantity: {order['quantity_b']}, TXN: {order['txn_b']}")

if __name__ == "__main__":
    main()

# %% [raw]
# manual update

# %%
import yfinance as yf
from datetime import datetime
import numpy as np
import pandas as pd
import requests
import pyotp
from sklearn.linear_model import LinearRegression

import time
from datetime import datetime, timedelta

class TimeUtils:
    """Utility class for time-related functions."""
    
    @staticmethod
    def get_current_datetime_hh_mm_ss_ms():
        """Returns the current datetime with milliseconds."""
        return datetime.now()

    @staticmethod
    def get_current_datetime_hh_mm_ss():
        """Returns the current time in HH:MM:SS format."""
        return datetime.now().strftime("%H:%M:%S")

    @staticmethod
    def print_current_datetime_hh_mm_ss_ms():
        """Prints the current datetime with milliseconds."""
        print(TimeUtils.get_current_datetime_hh_mm_ss_ms().strftime("%H:%M:%S.%f"))

    @staticmethod
    def print_current_datetime_hh_mm_ss():
        """Prints the current time in HH:MM:SS format."""
        print(TimeUtils.get_current_datetime_hh_mm_ss())

    @staticmethod
    def execute_at_precise_time(target_time, func):
        """
        Executes a given function at a precise target time.

        :param target_time: Datetime object specifying the execution time.
        :param func: Function to execute.
        """
        delay = (target_time - datetime.now()).total_seconds()
        
        # Sleep until just before the target time
        time.sleep(max(0, delay - 0.1))
        
        # Busy-wait until the exact moment
        while datetime.now() < target_time:
            pass

        func()

class ETFPricePredictor:
    """Predicts ETF opening prices using linear regression based on underlying index data."""

    def __init__(self, assets, start_date="2025-01-01"):
        self.assets = assets
        self.start_date = start_date
        self.end_date = datetime.today().strftime("%Y-%m-%d")
        self.closing_prices = None
        self.opening_prices = {}
        self.models = {}

    def fetch_closing_prices(self):
        """Fetches daily closing prices for underlying indices and ETFs."""
        symbols = list(self.assets.keys()) + list(self.assets.values())  
        try:
            data = yf.download(symbols, start=self.start_date, end=self.end_date)["Close"]
            data.dropna(inplace=True)  
            self.closing_prices = data
        except Exception as e:
            print(f"Error fetching closing prices: {e}")

    def fetch_opening_prices(self):
        """Fetches today's opening prices for the underlying indices."""
        for index in self.assets.keys():
            try:
                data = yf.Ticker(index).history(period="1d")
                self.opening_prices[index] = data["Open"].iloc[0] if not data.empty else None
            except Exception as e:
                print(f"Error fetching opening price for {index}: {e}")
                self.opening_prices[index] = None  

    def train_models(self):
        """Trains a Linear Regression model for each ETF based on its underlying index."""
        if self.closing_prices is None:
            print("Error: Closing prices not available. Fetch data first.")
            return
        
        for index, etf in self.assets.items():
            try:
                X = self.closing_prices[index].values.reshape(-1, 1)  
                y = self.closing_prices[etf].values.reshape(-1, 1)  
                
                model = LinearRegression()
                model.fit(X, y)  
                self.models[etf] = model
            except Exception as e:
                print(f"Error training model for {etf}: {e}")

    def predict_opening_prices(self):
        """Predicts today's opening price for ETFs using the trained regression models."""
        predicted_openings = {}
        for index, etf in self.assets.items():
            if self.opening_prices.get(index) is not None and etf in self.models:
                try:
                    predicted_openings[etf] = self.models[etf].predict(np.array([[self.opening_prices[index]]]))[0][0]
                except Exception as e:
                    print(f"Error predicting opening price for {etf}: {e}")
                    predicted_openings[etf] = None
            else:
                predicted_openings[etf] = "Market Closed or Model Not Available"
        return predicted_openings

class ETFVolumeAnalyzer:
    """Analyzes ETF trading volume and calculates safe volume."""

    def __init__(self, assets, start_date="2025-01-01"):
        self.etf_symbols = list(assets.values())  
        self.start_date = start_date
        self.end_date = datetime.today().strftime("%Y-%m-%d")
        self.average_volumes = {}
        self.safe_volumes = {}

    def fetch_average_volumes(self):
        """Fetches daily ETF trading volumes and calculates the average volume for each ETF."""
        try:
            volume_data = yf.download(self.etf_symbols, start=self.start_date, end=self.end_date)["Volume"]
            self.average_volumes = volume_data.mean().to_dict()  
        except Exception as e:
            print(f"Error fetching ETF volumes: {e}")

    def calculate_safe_volumes(self):
        """Calculates safe volume using the formula: Average Volume / 4500."""
        for etf, avg_volume in self.average_volumes.items():
            self.safe_volumes[etf] = int(avg_volume / 4500)  
            # 6.25 hours = 22,500 seconds | 22500/5 = 4500

    def get_safe_volumes(self):
        """Returns the calculated safe volumes."""
        return self.safe_volumes

class ZerodhaLogin:
    """Handles Zerodha Kite login and maintains a session for order placement."""
    
    LOGIN_URL = "https://kite.zerodha.com/api/login"
    TOTP_URL = "https://kite.zerodha.com/api/twofa"

    def __init__(self, username, password, totp_key):
        self.username = username
        self.password = password
        self.totp_key = totp_key
        self.session = requests.Session()
        self.enctoken = None  
        self.headers = None  

    def login(self):
        """Performs login using Zerodha credentials and TOTP authentication."""
        try:
            res1 = self.session.post(self.LOGIN_URL, data={
                "user_id": self.username,
                "password": self.password,
                "type": "user_id"
            })
            res1.raise_for_status()  
            loginRes = res1.json()

            if "data" not in loginRes or "request_id" not in loginRes["data"]:
                raise ValueError("Login failed: Invalid response from server")

            totp_value = pyotp.TOTP(self.totp_key).now()
            finalRes = self.session.post(self.TOTP_URL, data={
                "request_id": loginRes["data"]["request_id"],
                "twofa_value": totp_value,
                "user_id": loginRes["data"]["user_id"],
                "twofa_type": "totp"
            })
            finalRes.raise_for_status()
            authRes = finalRes.json()

            if "status" not in authRes or authRes["status"] != "success":
                raise ValueError("TOTP Authentication failed")

            self.enctoken = self.session.cookies.get_dict().get("enctoken", None)
            if not self.enctoken:
                raise ValueError("Failed to retrieve enctoken")

            print("Login successful!")
            return self.session, self.enctoken

        except requests.exceptions.RequestException as e:
            print(f"HTTP Request Failed: {e}")
        except ValueError as ve:
            print(f"Error: {ve}")

class ZerodhaMargin:
    """Fetches margin details from Zerodha Kite API using an existing session."""

    MARGIN_URL = "https://kite.zerodha.com/oms/user/margins"

    def __init__(self, session, enctoken, headers):
        """Initialize with an existing authenticated session and headers."""
        self.session = session
        self.enctoken = enctoken
        self.headers = headers

        if not self.enctoken or not self.headers:
            raise ValueError("Authentication token or headers are missing. Cannot fetch margin data.")

    def fetch_margin(self):
        """Fetches margin details and extracts net margin for equity and commodity."""
        try:
            response = self.session.get(self.MARGIN_URL, headers=self.headers)
            response.raise_for_status()
            data = response.json()

            equity_margin = data["data"]["equity"]["net"]
            commodity_margin = data["data"]["commodity"]["net"]

            return equity_margin, commodity_margin

        except requests.exceptions.RequestException as e:
            print(f"HTTP Request Failed: {e}")
            return None, None

class VolumeCalculation:
    """Calculates adjusted trading volumes based on margin and safe volumes."""

    def __init__(self, equity_margin, predicted_openings, safe_volumes):
        self.equity_margin = equity_margin
        self.predicted_openings = predicted_openings
        self.safe_volumes = safe_volumes

    def calculate_leveraged_margin(self):
        """Calculates leveraged margin as equity margin multiplied by 5."""
        return self.equity_margin * 5

    def calculate_discount_margin(self):
        """Calculates discounted margin as (equity margin * 5) - 5% of equity margin."""
        return (self.equity_margin * 5) - (self.equity_margin * 5 * 0.05)

    def calculate_trade_values(self):
        """Calculates trade value for each ETF as predicted_openings * safe_volumes."""
        return {etf: self.predicted_openings[etf] * self.safe_volumes[etf] for etf in self.safe_volumes}

    def calculate_total_trade_value(self, trade_values):
        """Calculates total trade value as the sum of all individual trade values."""
        return sum(trade_values.values())

    def calculate_allocation_ratio(self, discount_margin, total_trade_value):
        """Calculates allocation ratio as discount_margin / total_trade_value."""
        return discount_margin / total_trade_value if total_trade_value > 0 else 0

    def calculate_adjusted_quantities(self, allocation_ratio):
        """Calculates adjusted quantity for each ETF as allocation_ratio * safe_volumes."""
        return {etf: int(allocation_ratio * self.safe_volumes[etf]) for etf in self.safe_volumes}

    def execute_volume_calculation(self):
        """Executes all calculations and returns adjusted quantities."""
        discount_margin = self.calculate_discount_margin()  # Use discount margin instead of leveraged margin
        trade_values = self.calculate_trade_values()
        total_trade_value = self.calculate_total_trade_value(trade_values)
        allocation_ratio = self.calculate_allocation_ratio(discount_margin, total_trade_value)
        adjusted_quantities = self.calculate_adjusted_quantities(allocation_ratio)
        
        return adjusted_quantities

class DataStore:
    """Class to store symbols, adjusted quantities, and predicted prices."""

    def __init__(self):
        self.data = []

    def add_data(self, symbol, adjusted_quantity, predicted_price):
        """Adds a new entry to the data store."""
        self.data.append({
            'symbol_a': symbol,
            'quantity_a': adjusted_quantity,
            'price_a': predicted_price
        })

    def get_data(self):
        """Returns all stored data."""
        return self.data

class OrderStore:
    """Generates order data using symbols, quantities, and prices from DataStore."""

    def __init__(self):
        self.orders = []  # List to store order data

    def format_symbol(self, symbol):
        """Removes '.NS' from the symbol."""
        return symbol.split(".")[0]

    def add_order(self, symbol, quantity, price):
        """Creates two order records (BUY and SELL) for each ETF."""
        symbol_b = self.format_symbol(symbol)  # Format symbol
        price_b_buy = round(price * 0.995, 2)  # 0.5% lower for BUY
        price_b_sell = round(price * 1.005, 2)  # 0.5% higher for SELL
        quantity_b = quantity

        # Add BUY order
        self.orders.append({
            "symbol_b": symbol_b,
            "price_b": price_b_buy,
            "quantity_b": quantity_b,
            "txn_b": "BUY"
        })

        # Add SELL order
        self.orders.append({
            "symbol_b": symbol_b,
            "price_b": price_b_sell,
            "quantity_b": quantity_b,
            "txn_b": "SELL"
        })

    def generate_orders(self, data_store):
        """Creates orders from data stored in DataStore."""
        for entry in data_store.get_data():
            self.add_order(entry['symbol_a'], entry['quantity_a'], entry['price_a'])

    def get_orders(self):
        """Returns the list of generated orders."""
        return self.orders

def main():
    """Main execution function"""
    assets = {
        "^NSEI": "NIFTYBEES.NS",      # Nifty 50 → Niftybees
        "^NSMIDCP": "JUNIORBEES.NS",   # Nifty Next 50 → Junior Bees
        "^NSEBANK": "BANKBEES.NS"      # Nifty Bank → Bank Bees
    }

    # Predict ETF opening prices
    predictor = ETFPricePredictor(assets)
    
    print("Fetching historical closing prices...")
    predictor.fetch_closing_prices()

    print("Fetching today's opening prices...")
    predictor.fetch_opening_prices()

    print("Training regression models...")
    predictor.train_models()

    print("\nToday's Opening Prices:")
    for index, price in predictor.opening_prices.items():
        print(f"{index}: {price}")

    print("\nPredicted ETF Opening Prices:")
    predicted_prices = predictor.predict_opening_prices()
    for etf, price in predicted_prices.items():
        print(f"{etf}: {price:.2f}" if isinstance(price, float) else f"{etf}: {price}")

    # Analyze ETF trading volumes
    volume_analyzer = ETFVolumeAnalyzer(assets)
    
    print("\nFetching ETF volume data...")
    volume_analyzer.fetch_average_volumes()

    print("Calculating safe volumes...")
    volume_analyzer.calculate_safe_volumes()

    print("\nAverage ETF Trading Volumes:")
    for etf, avg_volume in volume_analyzer.average_volumes.items():
        print(f"{etf}: {avg_volume:,.0f}")

    print("\nSafe Trading Volumes:")
    safe_volumes = volume_analyzer.get_safe_volumes()
    for etf, safe_vol in safe_volumes.items():
        print(f"{etf}: {safe_vol}")

    # Log in to Zerodha
    zerodha = ZerodhaLogin("DXU151", "Pratibha", "FLJBDJNEBOIMZZZPE25YYYR72Y2B2IAP")
    session, enctoken = zerodha.login()

    # Ensure successful login before proceeding
    if not enctoken:
        print("Zerodha login failed. Exiting...")
        return  

    # Initialize ZerodhaMargin with correct headers
    headers = {
        "Authorization": f"enctoken {enctoken}",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36",
        "Referer": "https://kite.zerodha.com/dashboard",
        "Accept-Language": "en-US,en;q=0.6",
        "Content-type": "application/x-www-form-urlencoded",
        "Accept": "application/json, text/plain, */*",
    }

    zerodha_margin = ZerodhaMargin(session, enctoken, headers)
    equity_margin, commodity_margin = zerodha_margin.fetch_margin()

    print("\nZerodha Margin Details:")
    print(f"Equity Margin: {equity_margin}")
    print(f"Commodity Margin: {commodity_margin}")

    # Initialize VolumeCalculation with necessary data
    volume_calculator = VolumeCalculation(equity_margin, predicted_prices, safe_volumes)

    # Calculate adjusted quantities
    adjusted_quantities = volume_calculator.execute_volume_calculation()

    print("\nAdjusted Quantities for Each ETF:")
    for etf, adjusted_quantity in adjusted_quantities.items():
        print(f"{etf}: {adjusted_quantity}")

    # Create DataStore and add data
    datastore = DataStore()
    
    for etf, adjusted_quantity in adjusted_quantities.items():
        predicted_price = predicted_prices.get(etf, None)
        datastore.add_data(etf, adjusted_quantity, predicted_price)

    # Get and display the stored data
    print("\nStored Data:")
    data = datastore.get_data()
    for entry in data:
        print(f"Symbol: {entry['symbol_a']}, Quantity: {entry['quantity_a']}, Predicted Price: {entry['price_a']}")

    # Create an instance of OrderStore
    order_store = OrderStore()

    # Generate orders using data from DataStore
    order_store.generate_orders(datastore)

    # Retrieve and display the orders
    print("\nGenerated Orders:")
    for order in order_store.get_orders():
        print(f"Symbol: {order['symbol_b']}, Price: {order['price_b']}, Quantity: {order['quantity_b']}, TXN: {order['txn_b']}")

if __name__ == "__main__":
    main()

# %% [raw]
# import yfinance as yf
# from datetime import datetime
# import numpy as np
# import pandas as pd
# import requests
# import pyotp
# from sklearn.linear_model import LinearRegression
#
# import time
# from datetime import datetime, timedelta
#
# class TimeUtils:
#     """Utility class for time-related functions."""
#
#     @staticmethod
#     def get_current_datetime_hh_mm_ss_ms():
#         """Returns the current datetime with milliseconds."""
#         return datetime.now()
#
#     @staticmethod
#     def get_current_datetime_hh_mm_ss():
#         """Returns the current time in HH:MM:SS format."""
#         return datetime.now().strftime("%H:%M:%S")
#
#     @staticmethod
#     def print_current_datetime_hh_mm_ss_ms():
#         """Prints the current datetime with milliseconds."""
#         print(TimeUtils.get_current_datetime_hh_mm_ss_ms().strftime("%H:%M:%S.%f"))
#
#     @staticmethod
#     def print_current_datetime_hh_mm_ss():
#         """Prints the current time in HH:MM:SS format."""
#         print(TimeUtils.get_current_datetime_hh_mm_ss())
#
#     @staticmethod
#     def execute_at_precise_time(target_time, func):
#         """
#         Executes a given function at a precise target time.
#
#         :param target_time: Datetime object specifying the execution time.
#         :param func: Function to execute.
#         """
#         delay = (target_time - datetime.now()).total_seconds()
#
#         # Sleep until just before the target time
#         time.sleep(max(0, delay - 0.1))
#
#         # Busy-wait until the exact moment
#         while datetime.now() < target_time:
#             pass
#
#         func()
#
# class ETFPricePredictor:
#     """Predicts ETF opening prices using linear regression based on underlying index data."""
#
#     def __init__(self, assets, start_date="2025-01-01"):
#         self.assets = assets
#         self.start_date = start_date
#         self.end_date = datetime.today().strftime("%Y-%m-%d")
#         self.closing_prices = None
#         self.opening_prices = {}
#         self.models = {}
#
#     def fetch_closing_prices(self):
#         """Fetches daily closing prices for underlying indices and ETFs."""
#         symbols = list(self.assets.keys()) + list(self.assets.values())
#         try:
#             data = yf.download(symbols, start=self.start_date, end=self.end_date)["Close"]
#             data.dropna(inplace=True)
#             self.closing_prices = data
#         except Exception as e:
#             print(f"Error fetching closing prices: {e}")
#
#     def fetch_opening_prices(self):
#         """Fetches today's opening prices for the underlying indices."""
#         for index in self.assets.keys():
#             try:
#                 data = yf.Ticker(index).history(period="1d")
#                 self.opening_prices[index] = data["Open"].iloc[0] if not data.empty else None
#             except Exception as e:
#                 print(f"Error fetching opening price for {index}: {e}")
#                 self.opening_prices[index] = None
#
#     def train_models(self):
#         """Trains a Linear Regression model for each ETF based on its underlying index."""
#         if self.closing_prices is None:
#             print("Error: Closing prices not available. Fetch data first.")
#             return
#
#         for index, etf in self.assets.items():
#             try:
#                 X = self.closing_prices[index].values.reshape(-1, 1)
#                 y = self.closing_prices[etf].values.reshape(-1, 1)
#
#                 model = LinearRegression()
#                 model.fit(X, y)
#                 self.models[etf] = model
#             except Exception as e:
#                 print(f"Error training model for {etf}: {e}")
#
#     def predict_opening_prices(self):
#         """Predicts today's opening price for ETFs using the trained regression models."""
#         predicted_openings = {}
#         for index, etf in self.assets.items():
#             if self.opening_prices.get(index) is not None and etf in self.models:
#                 try:
#                     predicted_openings[etf] = self.models[etf].predict(np.array([[self.opening_prices[index]]]))[0][0]
#                 except Exception as e:
#                     print(f"Error predicting opening price for {etf}: {e}")
#                     predicted_openings[etf] = None
#             else:
#                 predicted_openings[etf] = "Market Closed or Model Not Available"
#         return predicted_openings
#
# class ETFVolumeAnalyzer:
#     """Analyzes ETF trading volume and calculates safe volume."""
#
#     def __init__(self, assets, start_date="2025-01-01"):
#         self.etf_symbols = list(assets.values())
#         self.start_date = start_date
#         self.end_date = datetime.today().strftime("%Y-%m-%d")
#         self.average_volumes = {}
#         self.safe_volumes = {}
#
#     def fetch_average_volumes(self):
#         """Fetches daily ETF trading volumes and calculates the average volume for each ETF."""
#         try:
#             volume_data = yf.download(self.etf_symbols, start=self.start_date, end=self.end_date)["Volume"]
#             self.average_volumes = volume_data.mean().to_dict()
#         except Exception as e:
#             print(f"Error fetching ETF volumes: {e}")
#
#     def calculate_safe_volumes(self):
#         """Calculates safe volume using the formula: Average Volume / 4500."""
#         for etf, avg_volume in self.average_volumes.items():
#             self.safe_volumes[etf] = int(avg_volume / 4500)
#             # 6.25 hours = 22,500 seconds | 22500/5 = 4500
#
#     def get_safe_volumes(self):
#         """Returns the calculated safe volumes."""
#         return self.safe_volumes
#
# class ZerodhaLogin:
#     """Handles Zerodha Kite login and maintains a session for order placement."""
#
#     LOGIN_URL = "https://kite.zerodha.com/api/login"
#     TOTP_URL = "https://kite.zerodha.com/api/twofa"
#
#     def __init__(self, username, password, totp_key):
#         self.username = username
#         self.password = password
#         self.totp_key = totp_key
#         self.session = requests.Session()
#         self.enctoken = None
#         self.headers = None
#
#     def login(self):
#         """Performs login using Zerodha credentials and TOTP authentication."""
#         try:
#             res1 = self.session.post(self.LOGIN_URL, data={
#                 "user_id": self.username,
#                 "password": self.password,
#                 "type": "user_id"
#             })
#             res1.raise_for_status()
#             loginRes = res1.json()
#
#             if "data" not in loginRes or "request_id" not in loginRes["data"]:
#                 raise ValueError("Login failed: Invalid response from server")
#
#             totp_value = pyotp.TOTP(self.totp_key).now()
#             finalRes = self.session.post(self.TOTP_URL, data={
#                 "request_id": loginRes["data"]["request_id"],
#                 "twofa_value": totp_value,
#                 "user_id": loginRes["data"]["user_id"],
#                 "twofa_type": "totp"
#             })
#             finalRes.raise_for_status()
#             authRes = finalRes.json()
#
#             if "status" not in authRes or authRes["status"] != "success":
#                 raise ValueError("TOTP Authentication failed")
#
#             self.enctoken = self.session.cookies.get_dict().get("enctoken", None)
#             if not self.enctoken:
#                 raise ValueError("Failed to retrieve enctoken")
#
#             print("Login successful!")
#             return self.session, self.enctoken
#
#         except requests.exceptions.RequestException as e:
#             print(f"HTTP Request Failed: {e}")
#         except ValueError as ve:
#             print(f"Error: {ve}")
#
# class ZerodhaMargin:
#     """Fetches margin details from Zerodha Kite API using an existing session."""
#
#     MARGIN_URL = "https://kite.zerodha.com/oms/user/margins"
#
#     def __init__(self, session, enctoken, headers):
#         """Initialize with an existing authenticated session and headers."""
#         self.session = session
#         self.enctoken = enctoken
#         self.headers = headers
#
#         if not self.enctoken or not self.headers:
#             raise ValueError("Authentication token or headers are missing. Cannot fetch margin data.")
#
#     def fetch_margin(self):
#         """Fetches margin details and extracts net margin for equity and commodity."""
#         try:
#             response = self.session.get(self.MARGIN_URL, headers=self.headers)
#             response.raise_for_status()
#             data = response.json()
#
#             equity_margin = data["data"]["equity"]["net"]
#             commodity_margin = data["data"]["commodity"]["net"]
#
#             return equity_margin, commodity_margin
#
#         except requests.exceptions.RequestException as e:
#             print(f"HTTP Request Failed: {e}")
#             return None, None
#
# class VolumeCalculation:
#     """Calculates adjusted trading volumes based on margin and safe volumes."""
#
#     def __init__(self, equity_margin, predicted_openings, safe_volumes):
#         self.equity_margin = equity_margin
#         self.predicted_openings = predicted_openings
#         self.safe_volumes = safe_volumes
#
#     def calculate_leveraged_margin(self):
#         """Calculates leveraged margin as equity margin multiplied by 5."""
#         return self.equity_margin * 5
#
#     def calculate_discount_margin(self):
#         """Calculates discounted margin as (equity margin * 5) - 5% of equity margin."""
#         return (self.equity_margin * 5) - (self.equity_margin * 5 * 0.05)
#
#     def calculate_trade_values(self):
#         """Calculates trade value for each ETF as predicted_openings * safe_volumes."""
#         return {etf: self.predicted_openings[etf] * self.safe_volumes[etf] for etf in self.safe_volumes}
#
#     def calculate_total_trade_value(self, trade_values):
#         """Calculates total trade value as the sum of all individual trade values."""
#         return sum(trade_values.values())
#
#     def calculate_allocation_ratio(self, discount_margin, total_trade_value):
#         """Calculates allocation ratio as discount_margin / total_trade_value."""
#         return discount_margin / total_trade_value if total_trade_value > 0 else 0
#
#     def calculate_adjusted_quantities(self, allocation_ratio):
#         """Calculates adjusted quantity for each ETF as allocation_ratio * safe_volumes."""
#         return {etf: int(allocation_ratio * self.safe_volumes[etf]) for etf in self.safe_volumes}
#
#     def execute_volume_calculation(self):
#         """Executes all calculations and returns adjusted quantities."""
#         discount_margin = self.calculate_discount_margin()  # Use discount margin instead of leveraged margin
#         trade_values = self.calculate_trade_values()
#         total_trade_value = self.calculate_total_trade_value(trade_values)
#         allocation_ratio = self.calculate_allocation_ratio(discount_margin, total_trade_value)
#         adjusted_quantities = self.calculate_adjusted_quantities(allocation_ratio)
#
#         return adjusted_quantities
#
# class DataStore:
#     """Class to store symbols, adjusted quantities, and predicted prices."""
#
#     def __init__(self):
#         self.data = []
#
#     def add_data(self, symbol, adjusted_quantity, predicted_price):
#         """Adds a new entry to the data store."""
#         self.data.append({
#             'symbol_a': symbol,
#             'quantity_a': adjusted_quantity,
#             'price_a': predicted_price
#         })
#
#     def get_data(self):
#         """Returns all stored data."""
#         return self.data
#
# class OrderStore:
#     """Generates order data using symbols, quantities, and prices from DataStore."""
#
#     def __init__(self):
#         self.orders = []  # List to store order data
#
#     def format_symbol(self, symbol):
#         """Removes '.NS' from the symbol."""
#         return symbol.split(".")[0]
#
#     def add_order(self, symbol, quantity, price):
#         """Creates two order records (BUY and SELL) for each ETF."""
#         symbol_b = self.format_symbol(symbol)  # Format symbol
#         price_b_buy = round(price * 0.995, 2)  # 0.5% lower for BUY
#         price_b_sell = round(price * 1.005, 2)  # 0.5% higher for SELL
#         quantity_b = quantity
#
#         # Add BUY order
#         self.orders.append({
#             "symbol_b": symbol_b,
#             "price_b": price_b_buy,
#             "quantity_b": quantity_b,
#             "txn_b": "BUY"
#         })
#
#         # Add SELL order
#         self.orders.append({
#             "symbol_b": symbol_b,
#             "price_b": price_b_sell,
#             "quantity_b": quantity_b,
#             "txn_b": "SELL"
#         })
#
#     def generate_orders(self, data_store):
#         """Creates orders from data stored in DataStore."""
#         for entry in data_store.get_data():
#             self.add_order(entry['symbol_a'], entry['quantity_a'], entry['price_a'])
#
#     def get_orders(self):
#         """Returns the list of generated orders."""
#         return self.orders
#
# def main():
#     """Main execution function"""
#     assets = {
#         "^NSEI": "NIFTYBEES.NS",      # Nifty 50 → Niftybees
#         "^NSMIDCP": "JUNIORBEES.NS",   # Nifty Next 50 → Junior Bees
#         "^NSEBANK": "BANKBEES.NS"      # Nifty Bank → Bank Bees
#     }
#
#     # Predict ETF opening prices
#     predictor = ETFPricePredictor(assets)
#
#     print("Fetching historical closing prices...")
#     predictor.fetch_closing_prices()
#
#     print("Fetching today's opening prices...")
#     predictor.fetch_opening_prices()
#
#     print("Training regression models...")
#     predictor.train_models()
#
#     print("\nToday's Opening Prices:")
#     for index, price in predictor.opening_prices.items():
#         print(f"{index}: {price}")
#
#     print("\nPredicted ETF Opening Prices:")
#     predicted_prices = predictor.predict_opening_prices()
#     for etf, price in predicted_prices.items():
#         print(f"{etf}: {price:.2f}" if isinstance(price, float) else f"{etf}: {price}")
#
#     # Analyze ETF trading volumes
#     volume_analyzer = ETFVolumeAnalyzer(assets)
#
#     print("\nFetching ETF volume data...")
#     volume_analyzer.fetch_average_volumes()
#
#     print("Calculating safe volumes...")
#     volume_analyzer.calculate_safe_volumes()
#
#     print("\nAverage ETF Trading Volumes:")
#     for etf, avg_volume in volume_analyzer.average_volumes.items():
#         print(f"{etf}: {avg_volume:,.0f}")
#
#     print("\nSafe Trading Volumes:")
#     safe_volumes = volume_analyzer.get_safe_volumes()
#     for etf, safe_vol in safe_volumes.items():
#         print(f"{etf}: {safe_vol}")
#
#     # Log in to Zerodha
#     zerodha = ZerodhaLogin("DXU151", "Pratibha", "FLJBDJNEBOIMZZZPE25YYYR72Y2B2IAP")
#     session, enctoken = zerodha.login()
#
#     # Ensure successful login before proceeding
#     if not enctoken:
#         print("Zerodha login failed. Exiting...")
#         return
#
#     # Initialize ZerodhaMargin with correct headers
#     headers = {
#         "Authorization": f"enctoken {enctoken}",
#         "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36",
#         "Referer": "https://kite.zerodha.com/dashboard",
#         "Accept-Language": "en-US,en;q=0.6",
#         "Content-type": "application/x-www-form-urlencoded",
#         "Accept": "application/json, text/plain, */*",
#     }
#
#     zerodha_margin = ZerodhaMargin(session, enctoken, headers)
#     equity_margin, commodity_margin = zerodha_margin.fetch_margin()
#
#     print("\nZerodha Margin Details:")
#     print(f"Equity Margin: {equity_margin}")
#     print(f"Commodity Margin: {commodity_margin}")
#
#     # Initialize VolumeCalculation with necessary data
#     volume_calculator = VolumeCalculation(equity_margin, predicted_prices, safe_volumes)
#
#     # Calculate adjusted quantities
#     adjusted_quantities = volume_calculator.execute_volume_calculation()
#
#     print("\nAdjusted Quantities for Each ETF:")
#     for etf, adjusted_quantity in adjusted_quantities.items():
#         print(f"{etf}: {adjusted_quantity}")
#
#     # Create DataStore and add data
#     datastore = DataStore()
#
#     for etf, adjusted_quantity in adjusted_quantities.items():
#         predicted_price = predicted_prices.get(etf, None)
#         datastore.add_data(etf, adjusted_quantity, predicted_price)
#
#     # Get and display the stored data
#     print("\nStored Data:")
#     data = datastore.get_data()
#     for entry in data:
#         print(f"Symbol: {entry['symbol_a']}, Quantity: {entry['quantity_a']}, Predicted Price: {entry['price_a']}")
#
#     # Create an instance of OrderStore
#     order_store = OrderStore()
#
#     # Generate orders using data from DataStore
#     order_store.generate_orders(datastore)
#
#     # Retrieve and display the orders
#     print("\nGenerated Orders:")
#     for order in order_store.get_orders():
#         print(f"Symbol: {order['symbol_b']}, Price: {order['price_b']}, Quantity: {order['quantity_b']}, TXN: {order['txn_b']}")
#
# if __name__ == "__main__":
#     main()
#
# above is the python code of entire project. act as a very clever python programmer and analyze it and guide / do mentioned task in this prompt.
#
# create a class PayloadStore.
#
# create an array orders to store data in the following form.
#
# orders = [
#     {
#         "variety": "regular",
#         "exchange": "NSE",
#         "order_type": "LIMIT",
#         "tradingsymbol": "NIFTYBEES",
#         "transaction_type": "BUY",
#         "quantity": 100,
#         "price": 99.5,
#         "product": "MIS",
#         "validity": "TTL",
#         "validity_ttl": "1"
#     },
#     {
#         "variety": "regular",
#         "exchange": "NSE",
#         "order_type": "LIMIT",
#         "tradingsymbol": "NIFTYBEES",
#         "transaction_type": "SELL",
#         "quantity": 100,
#         "price": 100.5,
#         "product": "MIS",
#         "validity": "TTL",
#         "validity_ttl": "1"
#     }
# ]
#
# it has "variety": "regular",
#         "exchange": "NSE",
#         "order_type": "LIMIT",
#         "product": "MIS",
#         "validity": "TTL",
#         "validity_ttl": "1"
#         constant data
#
# varaible data include tradingsymbol (symbol_b), transaction_type (txn_b), quantity (quantity_b), price (price_b) for that we are using the data generated in the OrderStore

# %%
class PayloadStore:
    """Stores order payloads in the required format."""

    def __init__(self):
        self.orders = []  # List to store formatted order payloads

    def add_order(self, symbol, txn, quantity, price):
        """Creates an order payload and adds it to the list."""
        order_payload = {
            "variety": "regular",
            "exchange": "NSE",
            "order_type": "LIMIT",
            "tradingsymbol": symbol,
            "transaction_type": txn,
            "quantity": quantity,
            "price": price,
            "product": "MIS",
            "validity": "TTL",
            "validity_ttl": "1"
        }
        self.orders.append(order_payload)

    def generate_payloads(self, order_store):
        """Generates payloads from orders in OrderStore."""
        for order in order_store.get_orders():
            self.add_order(
                symbol=order["symbol_b"],
                txn=order["txn_b"],
                quantity=order["quantity_b"],
                price=order["price_b"]
            )

    def get_payloads(self):
        """Returns the generated payloads."""
        return self.orders

# %%
# Create an instance of PayloadStore
payload_store = PayloadStore()

# Generate payloads from orders
payload_store.generate_payloads(order_store)

# Retrieve and display the payloads
print("\nGenerated Payloads:")
for payload in payload_store.get_payloads():
    print(payload)

# %% [raw]
# manual update

# %%
import yfinance as yf
from datetime import datetime
import numpy as np
import pandas as pd
import requests
import pyotp
from sklearn.linear_model import LinearRegression

import time
from datetime import datetime, timedelta

class TimeUtils:
    """Utility class for time-related functions."""
    
    @staticmethod
    def get_current_datetime_hh_mm_ss_ms():
        """Returns the current datetime with milliseconds."""
        return datetime.now()

    @staticmethod
    def get_current_datetime_hh_mm_ss():
        """Returns the current time in HH:MM:SS format."""
        return datetime.now().strftime("%H:%M:%S")

    @staticmethod
    def print_current_datetime_hh_mm_ss_ms():
        """Prints the current datetime with milliseconds."""
        print(TimeUtils.get_current_datetime_hh_mm_ss_ms().strftime("%H:%M:%S.%f"))

    @staticmethod
    def print_current_datetime_hh_mm_ss():
        """Prints the current time in HH:MM:SS format."""
        print(TimeUtils.get_current_datetime_hh_mm_ss())

    @staticmethod
    def execute_at_precise_time(target_time, func):
        """
        Executes a given function at a precise target time.

        :param target_time: Datetime object specifying the execution time.
        :param func: Function to execute.
        """
        delay = (target_time - datetime.now()).total_seconds()
        
        # Sleep until just before the target time
        time.sleep(max(0, delay - 0.1))
        
        # Busy-wait until the exact moment
        while datetime.now() < target_time:
            pass

        func()

class ETFPricePredictor:
    """Predicts ETF opening prices using linear regression based on underlying index data."""

    def __init__(self, assets, start_date="2025-01-01"):
        self.assets = assets
        self.start_date = start_date
        self.end_date = datetime.today().strftime("%Y-%m-%d")
        self.closing_prices = None
        self.opening_prices = {}
        self.models = {}

    def fetch_closing_prices(self):
        """Fetches daily closing prices for underlying indices and ETFs."""
        symbols = list(self.assets.keys()) + list(self.assets.values())  
        try:
            data = yf.download(symbols, start=self.start_date, end=self.end_date)["Close"]
            data.dropna(inplace=True)  
            self.closing_prices = data
        except Exception as e:
            print(f"Error fetching closing prices: {e}")

    def fetch_opening_prices(self):
        """Fetches today's opening prices for the underlying indices."""
        for index in self.assets.keys():
            try:
                data = yf.Ticker(index).history(period="1d")
                self.opening_prices[index] = data["Open"].iloc[0] if not data.empty else None
            except Exception as e:
                print(f"Error fetching opening price for {index}: {e}")
                self.opening_prices[index] = None  

    def train_models(self):
        """Trains a Linear Regression model for each ETF based on its underlying index."""
        if self.closing_prices is None:
            print("Error: Closing prices not available. Fetch data first.")
            return
        
        for index, etf in self.assets.items():
            try:
                X = self.closing_prices[index].values.reshape(-1, 1)  
                y = self.closing_prices[etf].values.reshape(-1, 1)  
                
                model = LinearRegression()
                model.fit(X, y)  
                self.models[etf] = model
            except Exception as e:
                print(f"Error training model for {etf}: {e}")

    def predict_opening_prices(self):
        """Predicts today's opening price for ETFs using the trained regression models."""
        predicted_openings = {}
        for index, etf in self.assets.items():
            if self.opening_prices.get(index) is not None and etf in self.models:
                try:
                    predicted_openings[etf] = self.models[etf].predict(np.array([[self.opening_prices[index]]]))[0][0]
                except Exception as e:
                    print(f"Error predicting opening price for {etf}: {e}")
                    predicted_openings[etf] = None
            else:
                predicted_openings[etf] = "Market Closed or Model Not Available"
        return predicted_openings

class ETFVolumeAnalyzer:
    """Analyzes ETF trading volume and calculates safe volume."""

    def __init__(self, assets, start_date="2025-01-01"):
        self.etf_symbols = list(assets.values())  
        self.start_date = start_date
        self.end_date = datetime.today().strftime("%Y-%m-%d")
        self.average_volumes = {}
        self.safe_volumes = {}

    def fetch_average_volumes(self):
        """Fetches daily ETF trading volumes and calculates the average volume for each ETF."""
        try:
            volume_data = yf.download(self.etf_symbols, start=self.start_date, end=self.end_date)["Volume"]
            self.average_volumes = volume_data.mean().to_dict()  
        except Exception as e:
            print(f"Error fetching ETF volumes: {e}")

    def calculate_safe_volumes(self):
        """Calculates safe volume using the formula: Average Volume / 4500."""
        for etf, avg_volume in self.average_volumes.items():
            self.safe_volumes[etf] = int(avg_volume / 4500)  
            # 6.25 hours = 22,500 seconds | 22500/5 = 4500

    def get_safe_volumes(self):
        """Returns the calculated safe volumes."""
        return self.safe_volumes

class ZerodhaLogin:
    """Handles Zerodha Kite login and maintains a session for order placement."""
    
    LOGIN_URL = "https://kite.zerodha.com/api/login"
    TOTP_URL = "https://kite.zerodha.com/api/twofa"

    def __init__(self, username, password, totp_key):
        self.username = username
        self.password = password
        self.totp_key = totp_key
        self.session = requests.Session()
        self.enctoken = None  
        self.headers = None  

    def login(self):
        """Performs login using Zerodha credentials and TOTP authentication."""
        try:
            res1 = self.session.post(self.LOGIN_URL, data={
                "user_id": self.username,
                "password": self.password,
                "type": "user_id"
            })
            res1.raise_for_status()  
            loginRes = res1.json()

            if "data" not in loginRes or "request_id" not in loginRes["data"]:
                raise ValueError("Login failed: Invalid response from server")

            totp_value = pyotp.TOTP(self.totp_key).now()
            finalRes = self.session.post(self.TOTP_URL, data={
                "request_id": loginRes["data"]["request_id"],
                "twofa_value": totp_value,
                "user_id": loginRes["data"]["user_id"],
                "twofa_type": "totp"
            })
            finalRes.raise_for_status()
            authRes = finalRes.json()

            if "status" not in authRes or authRes["status"] != "success":
                raise ValueError("TOTP Authentication failed")

            self.enctoken = self.session.cookies.get_dict().get("enctoken", None)
            if not self.enctoken:
                raise ValueError("Failed to retrieve enctoken")

            print("Login successful!")
            return self.session, self.enctoken

        except requests.exceptions.RequestException as e:
            print(f"HTTP Request Failed: {e}")
        except ValueError as ve:
            print(f"Error: {ve}")

class ZerodhaMargin:
    """Fetches margin details from Zerodha Kite API using an existing session."""

    MARGIN_URL = "https://kite.zerodha.com/oms/user/margins"

    def __init__(self, session, enctoken, headers):
        """Initialize with an existing authenticated session and headers."""
        self.session = session
        self.enctoken = enctoken
        self.headers = headers

        if not self.enctoken or not self.headers:
            raise ValueError("Authentication token or headers are missing. Cannot fetch margin data.")

    def fetch_margin(self):
        """Fetches margin details and extracts net margin for equity and commodity."""
        try:
            response = self.session.get(self.MARGIN_URL, headers=self.headers)
            response.raise_for_status()
            data = response.json()

            equity_margin = data["data"]["equity"]["net"]
            commodity_margin = data["data"]["commodity"]["net"]

            return equity_margin, commodity_margin

        except requests.exceptions.RequestException as e:
            print(f"HTTP Request Failed: {e}")
            return None, None

class VolumeCalculation:
    """Calculates adjusted trading volumes based on margin and safe volumes."""

    def __init__(self, equity_margin, predicted_openings, safe_volumes):
        self.equity_margin = equity_margin
        self.predicted_openings = predicted_openings
        self.safe_volumes = safe_volumes

    def calculate_leveraged_margin(self):
        """Calculates leveraged margin as equity margin multiplied by 5."""
        return self.equity_margin * 5

    def calculate_discount_margin(self):
        """Calculates discounted margin as (equity margin * 5) - 5% of equity margin."""
        return (self.equity_margin * 5) - (self.equity_margin * 5 * 0.05)

    def calculate_trade_values(self):
        """Calculates trade value for each ETF as predicted_openings * safe_volumes."""
        return {etf: self.predicted_openings[etf] * self.safe_volumes[etf] for etf in self.safe_volumes}

    def calculate_total_trade_value(self, trade_values):
        """Calculates total trade value as the sum of all individual trade values."""
        return sum(trade_values.values())

    def calculate_allocation_ratio(self, discount_margin, total_trade_value):
        """Calculates allocation ratio as discount_margin / total_trade_value."""
        return discount_margin / total_trade_value if total_trade_value > 0 else 0

    def calculate_adjusted_quantities(self, allocation_ratio):
        """Calculates adjusted quantity for each ETF as allocation_ratio * safe_volumes."""
        return {etf: int(allocation_ratio * self.safe_volumes[etf]) for etf in self.safe_volumes}

    def execute_volume_calculation(self):
        """Executes all calculations and returns adjusted quantities."""
        discount_margin = self.calculate_discount_margin()  # Use discount margin instead of leveraged margin
        trade_values = self.calculate_trade_values()
        total_trade_value = self.calculate_total_trade_value(trade_values)
        allocation_ratio = self.calculate_allocation_ratio(discount_margin, total_trade_value)
        adjusted_quantities = self.calculate_adjusted_quantities(allocation_ratio)
        
        return adjusted_quantities

class DataStore:
    """Class to store symbols, adjusted quantities, and predicted prices."""

    def __init__(self):
        self.data = []

    def add_data(self, symbol, adjusted_quantity, predicted_price):
        """Adds a new entry to the data store."""
        self.data.append({
            'symbol_a': symbol,
            'quantity_a': adjusted_quantity,
            'price_a': predicted_price
        })

    def get_data(self):
        """Returns all stored data."""
        return self.data

class OrderStore:
    """Generates order data using symbols, quantities, and prices from DataStore."""

    def __init__(self):
        self.orders = []  # List to store order data

    def format_symbol(self, symbol):
        """Removes '.NS' from the symbol."""
        return symbol.split(".")[0]

    def add_order(self, symbol, quantity, price):
        """Creates two order records (BUY and SELL) for each ETF."""
        symbol_b = self.format_symbol(symbol)  # Format symbol
        price_b_buy = round(price * 0.995, 2)  # 0.5% lower for BUY
        price_b_sell = round(price * 1.005, 2)  # 0.5% higher for SELL
        quantity_b = quantity

        # Add BUY order
        self.orders.append({
            "symbol_b": symbol_b,
            "price_b": price_b_buy,
            "quantity_b": quantity_b,
            "txn_b": "BUY"
        })

        # Add SELL order
        self.orders.append({
            "symbol_b": symbol_b,
            "price_b": price_b_sell,
            "quantity_b": quantity_b,
            "txn_b": "SELL"
        })

    def generate_orders(self, data_store):
        """Creates orders from data stored in DataStore."""
        for entry in data_store.get_data():
            self.add_order(entry['symbol_a'], entry['quantity_a'], entry['price_a'])

    def get_orders(self):
        """Returns the list of generated orders."""
        return self.orders

class PayloadStore:
    """Stores order payloads in the required format."""

    def __init__(self):
        self.orders = []  # List to store formatted order payloads

    def add_order(self, symbol, txn, quantity, price):
        """Creates an order payload and adds it to the list."""
        order_payload = {
            "variety": "regular",
            "exchange": "NSE",
            "order_type": "LIMIT",
            "tradingsymbol": symbol,
            "transaction_type": txn,
            "quantity": quantity,
            "price": price,
            "product": "MIS",
            "validity": "TTL",
            "validity_ttl": "1"
        }
        self.orders.append(order_payload)

    def generate_payloads(self, order_store):
        """Generates payloads from orders in OrderStore."""
        for order in order_store.get_orders():
            self.add_order(
                symbol=order["symbol_b"],
                txn=order["txn_b"],
                quantity=order["quantity_b"],
                price=order["price_b"]
            )

    def get_payloads(self):
        """Returns the generated payloads."""
        return self.orders

def main():
    """Main execution function"""
    assets = {
        "^NSEI": "NIFTYBEES.NS",      # Nifty 50 → Niftybees
        "^NSMIDCP": "JUNIORBEES.NS",   # Nifty Next 50 → Junior Bees
        "^NSEBANK": "BANKBEES.NS"      # Nifty Bank → Bank Bees
    }

    # Predict ETF opening prices
    predictor = ETFPricePredictor(assets)
    
    print("Fetching historical closing prices...")
    predictor.fetch_closing_prices()

    print("Fetching today's opening prices...")
    predictor.fetch_opening_prices()

    print("Training regression models...")
    predictor.train_models()

    print("\nToday's Opening Prices:")
    for index, price in predictor.opening_prices.items():
        print(f"{index}: {price}")

    print("\nPredicted ETF Opening Prices:")
    predicted_prices = predictor.predict_opening_prices()
    for etf, price in predicted_prices.items():
        print(f"{etf}: {price:.2f}" if isinstance(price, float) else f"{etf}: {price}")

    # Analyze ETF trading volumes
    volume_analyzer = ETFVolumeAnalyzer(assets)
    
    print("\nFetching ETF volume data...")
    volume_analyzer.fetch_average_volumes()

    print("Calculating safe volumes...")
    volume_analyzer.calculate_safe_volumes()

    print("\nAverage ETF Trading Volumes:")
    for etf, avg_volume in volume_analyzer.average_volumes.items():
        print(f"{etf}: {avg_volume:,.0f}")

    print("\nSafe Trading Volumes:")
    safe_volumes = volume_analyzer.get_safe_volumes()
    for etf, safe_vol in safe_volumes.items():
        print(f"{etf}: {safe_vol}")

    # Log in to Zerodha
    zerodha = ZerodhaLogin("DXU151", "Pratibha", "FLJBDJNEBOIMZZZPE25YYYR72Y2B2IAP")
    session, enctoken = zerodha.login()

    # Ensure successful login before proceeding
    if not enctoken:
        print("Zerodha login failed. Exiting...")
        return  

    # Initialize ZerodhaMargin with correct headers
    headers = {
        "Authorization": f"enctoken {enctoken}",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36",
        "Referer": "https://kite.zerodha.com/dashboard",
        "Accept-Language": "en-US,en;q=0.6",
        "Content-type": "application/x-www-form-urlencoded",
        "Accept": "application/json, text/plain, */*",
    }

    zerodha_margin = ZerodhaMargin(session, enctoken, headers)
    equity_margin, commodity_margin = zerodha_margin.fetch_margin()

    print("\nZerodha Margin Details:")
    print(f"Equity Margin: {equity_margin}")
    print(f"Commodity Margin: {commodity_margin}")

    # Initialize VolumeCalculation with necessary data
    volume_calculator = VolumeCalculation(equity_margin, predicted_prices, safe_volumes)

    # Calculate adjusted quantities
    adjusted_quantities = volume_calculator.execute_volume_calculation()

    print("\nAdjusted Quantities for Each ETF:")
    for etf, adjusted_quantity in adjusted_quantities.items():
        print(f"{etf}: {adjusted_quantity}")

    # Create DataStore and add data
    datastore = DataStore()
    
    for etf, adjusted_quantity in adjusted_quantities.items():
        predicted_price = predicted_prices.get(etf, None)
        datastore.add_data(etf, adjusted_quantity, predicted_price)

    # Get and display the stored data
    print("\nStored Data:")
    data = datastore.get_data()
    for entry in data:
        print(f"Symbol: {entry['symbol_a']}, Quantity: {entry['quantity_a']}, Predicted Price: {entry['price_a']}")

    # Create an instance of OrderStore
    order_store = OrderStore()

    # Generate orders using data from DataStore
    order_store.generate_orders(datastore)

    # Retrieve and display the orders
    print("\nGenerated Orders:")
    for order in order_store.get_orders():
        print(f"Symbol: {order['symbol_b']}, Price: {order['price_b']}, Quantity: {order['quantity_b']}, TXN: {order['txn_b']}")

    # Create an instance of PayloadStore
    payload_store = PayloadStore()

    # Generate payloads from orders
    payload_store.generate_payloads(order_store)

    # Retrieve and display the payloads
    print("\nGenerated Payloads:")
    for payload in payload_store.get_payloads():
        print(payload)

if __name__ == "__main__":
    main()

# %% [raw]
# manual update

# %%
import yfinance as yf
from datetime import datetime
import numpy as np
import pandas as pd
import requests
import pyotp
from sklearn.linear_model import LinearRegression

import time
from datetime import datetime, timedelta

class TimeUtils:
    """Utility class for time-related functions."""
    
    @staticmethod
    def get_current_datetime_hh_mm_ss_ms():
        """Returns the current datetime with milliseconds."""
        return datetime.now()

    @staticmethod
    def get_current_datetime_hh_mm_ss():
        """Returns the current time in HH:MM:SS format."""
        return datetime.now().strftime("%H:%M:%S")

    @staticmethod
    def print_current_datetime_hh_mm_ss_ms():
        """Prints the current datetime with milliseconds."""
        print(TimeUtils.get_current_datetime_hh_mm_ss_ms().strftime("%H:%M:%S.%f"))

    @staticmethod
    def print_current_datetime_hh_mm_ss():
        """Prints the current time in HH:MM:SS format."""
        print(TimeUtils.get_current_datetime_hh_mm_ss())

    @staticmethod
    def execute_at_precise_time(target_time, func):
        """
        Executes a given function at a precise target time.

        :param target_time: Datetime object specifying the execution time.
        :param func: Function to execute.
        """
        delay = (target_time - datetime.now()).total_seconds()
        
        # Sleep until just before the target time
        time.sleep(max(0, delay - 0.1))
        
        # Busy-wait until the exact moment
        while datetime.now() < target_time:
            pass

        func()

class ETFPricePredictor:
    """Predicts ETF opening prices using linear regression based on underlying index data."""

    def __init__(self, assets, start_date="2025-01-01"):
        self.assets = assets
        self.start_date = start_date
        self.end_date = datetime.today().strftime("%Y-%m-%d")
        self.closing_prices = None
        self.opening_prices = {}
        self.models = {}

    def fetch_closing_prices(self):
        """Fetches daily closing prices for underlying indices and ETFs."""
        symbols = list(self.assets.keys()) + list(self.assets.values())  
        try:
            data = yf.download(symbols, start=self.start_date, end=self.end_date)["Close"]
            data.dropna(inplace=True)  
            self.closing_prices = data
        except Exception as e:
            print(f"Error fetching closing prices: {e}")

    def fetch_opening_prices(self):
        """Fetches today's opening prices for the underlying indices."""
        for index in self.assets.keys():
            try:
                data = yf.Ticker(index).history(period="1d")
                self.opening_prices[index] = data["Open"].iloc[0] if not data.empty else None
            except Exception as e:
                print(f"Error fetching opening price for {index}: {e}")
                self.opening_prices[index] = None  

    def train_models(self):
        """Trains a Linear Regression model for each ETF based on its underlying index."""
        if self.closing_prices is None:
            print("Error: Closing prices not available. Fetch data first.")
            return
        
        for index, etf in self.assets.items():
            try:
                X = self.closing_prices[index].values.reshape(-1, 1)  
                y = self.closing_prices[etf].values.reshape(-1, 1)  
                
                model = LinearRegression()
                model.fit(X, y)  
                self.models[etf] = model
            except Exception as e:
                print(f"Error training model for {etf}: {e}")

    def predict_opening_prices(self):
        """Predicts today's opening price for ETFs using the trained regression models."""
        predicted_openings = {}
        for index, etf in self.assets.items():
            if self.opening_prices.get(index) is not None and etf in self.models:
                try:
                    predicted_openings[etf] = self.models[etf].predict(np.array([[self.opening_prices[index]]]))[0][0]
                except Exception as e:
                    print(f"Error predicting opening price for {etf}: {e}")
                    predicted_openings[etf] = None
            else:
                predicted_openings[etf] = "Market Closed or Model Not Available"
        return predicted_openings

class ETFVolumeAnalyzer:
    """Analyzes ETF trading volume and calculates safe volume."""

    def __init__(self, assets, start_date="2025-01-01"):
        self.etf_symbols = list(assets.values())  
        self.start_date = start_date
        self.end_date = datetime.today().strftime("%Y-%m-%d")
        self.average_volumes = {}
        self.safe_volumes = {}

    def fetch_average_volumes(self):
        """Fetches daily ETF trading volumes and calculates the average volume for each ETF."""
        try:
            volume_data = yf.download(self.etf_symbols, start=self.start_date, end=self.end_date)["Volume"]
            self.average_volumes = volume_data.mean().to_dict()  
        except Exception as e:
            print(f"Error fetching ETF volumes: {e}")

    def calculate_safe_volumes(self):
        """Calculates safe volume using the formula: Average Volume / 4500."""
        for etf, avg_volume in self.average_volumes.items():
            self.safe_volumes[etf] = int(avg_volume / 4500)  
            # 6.25 hours = 22,500 seconds | 22500/5 = 4500

    def get_safe_volumes(self):
        """Returns the calculated safe volumes."""
        return self.safe_volumes

class ZerodhaLogin:
    """Handles Zerodha Kite login and maintains a session for order placement."""
    
    LOGIN_URL = "https://kite.zerodha.com/api/login"
    TOTP_URL = "https://kite.zerodha.com/api/twofa"

    def __init__(self, username, password, totp_key):
        self.username = username
        self.password = password
        self.totp_key = totp_key
        self.session = requests.Session()
        self.enctoken = None  
        self.headers = None  

    def login(self):
        """Performs login using Zerodha credentials and TOTP authentication."""
        try:
            res1 = self.session.post(self.LOGIN_URL, data={
                "user_id": self.username,
                "password": self.password,
                "type": "user_id"
            })
            res1.raise_for_status()  
            loginRes = res1.json()

            if "data" not in loginRes or "request_id" not in loginRes["data"]:
                raise ValueError("Login failed: Invalid response from server")

            totp_value = pyotp.TOTP(self.totp_key).now()
            finalRes = self.session.post(self.TOTP_URL, data={
                "request_id": loginRes["data"]["request_id"],
                "twofa_value": totp_value,
                "user_id": loginRes["data"]["user_id"],
                "twofa_type": "totp"
            })
            finalRes.raise_for_status()
            authRes = finalRes.json()

            if "status" not in authRes or authRes["status"] != "success":
                raise ValueError("TOTP Authentication failed")

            self.enctoken = self.session.cookies.get_dict().get("enctoken", None)
            if not self.enctoken:
                raise ValueError("Failed to retrieve enctoken")

            print("Login successful!")
            return self.session, self.enctoken

        except requests.exceptions.RequestException as e:
            print(f"HTTP Request Failed: {e}")
        except ValueError as ve:
            print(f"Error: {ve}")

class ZerodhaMargin:
    """Fetches margin details from Zerodha Kite API using an existing session."""

    MARGIN_URL = "https://kite.zerodha.com/oms/user/margins"

    def __init__(self, session, enctoken, headers):
        """Initialize with an existing authenticated session and headers."""
        self.session = session
        self.enctoken = enctoken
        self.headers = headers

        if not self.enctoken or not self.headers:
            raise ValueError("Authentication token or headers are missing. Cannot fetch margin data.")

    def fetch_margin(self):
        """Fetches margin details and extracts net margin for equity and commodity."""
        try:
            response = self.session.get(self.MARGIN_URL, headers=self.headers)
            response.raise_for_status()
            data = response.json()

            equity_margin = data["data"]["equity"]["net"]
            commodity_margin = data["data"]["commodity"]["net"]

            return equity_margin, commodity_margin

        except requests.exceptions.RequestException as e:
            print(f"HTTP Request Failed: {e}")
            return None, None

class VolumeCalculation:
    """Calculates adjusted trading volumes based on margin and safe volumes."""

    def __init__(self, equity_margin, predicted_openings, safe_volumes):
        self.equity_margin = equity_margin
        self.predicted_openings = predicted_openings
        self.safe_volumes = safe_volumes

    def calculate_leveraged_margin(self):
        """Calculates leveraged margin as equity margin multiplied by 5."""
        return self.equity_margin * 5

    def calculate_discount_margin(self):
        """Calculates discounted margin as (equity margin * 5) - 5% of equity margin."""
        return (self.equity_margin * 5) - (self.equity_margin * 5 * 0.05)

    def calculate_trade_values(self):
        """Calculates trade value for each ETF as predicted_openings * safe_volumes."""
        return {etf: self.predicted_openings[etf] * self.safe_volumes[etf] for etf in self.safe_volumes}

    def calculate_total_trade_value(self, trade_values):
        """Calculates total trade value as the sum of all individual trade values."""
        return sum(trade_values.values())

    def calculate_allocation_ratio(self, discount_margin, total_trade_value):
        """Calculates allocation ratio as discount_margin / total_trade_value."""
        return discount_margin / total_trade_value if total_trade_value > 0 else 0

    def calculate_adjusted_quantities(self, allocation_ratio):
        """Calculates adjusted quantity for each ETF as allocation_ratio * safe_volumes."""
        return {etf: int(allocation_ratio * self.safe_volumes[etf]) for etf in self.safe_volumes}

    def execute_volume_calculation(self):
        """Executes all calculations and returns adjusted quantities."""
        discount_margin = self.calculate_discount_margin()  # Use discount margin instead of leveraged margin
        trade_values = self.calculate_trade_values()
        total_trade_value = self.calculate_total_trade_value(trade_values)
        allocation_ratio = self.calculate_allocation_ratio(discount_margin, total_trade_value)
        adjusted_quantities = self.calculate_adjusted_quantities(allocation_ratio)
        
        return adjusted_quantities

class DataStore:
    """Class to store symbols, adjusted quantities, and predicted prices."""

    def __init__(self):
        self.data = []

    def add_data(self, symbol, adjusted_quantity, predicted_price):
        """Adds a new entry to the data store."""
        self.data.append({
            'symbol_a': symbol,
            'quantity_a': adjusted_quantity,
            'price_a': predicted_price
        })

    def get_data(self):
        """Returns all stored data."""
        return self.data

class OrderStore:
    """Generates order data using symbols, quantities, and prices from DataStore."""

    def __init__(self):
        self.orders = []  # List to store order data

    def format_symbol(self, symbol):
        """Removes '.NS' from the symbol."""
        return symbol.split(".")[0]

    def add_order(self, symbol, quantity, price):
        """Creates two order records (BUY and SELL) for each ETF."""
        symbol_b = self.format_symbol(symbol)  # Format symbol
        price_b_buy = round(price * 0.95, 2)  # 0.5% lower for BUY
        price_b_sell = round(price * 1.05, 2)  # 0.5% higher for SELL
        quantity_b = quantity

        # Add BUY order
        self.orders.append({
            "symbol_b": symbol_b,
            "price_b": price_b_buy,
            "quantity_b": quantity_b,
            "txn_b": "BUY"
        })

        # Add SELL order
        self.orders.append({
            "symbol_b": symbol_b,
            "price_b": price_b_sell,
            "quantity_b": quantity_b,
            "txn_b": "SELL"
        })

    def generate_orders(self, data_store):
        """Creates orders from data stored in DataStore."""
        for entry in data_store.get_data():
            self.add_order(entry['symbol_a'], entry['quantity_a'], entry['price_a'])

    def get_orders(self):
        """Returns the list of generated orders."""
        return self.orders

class PayloadStore:
    """Stores order payloads in the required format."""

    def __init__(self):
        self.orders = []  # List to store formatted order payloads

    def add_order(self, symbol, txn, quantity, price):
        """Creates an order payload and adds it to the list."""
        order_payload = {
            "variety": "regular",
            "exchange": "NSE",
            "order_type": "LIMIT",
            "tradingsymbol": symbol,
            "transaction_type": txn,
            "quantity": quantity,
            "price": price,
            "product": "MIS",
            "validity": "TTL",
            "validity_ttl": "1"
        }
        self.orders.append(order_payload)

    def generate_payloads(self, order_store):
        """Generates payloads from orders in OrderStore."""
        for order in order_store.get_orders():
            self.add_order(
                symbol=order["symbol_b"],
                txn=order["txn_b"],
                quantity=order["quantity_b"],
                price=order["price_b"]
            )

    def get_payloads(self):
        """Returns the generated payloads."""
        return self.orders

class ZerodhaOrders:
    """Handles synchronous order placement using requests."""

    ORDER_URL = "https://kite.zerodha.com/oms/orders/regular"

    def __init__(self, session, enctoken, headers):
        """Initialize with an existing authenticated session and headers."""
        self.session = session
        self.enctoken = enctoken
        self.headers = headers

        if not self.enctoken or not self.headers:
            raise ValueError("Authentication token or headers are missing. Cannot place orders.")

    def place_order(self, order_data):
        """Places a single order synchronously."""
        try:
            response = requests.post(self.ORDER_URL, headers=self.headers, data=order_data)
            return response.json()
        except Exception as e:
            return {"error": str(e)}

    def place_orders(self, order_payloads):
        """Places multiple orders synchronously."""
        results = []
        for order in order_payloads:
            result = self.place_order(order)
            results.append(result)
        return results

def main():
    """Main execution function"""
    assets = {
        "^NSEI": "NIFTYBEES.NS",      # Nifty 50 → Niftybees
        "^NSMIDCP": "JUNIORBEES.NS",   # Nifty Next 50 → Junior Bees
        "^NSEBANK": "BANKBEES.NS"      # Nifty Bank → Bank Bees
    }

    # Predict ETF opening prices
    predictor = ETFPricePredictor(assets)
    
    print("Fetching historical closing prices...")
    predictor.fetch_closing_prices()

    print("Fetching today's opening prices...")
    predictor.fetch_opening_prices()

    print("Training regression models...")
    predictor.train_models()

    print("\nToday's Opening Prices:")
    for index, price in predictor.opening_prices.items():
        print(f"{index}: {price}")

    print("\nPredicted ETF Opening Prices:")
    predicted_prices = predictor.predict_opening_prices()
    for etf, price in predicted_prices.items():
        print(f"{etf}: {price:.2f}" if isinstance(price, float) else f"{etf}: {price}")

    # Analyze ETF trading volumes
    volume_analyzer = ETFVolumeAnalyzer(assets)
    
    print("\nFetching ETF volume data...")
    volume_analyzer.fetch_average_volumes()

    print("Calculating safe volumes...")
    volume_analyzer.calculate_safe_volumes()

    print("\nAverage ETF Trading Volumes:")
    for etf, avg_volume in volume_analyzer.average_volumes.items():
        print(f"{etf}: {avg_volume:,.0f}")

    print("\nSafe Trading Volumes:")
    safe_volumes = volume_analyzer.get_safe_volumes()
    for etf, safe_vol in safe_volumes.items():
        print(f"{etf}: {safe_vol}")

    # Log in to Zerodha
    zerodha = ZerodhaLogin("DXU151", "Pratibha", "FLJBDJNEBOIMZZZPE25YYYR72Y2B2IAP")
    session, enctoken = zerodha.login()

    # Ensure successful login before proceeding
    if not enctoken:
        print("Zerodha login failed. Exiting...")
        return  

    # Initialize ZerodhaMargin with correct headers
    headers = {
        "Authorization": f"enctoken {enctoken}",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36",
        "Referer": "https://kite.zerodha.com/dashboard",
        "Accept-Language": "en-US,en;q=0.6",
        "Content-type": "application/x-www-form-urlencoded",
        "Accept": "application/json, text/plain, */*",
    }

    zerodha_margin = ZerodhaMargin(session, enctoken, headers)
    equity_margin, commodity_margin = zerodha_margin.fetch_margin()

    print("\nZerodha Margin Details:")
    print(f"Equity Margin: {equity_margin}")
    print(f"Commodity Margin: {commodity_margin}")

    # Initialize VolumeCalculation with necessary data
    volume_calculator = VolumeCalculation(equity_margin, predicted_prices, safe_volumes)

    # Calculate adjusted quantities
    adjusted_quantities = volume_calculator.execute_volume_calculation()

    print("\nAdjusted Quantities for Each ETF:")
    for etf, adjusted_quantity in adjusted_quantities.items():
        print(f"{etf}: {adjusted_quantity}")

    # Create DataStore and add data
    datastore = DataStore()
    
    for etf, adjusted_quantity in adjusted_quantities.items():
        predicted_price = predicted_prices.get(etf, None)
        datastore.add_data(etf, adjusted_quantity, predicted_price)

    # Get and display the stored data
    print("\nStored Data:")
    data = datastore.get_data()
    for entry in data:
        print(f"Symbol: {entry['symbol_a']}, Quantity: {entry['quantity_a']}, Predicted Price: {entry['price_a']}")

    # Create an instance of OrderStore
    order_store = OrderStore()

    # Generate orders using data from DataStore
    order_store.generate_orders(datastore)

    # Retrieve and display the orders
    print("\nGenerated Orders:")
    for order in order_store.get_orders():
        print(f"Symbol: {order['symbol_b']}, Price: {order['price_b']}, Quantity: {order['quantity_b']}, TXN: {order['txn_b']}")

    # Create an instance of PayloadStore
    payload_store = PayloadStore()

    # Generate payloads from orders
    payload_store.generate_payloads(order_store)

    # Retrieve and display the payloads
    print("\nGenerated Payloads:")
    for payload in payload_store.get_payloads():
        print(payload)

    order_payloads = payload_store.get_payloads()  # Get the actual data

    # Initialize ZerodhaOrders
    zerodha_orders = ZerodhaOrders(session, enctoken, headers)

    # Place orders
    results = zerodha_orders.place_orders(order_payloads)

    # Print responses
    print("\nOrder Placement Results:", results)

if __name__ == "__main__":
    main()

# %% [raw]
# manual update

# %%
import yfinance as yf
from datetime import datetime
import numpy as np
import pandas as pd
import requests
import pyotp
from sklearn.linear_model import LinearRegression

import time
from datetime import datetime, timedelta

class TimeUtils:
    """Utility class for time-related functions."""
    
    @staticmethod
    def get_current_datetime_hh_mm_ss_ms():
        """Returns the current datetime with milliseconds."""
        return datetime.now()

    @staticmethod
    def get_current_datetime_hh_mm_ss():
        """Returns the current time in HH:MM:SS format."""
        return datetime.now().strftime("%H:%M:%S")

    @staticmethod
    def print_current_datetime_hh_mm_ss_ms():
        """Prints the current datetime with milliseconds."""
        print(TimeUtils.get_current_datetime_hh_mm_ss_ms().strftime("%H:%M:%S.%f"))

    @staticmethod
    def print_current_datetime_hh_mm_ss():
        """Prints the current time in HH:MM:SS format."""
        print(TimeUtils.get_current_datetime_hh_mm_ss())

    @staticmethod
    def execute_at_precise_time(target_time, func):
        """
        Executes a given function at a precise target time.

        :param target_time: Datetime object specifying the execution time.
        :param func: Function to execute.
        """
        delay = (target_time - datetime.now()).total_seconds()
        
        # Sleep until just before the target time
        time.sleep(max(0, delay - 0.1))
        
        # Busy-wait until the exact moment
        while datetime.now() < target_time:
            pass

        func()

class ETFPricePredictor:
    """Predicts ETF opening prices using linear regression based on underlying index data."""

    def __init__(self, assets, start_date="2025-01-01"):
        self.assets = assets
        self.start_date = start_date
        self.end_date = datetime.today().strftime("%Y-%m-%d")
        self.closing_prices = None
        self.opening_prices = {}
        self.models = {}

    def fetch_closing_prices(self):
        """Fetches daily closing prices for underlying indices and ETFs."""
        symbols = list(self.assets.keys()) + list(self.assets.values())  
        try:
            data = yf.download(symbols, start=self.start_date, end=self.end_date)["Close"]
            data.dropna(inplace=True)  
            self.closing_prices = data
        except Exception as e:
            print(f"Error fetching closing prices: {e}")

    def fetch_opening_prices(self):
        """Fetches today's opening prices for the underlying indices."""
        for index in self.assets.keys():
            try:
                data = yf.Ticker(index).history(period="1d")
                self.opening_prices[index] = data["Open"].iloc[0] if not data.empty else None
            except Exception as e:
                print(f"Error fetching opening price for {index}: {e}")
                self.opening_prices[index] = None  

    def train_models(self):
        """Trains a Linear Regression model for each ETF based on its underlying index."""
        if self.closing_prices is None:
            print("Error: Closing prices not available. Fetch data first.")
            return
        
        for index, etf in self.assets.items():
            try:
                X = self.closing_prices[index].values.reshape(-1, 1)  
                y = self.closing_prices[etf].values.reshape(-1, 1)  
                
                model = LinearRegression()
                model.fit(X, y)  
                self.models[etf] = model
            except Exception as e:
                print(f"Error training model for {etf}: {e}")

    def predict_opening_prices(self):
        """Predicts today's opening price for ETFs using the trained regression models."""
        predicted_openings = {}
        for index, etf in self.assets.items():
            if self.opening_prices.get(index) is not None and etf in self.models:
                try:
                    predicted_openings[etf] = self.models[etf].predict(np.array([[self.opening_prices[index]]]))[0][0]
                except Exception as e:
                    print(f"Error predicting opening price for {etf}: {e}")
                    predicted_openings[etf] = None
            else:
                predicted_openings[etf] = "Market Closed or Model Not Available"
        return predicted_openings

class ETFVolumeAnalyzer:
    """Analyzes ETF trading volume and calculates safe volume."""

    def __init__(self, assets, start_date="2025-01-01"):
        self.etf_symbols = list(assets.values())  
        self.start_date = start_date
        self.end_date = datetime.today().strftime("%Y-%m-%d")
        self.average_volumes = {}
        self.safe_volumes = {}

    def fetch_average_volumes(self):
        """Fetches daily ETF trading volumes and calculates the average volume for each ETF."""
        try:
            volume_data = yf.download(self.etf_symbols, start=self.start_date, end=self.end_date)["Volume"]
            self.average_volumes = volume_data.mean().to_dict()  
        except Exception as e:
            print(f"Error fetching ETF volumes: {e}")

    def calculate_safe_volumes(self):
        """Calculates safe volume using the formula: Average Volume / 4500."""
        for etf, avg_volume in self.average_volumes.items():
            self.safe_volumes[etf] = int(avg_volume / 4500)  
            # 6.25 hours = 22,500 seconds | 22500/5 = 4500

    def get_safe_volumes(self):
        """Returns the calculated safe volumes."""
        return self.safe_volumes

class ZerodhaLogin:
    """Handles Zerodha Kite login and maintains a session for order placement."""
    
    LOGIN_URL = "https://kite.zerodha.com/api/login"
    TOTP_URL = "https://kite.zerodha.com/api/twofa"

    def __init__(self, username, password, totp_key):
        self.username = username
        self.password = password
        self.totp_key = totp_key
        self.session = requests.Session()
        self.enctoken = None  
        self.headers = None  

    def login(self):
        """Performs login using Zerodha credentials and TOTP authentication."""
        try:
            res1 = self.session.post(self.LOGIN_URL, data={
                "user_id": self.username,
                "password": self.password,
                "type": "user_id"
            })
            res1.raise_for_status()  
            loginRes = res1.json()

            if "data" not in loginRes or "request_id" not in loginRes["data"]:
                raise ValueError("Login failed: Invalid response from server")

            totp_value = pyotp.TOTP(self.totp_key).now()
            finalRes = self.session.post(self.TOTP_URL, data={
                "request_id": loginRes["data"]["request_id"],
                "twofa_value": totp_value,
                "user_id": loginRes["data"]["user_id"],
                "twofa_type": "totp"
            })
            finalRes.raise_for_status()
            authRes = finalRes.json()

            if "status" not in authRes or authRes["status"] != "success":
                raise ValueError("TOTP Authentication failed")

            self.enctoken = self.session.cookies.get_dict().get("enctoken", None)
            if not self.enctoken:
                raise ValueError("Failed to retrieve enctoken")

            print("Login successful!")
            return self.session, self.enctoken

        except requests.exceptions.RequestException as e:
            print(f"HTTP Request Failed: {e}")
        except ValueError as ve:
            print(f"Error: {ve}")

class ZerodhaMargin:
    """Fetches margin details from Zerodha Kite API using an existing session."""

    MARGIN_URL = "https://kite.zerodha.com/oms/user/margins"

    def __init__(self, session, enctoken, headers):
        """Initialize with an existing authenticated session and headers."""
        self.session = session
        self.enctoken = enctoken
        self.headers = headers

        if not self.enctoken or not self.headers:
            raise ValueError("Authentication token or headers are missing. Cannot fetch margin data.")

    def fetch_margin(self):
        """Fetches margin details and extracts net margin for equity and commodity."""
        try:
            response = self.session.get(self.MARGIN_URL, headers=self.headers)
            response.raise_for_status()
            data = response.json()

            equity_margin = data["data"]["equity"]["net"]
            commodity_margin = data["data"]["commodity"]["net"]

            return equity_margin, commodity_margin

        except requests.exceptions.RequestException as e:
            print(f"HTTP Request Failed: {e}")
            return None, None

class VolumeCalculation:
    """Calculates adjusted trading volumes based on margin and safe volumes."""

    def __init__(self, equity_margin, predicted_openings, safe_volumes):
        self.equity_margin = equity_margin
        self.predicted_openings = predicted_openings
        self.safe_volumes = safe_volumes

    def calculate_leveraged_margin(self):
        """Calculates leveraged margin as equity margin multiplied by 5."""
        return self.equity_margin * 5

    def calculate_discount_margin(self):
        """Calculates discounted margin as (equity margin * 5) - 5% of equity margin."""
        return (self.equity_margin * 5) - (self.equity_margin * 5 * 0.05)

    def calculate_trade_values(self):
        """Calculates trade value for each ETF as predicted_openings * safe_volumes."""
        return {etf: self.predicted_openings[etf] * self.safe_volumes[etf] for etf in self.safe_volumes}

    def calculate_total_trade_value(self, trade_values):
        """Calculates total trade value as the sum of all individual trade values."""
        return sum(trade_values.values())

    def calculate_allocation_ratio(self, discount_margin, total_trade_value):
        """Calculates allocation ratio as discount_margin / total_trade_value."""
        return discount_margin / total_trade_value if total_trade_value > 0 else 0

    def calculate_adjusted_quantities(self, allocation_ratio):
        """Calculates adjusted quantity for each ETF as allocation_ratio * safe_volumes."""
        return {etf: int(allocation_ratio * self.safe_volumes[etf]) for etf in self.safe_volumes}

    def execute_volume_calculation(self):
        """Executes all calculations and returns adjusted quantities."""
        discount_margin = self.calculate_discount_margin()  # Use discount margin instead of leveraged margin
        trade_values = self.calculate_trade_values()
        total_trade_value = self.calculate_total_trade_value(trade_values)
        allocation_ratio = self.calculate_allocation_ratio(discount_margin, total_trade_value)
        adjusted_quantities = self.calculate_adjusted_quantities(allocation_ratio)
        
        return adjusted_quantities

class DataStore:
    """Class to store symbols, adjusted quantities, and predicted prices."""

    def __init__(self):
        self.data = []

    def add_data(self, symbol, adjusted_quantity, predicted_price):
        """Adds a new entry to the data store."""
        self.data.append({
            'symbol_a': symbol,
            'quantity_a': adjusted_quantity,
            'price_a': predicted_price
        })

    def get_data(self):
        """Returns all stored data."""
        return self.data

class OrderStore:
    """Generates order data using symbols, quantities, and prices from DataStore."""

    def __init__(self):
        self.orders = []  # List to store order data

    def format_symbol(self, symbol):
        """Removes '.NS' from the symbol."""
        return symbol.split(".")[0]

    def add_order(self, symbol, quantity, price):
        """Creates two order records (BUY and SELL) for each ETF."""
        symbol_b = self.format_symbol(symbol)  # Format symbol
        price_b_buy = round(price * 0.95, 2)  # 0.5% lower for BUY
        price_b_sell = round(price * 1.05, 2)  # 0.5% higher for SELL
        quantity_b = quantity

        # Add BUY order
        self.orders.append({
            "symbol_b": symbol_b,
            "price_b": price_b_buy,
            "quantity_b": quantity_b,
            "txn_b": "BUY"
        })

        # Add SELL order
        self.orders.append({
            "symbol_b": symbol_b,
            "price_b": price_b_sell,
            "quantity_b": quantity_b,
            "txn_b": "SELL"
        })

    def generate_orders(self, data_store):
        """Creates orders from data stored in DataStore."""
        for entry in data_store.get_data():
            self.add_order(entry['symbol_a'], entry['quantity_a'], entry['price_a'])

    def get_orders(self):
        """Returns the list of generated orders."""
        return self.orders

class PayloadStore:
    """Stores order payloads in the required format."""

    def __init__(self):
        self.orders = []  # List to store formatted order payloads

    def add_order(self, symbol, txn, quantity, price):
        """Creates an order payload and adds it to the list."""
        order_payload = {
            "variety": "regular",
            "exchange": "NSE",
            "order_type": "LIMIT",
            "tradingsymbol": symbol,
            "transaction_type": txn,
            "quantity": quantity,
            "price": price,
            "product": "MIS",
            "validity": "TTL",
            "validity_ttl": "1"
        }
        self.orders.append(order_payload)

    def generate_payloads(self, order_store):
        """Generates payloads from orders in OrderStore."""
        for order in order_store.get_orders():
            self.add_order(
                symbol=order["symbol_b"],
                txn=order["txn_b"],
                quantity=order["quantity_b"],
                price=order["price_b"]
            )

    def get_payloads(self):
        """Returns the generated payloads."""
        return self.orders

class ZerodhaOrders:
    """Handles synchronous order placement using requests."""

    ORDER_URL = "https://kite.zerodha.com/oms/orders/regular"

    def __init__(self, session, enctoken, headers):
        """Initialize with an existing authenticated session and headers."""
        self.session = session
        self.enctoken = enctoken
        self.headers = headers

        if not self.enctoken or not self.headers:
            raise ValueError("Authentication token or headers are missing. Cannot place orders.")

    def place_order(self, order_data):
        """Places a single order synchronously."""
        try:
            response = requests.post(self.ORDER_URL, headers=self.headers, data=order_data)
            return response.json()
        except Exception as e:
            return {"error": str(e)}

    def place_orders(self, order_payloads):
        """Places multiple orders synchronously."""
        results = []
        for order in order_payloads:
            result = self.place_order(order)
            results.append(result)
        return results

def main():
    """Main execution function"""
    assets = {
        "^NSEI": "NIFTYBEES.NS",      # Nifty 50 → Niftybees
        "^NSMIDCP": "JUNIORBEES.NS",   # Nifty Next 50 → Junior Bees
        "^NSEBANK": "BANKBEES.NS"      # Nifty Bank → Bank Bees
    }

    # Predict ETF opening prices
    predictor = ETFPricePredictor(assets)
    
    print("Fetching historical closing prices...")
    predictor.fetch_closing_prices()

    print("Fetching today's opening prices...")
    predictor.fetch_opening_prices()

    print("Training regression models...")
    predictor.train_models()

    print("\nToday's Opening Prices:")
    for index, price in predictor.opening_prices.items():
        print(f"{index}: {price}")

    print("\nPredicted ETF Opening Prices:")
    predicted_prices = predictor.predict_opening_prices()
    for etf, price in predicted_prices.items():
        print(f"{etf}: {price:.2f}" if isinstance(price, float) else f"{etf}: {price}")

    # Analyze ETF trading volumes
    volume_analyzer = ETFVolumeAnalyzer(assets)
    
    print("\nFetching ETF volume data...")
    volume_analyzer.fetch_average_volumes()

    print("Calculating safe volumes...")
    volume_analyzer.calculate_safe_volumes()

    print("\nAverage ETF Trading Volumes:")
    for etf, avg_volume in volume_analyzer.average_volumes.items():
        print(f"{etf}: {avg_volume:,.0f}")

    print("\nSafe Trading Volumes:")
    safe_volumes = volume_analyzer.get_safe_volumes()
    for etf, safe_vol in safe_volumes.items():
        print(f"{etf}: {safe_vol}")

    # Log in to Zerodha
    zerodha = ZerodhaLogin("DXU151", "Pratibha", "FLJBDJNEBOIMZZZPE25YYYR72Y2B2IAP")
    session, enctoken = zerodha.login()

    # Ensure successful login before proceeding
    if not enctoken:
        print("Zerodha login failed. Exiting...")
        return  

    # Initialize ZerodhaMargin with correct headers
    headers = {
        "Authorization": f"enctoken {enctoken}",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36",
        "Referer": "https://kite.zerodha.com/dashboard",
        "Accept-Language": "en-US,en;q=0.6",
        "Content-type": "application/x-www-form-urlencoded",
        "Accept": "application/json, text/plain, */*",
    }

    zerodha_margin = ZerodhaMargin(session, enctoken, headers)
    equity_margin, commodity_margin = zerodha_margin.fetch_margin()

    print("\nZerodha Margin Details:")
    print(f"Equity Margin: {equity_margin}")
    print(f"Commodity Margin: {commodity_margin}")

    # Initialize VolumeCalculation with necessary data
    volume_calculator = VolumeCalculation(equity_margin, predicted_prices, safe_volumes)

    # Calculate adjusted quantities
    adjusted_quantities = volume_calculator.execute_volume_calculation()

    print("\nAdjusted Quantities for Each ETF:")
    for etf, adjusted_quantity in adjusted_quantities.items():
        print(f"{etf}: {adjusted_quantity}")

    # Create DataStore and add data
    datastore = DataStore()
    
    for etf, adjusted_quantity in adjusted_quantities.items():
        predicted_price = predicted_prices.get(etf, None)
        datastore.add_data(etf, adjusted_quantity, predicted_price)

    # Get and display the stored data
    print("\nStored Data:")
    data = datastore.get_data()
    for entry in data:
        print(f"Symbol: {entry['symbol_a']}, Quantity: {entry['quantity_a']}, Predicted Price: {entry['price_a']}")

    # Create an instance of OrderStore
    order_store = OrderStore()

    # Generate orders using data from DataStore
    order_store.generate_orders(datastore)

    # Retrieve and display the orders
    print("\nGenerated Orders:")
    for order in order_store.get_orders():
        print(f"Symbol: {order['symbol_b']}, Price: {order['price_b']}, Quantity: {order['quantity_b']}, TXN: {order['txn_b']}")

    # Create an instance of PayloadStore
    payload_store = PayloadStore()

    # Generate payloads from orders
    payload_store.generate_payloads(order_store)

    # Retrieve and display the payloads
    print("\nGenerated Payloads:")
    for payload in payload_store.get_payloads():
        print(payload)

    order_payloads = payload_store.get_payloads()  # Get the actual data

    # Initialize ZerodhaOrders
    zerodha_orders = ZerodhaOrders(session, enctoken, headers)

    # Place orders
    results = zerodha_orders.place_orders(order_payloads)

    # Define the exact target time
    now = datetime.now()
    target_time = now.replace(hour=9, minute=15, second=0, microsecond=0)

    def execute_orders():
        """Function to place orders precisely at 9:15 AM"""
        # Assuming session, enctoken, and headers are already initialized
        #zerodha_orders = ZerodhaOrders(session, enctoken, headers)
        #order_payloads = payload_store.get_payloads()
        results = zerodha_orders.place_orders(order_payloads)
            
        # Print results
        #print("\nOrder Placement Results:", results)

    # Execute `execute_orders` at exactly 9:15 AM
    TimeUtils.execute_at_precise_time(target_time, execute_orders)

    # Print responses
    print("\nOrder Placement Results:", results)

if __name__ == "__main__":
    main()

# %% [raw]
# time.sleep for yahoo finance requests

# %%
import yfinance as yf
from datetime import datetime
import numpy as np
import pandas as pd
import requests
import pyotp
from sklearn.linear_model import LinearRegression

import time
from datetime import datetime, timedelta

class TimeUtils:
    """Utility class for time-related functions."""
    
    @staticmethod
    def get_current_datetime_hh_mm_ss_ms():
        """Returns the current datetime with milliseconds."""
        return datetime.now()

    @staticmethod
    def get_current_datetime_hh_mm_ss():
        """Returns the current time in HH:MM:SS format."""
        return datetime.now().strftime("%H:%M:%S")

    @staticmethod
    def print_current_datetime_hh_mm_ss_ms():
        """Prints the current datetime with milliseconds."""
        print(TimeUtils.get_current_datetime_hh_mm_ss_ms().strftime("%H:%M:%S.%f"))

    @staticmethod
    def print_current_datetime_hh_mm_ss():
        """Prints the current time in HH:MM:SS format."""
        print(TimeUtils.get_current_datetime_hh_mm_ss())

    @staticmethod
    def execute_at_precise_time(target_time, func):
        """
        Executes a given function at a precise target time.

        :param target_time: Datetime object specifying the execution time.
        :param func: Function to execute.
        """
        delay = (target_time - datetime.now()).total_seconds()
        
        # Sleep until just before the target time
        time.sleep(max(0, delay - 0.1))
        
        # Busy-wait until the exact moment
        while datetime.now() < target_time:
            pass

        func()

class ETFPricePredictor:
    """Predicts ETF opening prices using linear regression based on underlying index data."""

    def __init__(self, assets, start_date="2025-01-01"):
        self.assets = assets
        self.start_date = start_date
        self.end_date = datetime.today().strftime("%Y-%m-%d")
        self.closing_prices = None
        self.opening_prices = {}
        self.models = {}

    def fetch_closing_prices(self):
        """Fetches daily closing prices for underlying indices and ETFs."""
        symbols = list(self.assets.keys()) + list(self.assets.values())  
        try:
            data = yf.download(symbols, start=self.start_date, end=self.end_date)["Close"]
            data.dropna(inplace=True)  
            self.closing_prices = data
        except Exception as e:
            print(f"Error fetching closing prices: {e}")

    def fetch_opening_prices(self):
        """Fetches today's opening prices for the underlying indices."""
        for index in self.assets.keys():
            try:
                data = yf.Ticker(index).history(period="1d")
                self.opening_prices[index] = data["Open"].iloc[0] if not data.empty else None
            except Exception as e:
                print(f"Error fetching opening price for {index}: {e}")
                self.opening_prices[index] = None  

    def train_models(self):
        """Trains a Linear Regression model for each ETF based on its underlying index."""
        if self.closing_prices is None:
            print("Error: Closing prices not available. Fetch data first.")
            return
        
        for index, etf in self.assets.items():
            try:
                X = self.closing_prices[index].values.reshape(-1, 1)  
                y = self.closing_prices[etf].values.reshape(-1, 1)  
                
                model = LinearRegression()
                model.fit(X, y)  
                self.models[etf] = model
            except Exception as e:
                print(f"Error training model for {etf}: {e}")

    def predict_opening_prices(self):
        """Predicts today's opening price for ETFs using the trained regression models."""
        predicted_openings = {}
        for index, etf in self.assets.items():
            if self.opening_prices.get(index) is not None and etf in self.models:
                try:
                    predicted_openings[etf] = self.models[etf].predict(np.array([[self.opening_prices[index]]]))[0][0]
                except Exception as e:
                    print(f"Error predicting opening price for {etf}: {e}")
                    predicted_openings[etf] = None
            else:
                predicted_openings[etf] = "Market Closed or Model Not Available"
        return predicted_openings

class ETFVolumeAnalyzer:
    """Analyzes ETF trading volume and calculates safe volume."""

    def __init__(self, assets, start_date="2025-01-01"):
        self.etf_symbols = list(assets.values())  
        self.start_date = start_date
        self.end_date = datetime.today().strftime("%Y-%m-%d")
        self.average_volumes = {}
        self.safe_volumes = {}

    def fetch_average_volumes(self):
        """Fetches daily ETF trading volumes and calculates the average volume for each ETF."""
        try:
            volume_data = yf.download(self.etf_symbols, start=self.start_date, end=self.end_date)["Volume"]
            self.average_volumes = volume_data.mean().to_dict()  
        except Exception as e:
            print(f"Error fetching ETF volumes: {e}")

    def calculate_safe_volumes(self):
        """Calculates safe volume using the formula: Average Volume / 4500."""
        for etf, avg_volume in self.average_volumes.items():
            self.safe_volumes[etf] = int(avg_volume / 4500)  
            # 6.25 hours = 22,500 seconds | 22500/5 = 4500

    def get_safe_volumes(self):
        """Returns the calculated safe volumes."""
        return self.safe_volumes

class ZerodhaLogin:
    """Handles Zerodha Kite login and maintains a session for order placement."""
    
    LOGIN_URL = "https://kite.zerodha.com/api/login"
    TOTP_URL = "https://kite.zerodha.com/api/twofa"

    def __init__(self, username, password, totp_key):
        self.username = username
        self.password = password
        self.totp_key = totp_key
        self.session = requests.Session()
        self.enctoken = None  
        self.headers = None  

    def login(self):
        """Performs login using Zerodha credentials and TOTP authentication."""
        try:
            res1 = self.session.post(self.LOGIN_URL, data={
                "user_id": self.username,
                "password": self.password,
                "type": "user_id"
            })
            res1.raise_for_status()  
            loginRes = res1.json()

            if "data" not in loginRes or "request_id" not in loginRes["data"]:
                raise ValueError("Login failed: Invalid response from server")

            totp_value = pyotp.TOTP(self.totp_key).now()
            finalRes = self.session.post(self.TOTP_URL, data={
                "request_id": loginRes["data"]["request_id"],
                "twofa_value": totp_value,
                "user_id": loginRes["data"]["user_id"],
                "twofa_type": "totp"
            })
            finalRes.raise_for_status()
            authRes = finalRes.json()

            if "status" not in authRes or authRes["status"] != "success":
                raise ValueError("TOTP Authentication failed")

            self.enctoken = self.session.cookies.get_dict().get("enctoken", None)
            if not self.enctoken:
                raise ValueError("Failed to retrieve enctoken")

            print("Login successful!")
            return self.session, self.enctoken

        except requests.exceptions.RequestException as e:
            print(f"HTTP Request Failed: {e}")
        except ValueError as ve:
            print(f"Error: {ve}")

class ZerodhaMargin:
    """Fetches margin details from Zerodha Kite API using an existing session."""

    MARGIN_URL = "https://kite.zerodha.com/oms/user/margins"

    def __init__(self, session, enctoken, headers):
        """Initialize with an existing authenticated session and headers."""
        self.session = session
        self.enctoken = enctoken
        self.headers = headers

        if not self.enctoken or not self.headers:
            raise ValueError("Authentication token or headers are missing. Cannot fetch margin data.")

    def fetch_margin(self):
        """Fetches margin details and extracts net margin for equity and commodity."""
        try:
            response = self.session.get(self.MARGIN_URL, headers=self.headers)
            response.raise_for_status()
            data = response.json()

            equity_margin = data["data"]["equity"]["net"]
            commodity_margin = data["data"]["commodity"]["net"]

            return equity_margin, commodity_margin

        except requests.exceptions.RequestException as e:
            print(f"HTTP Request Failed: {e}")
            return None, None

class VolumeCalculation:
    """Calculates adjusted trading volumes based on margin and safe volumes."""

    def __init__(self, equity_margin, predicted_openings, safe_volumes):
        self.equity_margin = equity_margin
        self.predicted_openings = predicted_openings
        self.safe_volumes = safe_volumes

    def calculate_leveraged_margin(self):
        """Calculates leveraged margin as equity margin multiplied by 5."""
        return self.equity_margin * 5

    def calculate_discount_margin(self):
        """Calculates discounted margin as (equity margin * 5) - 5% of equity margin."""
        return (self.equity_margin * 5) - (self.equity_margin * 5 * 0.05)

    def calculate_trade_values(self):
        """Calculates trade value for each ETF as predicted_openings * safe_volumes."""
        return {etf: self.predicted_openings[etf] * self.safe_volumes[etf] for etf in self.safe_volumes}

    def calculate_total_trade_value(self, trade_values):
        """Calculates total trade value as the sum of all individual trade values."""
        return sum(trade_values.values())

    def calculate_allocation_ratio(self, discount_margin, total_trade_value):
        """Calculates allocation ratio as discount_margin / total_trade_value."""
        return discount_margin / total_trade_value if total_trade_value > 0 else 0

    def calculate_adjusted_quantities(self, allocation_ratio):
        """Calculates adjusted quantity for each ETF as allocation_ratio * safe_volumes."""
        return {etf: int(allocation_ratio * self.safe_volumes[etf]) for etf in self.safe_volumes}

    def execute_volume_calculation(self):
        """Executes all calculations and returns adjusted quantities."""
        discount_margin = self.calculate_discount_margin()  # Use discount margin instead of leveraged margin
        trade_values = self.calculate_trade_values()
        total_trade_value = self.calculate_total_trade_value(trade_values)
        allocation_ratio = self.calculate_allocation_ratio(discount_margin, total_trade_value)
        adjusted_quantities = self.calculate_adjusted_quantities(allocation_ratio)
        
        return adjusted_quantities

class DataStore:
    """Class to store symbols, adjusted quantities, and predicted prices."""

    def __init__(self):
        self.data = []

    def add_data(self, symbol, adjusted_quantity, predicted_price):
        """Adds a new entry to the data store."""
        self.data.append({
            'symbol_a': symbol,
            'quantity_a': adjusted_quantity,
            'price_a': predicted_price
        })

    def get_data(self):
        """Returns all stored data."""
        return self.data

class OrderStore:
    """Generates order data using symbols, quantities, and prices from DataStore."""

    def __init__(self):
        self.orders = []  # List to store order data

    def format_symbol(self, symbol):
        """Removes '.NS' from the symbol."""
        return symbol.split(".")[0]

    def add_order(self, symbol, quantity, price):
        """Creates two order records (BUY and SELL) for each ETF."""
        symbol_b = self.format_symbol(symbol)  # Format symbol
        price_b_buy = round(price * 0.95, 2)  # 0.5% lower for BUY
        price_b_sell = round(price * 1.05, 2)  # 0.5% higher for SELL
        quantity_b = quantity

        # Add BUY order
        self.orders.append({
            "symbol_b": symbol_b,
            "price_b": price_b_buy,
            "quantity_b": quantity_b,
            "txn_b": "BUY"
        })

        # Add SELL order
        self.orders.append({
            "symbol_b": symbol_b,
            "price_b": price_b_sell,
            "quantity_b": quantity_b,
            "txn_b": "SELL"
        })

    def generate_orders(self, data_store):
        """Creates orders from data stored in DataStore."""
        for entry in data_store.get_data():
            self.add_order(entry['symbol_a'], entry['quantity_a'], entry['price_a'])

    def get_orders(self):
        """Returns the list of generated orders."""
        return self.orders

class PayloadStore:
    """Stores order payloads in the required format."""

    def __init__(self):
        self.orders = []  # List to store formatted order payloads

    def add_order(self, symbol, txn, quantity, price):
        """Creates an order payload and adds it to the list."""
        order_payload = {
            "variety": "regular",
            "exchange": "NSE",
            "order_type": "LIMIT",
            "tradingsymbol": symbol,
            "transaction_type": txn,
            "quantity": quantity,
            "price": price,
            "product": "MIS",
            "validity": "TTL",
            "validity_ttl": "1"
        }
        self.orders.append(order_payload)

    def generate_payloads(self, order_store):
        """Generates payloads from orders in OrderStore."""
        for order in order_store.get_orders():
            self.add_order(
                symbol=order["symbol_b"],
                txn=order["txn_b"],
                quantity=order["quantity_b"],
                price=order["price_b"]
            )

    def get_payloads(self):
        """Returns the generated payloads."""
        return self.orders

class ZerodhaOrders:
    """Handles synchronous order placement using requests."""

    ORDER_URL = "https://kite.zerodha.com/oms/orders/regular"

    def __init__(self, session, enctoken, headers):
        """Initialize with an existing authenticated session and headers."""
        self.session = session
        self.enctoken = enctoken
        self.headers = headers

        if not self.enctoken or not self.headers:
            raise ValueError("Authentication token or headers are missing. Cannot place orders.")

    def place_order(self, order_data):
        """Places a single order synchronously."""
        try:
            response = requests.post(self.ORDER_URL, headers=self.headers, data=order_data)
            return response.json()
        except Exception as e:
            return {"error": str(e)}

    def place_orders(self, order_payloads):
        """Places multiple orders synchronously."""
        results = []
        for order in order_payloads:
            result = self.place_order(order)
            results.append(result)
        return results

def main():
    """Main execution function"""
    assets = {
        "^NSEI": "NIFTYBEES.NS",      # Nifty 50 → Niftybees
        "^NSMIDCP": "JUNIORBEES.NS",   # Nifty Next 50 → Junior Bees
        "^NSEBANK": "BANKBEES.NS"      # Nifty Bank → Bank Bees
    }

    # Predict ETF opening prices
    predictor = ETFPricePredictor(assets)
    
    print("Fetching historical closing prices...")
    predictor.fetch_closing_prices()

    print("Fetching today's opening prices...")
    predictor.fetch_opening_prices()

    print("Training regression models...")
    predictor.train_models()

    print("\nToday's Opening Prices:")
    for index, price in predictor.opening_prices.items():
        print(f"{index}: {price}")

    print("\nPredicted ETF Opening Prices:")
    predicted_prices = predictor.predict_opening_prices()
    for etf, price in predicted_prices.items():
        print(f"{etf}: {price:.2f}" if isinstance(price, float) else f"{etf}: {price}")

    # Analyze ETF trading volumes
    volume_analyzer = ETFVolumeAnalyzer(assets)
    
    print("\nFetching ETF volume data...")
    volume_analyzer.fetch_average_volumes()

    print("Calculating safe volumes...")
    volume_analyzer.calculate_safe_volumes()

    print("\nAverage ETF Trading Volumes:")
    for etf, avg_volume in volume_analyzer.average_volumes.items():
        print(f"{etf}: {avg_volume:,.0f}")

    print("\nSafe Trading Volumes:")
    safe_volumes = volume_analyzer.get_safe_volumes()
    for etf, safe_vol in safe_volumes.items():
        print(f"{etf}: {safe_vol}")

    # Log in to Zerodha
    zerodha = ZerodhaLogin("DXU151", "Pratibha", "FLJBDJNEBOIMZZZPE25YYYR72Y2B2IAP")
    session, enctoken = zerodha.login()

    # Ensure successful login before proceeding
    if not enctoken:
        print("Zerodha login failed. Exiting...")
        return  

    # Initialize ZerodhaMargin with correct headers
    headers = {
        "Authorization": f"enctoken {enctoken}",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36",
        "Referer": "https://kite.zerodha.com/dashboard",
        "Accept-Language": "en-US,en;q=0.6",
        "Content-type": "application/x-www-form-urlencoded",
        "Accept": "application/json, text/plain, */*",
    }

    zerodha_margin = ZerodhaMargin(session, enctoken, headers)
    equity_margin, commodity_margin = zerodha_margin.fetch_margin()

    print("\nZerodha Margin Details:")
    print(f"Equity Margin: {equity_margin}")
    print(f"Commodity Margin: {commodity_margin}")

    # Initialize VolumeCalculation with necessary data
    volume_calculator = VolumeCalculation(equity_margin, predicted_prices, safe_volumes)

    # Calculate adjusted quantities
    adjusted_quantities = volume_calculator.execute_volume_calculation()

    print("\nAdjusted Quantities for Each ETF:")
    for etf, adjusted_quantity in adjusted_quantities.items():
        print(f"{etf}: {adjusted_quantity}")

    # Create DataStore and add data
    datastore = DataStore()
    
    for etf, adjusted_quantity in adjusted_quantities.items():
        predicted_price = predicted_prices.get(etf, None)
        datastore.add_data(etf, adjusted_quantity, predicted_price)

    # Get and display the stored data
    print("\nStored Data:")
    data = datastore.get_data()
    for entry in data:
        print(f"Symbol: {entry['symbol_a']}, Quantity: {entry['quantity_a']}, Predicted Price: {entry['price_a']}")

    # Create an instance of OrderStore
    order_store = OrderStore()

    # Generate orders using data from DataStore
    order_store.generate_orders(datastore)

    # Retrieve and display the orders
    print("\nGenerated Orders:")
    for order in order_store.get_orders():
        print(f"Symbol: {order['symbol_b']}, Price: {order['price_b']}, Quantity: {order['quantity_b']}, TXN: {order['txn_b']}")

    # Create an instance of PayloadStore
    payload_store = PayloadStore()

    # Generate payloads from orders
    payload_store.generate_payloads(order_store)

    # Retrieve and display the payloads
    print("\nGenerated Payloads:")
    for payload in payload_store.get_payloads():
        print(payload)

    order_payloads = payload_store.get_payloads()  # Get the actual data

    # Initialize ZerodhaOrders
    zerodha_orders = ZerodhaOrders(session, enctoken, headers)

    # Place orders
    results = zerodha_orders.place_orders(order_payloads)

    # Define the exact target time
    now = datetime.now()
    target_time = now.replace(hour=9, minute=15, second=0, microsecond=0)

    def execute_orders():
        """Function to place orders precisely at 9:15 AM"""
        # Assuming session, enctoken, and headers are already initialized
        #zerodha_orders = ZerodhaOrders(session, enctoken, headers)
        #order_payloads = payload_store.get_payloads()
        results = zerodha_orders.place_orders(order_payloads)
            
        # Print results
        #print("\nOrder Placement Results:", results)

    # Execute `execute_orders` at exactly 9:15 AM
    TimeUtils.execute_at_precise_time(target_time, execute_orders)

    # Print responses
    print("\nOrder Placement Results:", results)

if __name__ == "__main__":
    main()
# Out:
# [*********************100%***********************]  6 of 6 completed
# Fetching historical closing prices...
# Fetching today's opening prices...
# [*********************100%***********************]  3 of 3 completed
# Training regression models...
#
# Today's Opening Prices:
# ^NSEI: 23192.599609375
# ^NSMIDCP: 62466.55078125
# ^NSEBANK: 50966.8984375
#
# Predicted ETF Opening Prices:
# NIFTYBEES.NS: 259.58
# JUNIORBEES.NS: 667.98
# BANKBEES.NS: 522.39
#
# Fetching ETF volume data...
# Calculating safe volumes...
#
# Average ETF Trading Volumes:
# BANKBEES.NS: 911,506
# JUNIORBEES.NS: 465,061
# NIFTYBEES.NS: 6,116,315
#
# Safe Trading Volumes:
# BANKBEES.NS: 202
# JUNIORBEES.NS: 103
# NIFTYBEES.NS: 1359
# Login successful!
#
# Zerodha Margin Details:
# Equity Margin: 95147.21720000001
# Commodity Margin: 0
#
# Adjusted Quantities for Each ETF:
# BANKBEES.NS: 173
# JUNIORBEES.NS: 88
# NIFTYBEES.NS: 1165
#
# Stored Data:
# Symbol: BANKBEES.NS, Quantity: 173, Predicted Price: 522.393284738677
# Symbol: JUNIORBEES.NS, Quantity: 88, Predicted Price: 667.9832315013414
# Symbol: NIFTYBEES.NS, Quantity: 1165, Predicted Price: 259.5771520141817
#
# Generated Orders:
# Symbol: BANKBEES, Price: 496.27, Quantity: 173, TXN: BUY
# Symbol: BANKBEES, Price: 548.51, Quantity: 173, TXN: SELL
# Symbol: JUNIORBEES, Price: 634.58, Quantity: 88, TXN: BUY
# Symbol: JUNIORBEES, Price: 701.38, Quantity: 88, TXN: SELL
# Symbol: NIFTYBEES, Price: 246.6, Quantity: 1165, TXN: BUY
# Symbol: NIFTYBEES, Price: 272.56, Quantity: 1165, TXN: SELL
#
# Generated Payloads:
# {'variety': 'regular', 'exchange': 'NSE', 'order_type': 'LIMIT', 'tradingsymbol': 'BANKBEES', 'transaction_type': 'BUY', 'quantity': 173, 'price': np.float64(496.27), 'product': 'MIS', 'validity': 'TTL', 'validity_ttl': '1'}
# {'variety': 'regular', 'exchange': 'NSE', 'order_type': 'LIMIT', 'tradingsymbol': 'BANKBEES', 'transaction_type': 'SELL', 'quantity': 173, 'price': np.float64(548.51), 'product': 'MIS', 'validity': 'TTL', 'validity_ttl': '1'}
# {'variety': 'regular', 'exchange': 'NSE', 'order_type': 'LIMIT', 'tradingsymbol': 'JUNIORBEES', 'transaction_type': 'BUY', 'quantity': 88, 'price': np.float64(634.58), 'product': 'MIS', 'validity': 'TTL', 'validity_ttl': '1'}
# {'variety': 'regular', 'exchange': 'NSE', 'order_type': 'LIMIT', 'tradingsymbol': 'JUNIORBEES', 'transaction_type': 'SELL', 'quantity': 88, 'price': np.float64(701.38), 'product': 'MIS', 'validity': 'TTL', 'validity_ttl': '1'}
# {'variety': 'regular', 'exchange': 'NSE', 'order_type': 'LIMIT', 'tradingsymbol': 'NIFTYBEES', 'transaction_type': 'BUY', 'quantity': 1165, 'price': np.float64(246.6), 'product': 'MIS', 'validity': 'TTL', 'validity_ttl': '1'}
# {'variety': 'regular', 'exchange': 'NSE', 'order_type': 'LIMIT', 'tradingsymbol': 'NIFTYBEES', 'transaction_type': 'SELL', 'quantity': 1165, 'price': np.float64(272.56), 'product': 'MIS', 'validity': 'TTL', 'validity_ttl': '1'}
#
# Order Placement Results: [{'status': 'error', 'message': 'Your order could not be converted to a After Market Order (AMO).', 'data': {'hints': ['switch_to_amo']}, 'error_type': 'InputException'}, {'status': 'error', 'message': 'Your order could not be converted to a After Market Order (AMO).', 'data': {'hints': ['switch_to_amo']}, 'error_type': 'InputException'}, {'status': 'error', 'message': 'Your order could not be converted to a After Market Order (AMO).', 'data': {'hints': ['switch_to_amo']}, 'error_type': 'InputException'}, {'status': 'error', 'message': 'Your order could not be converted to a After Market Order (AMO).', 'data': {'hints': ['switch_to_amo']}, 'error_type': 'InputException'}, {'status': 'error', 'message': 'Your order could not be converted to a After Market Order (AMO).', 'data': {'hints': ['switch_to_amo']}, 'error_type': 'InputException'}, {'status': 'error', 'message': 'Your order could not be converted to a After Market Order (AMO).', 'data': {'hints': ['switch_to_amo']}, 'error_type': 'InputException'}]
